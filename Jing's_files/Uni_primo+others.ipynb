# %%
#環境設置
from selenium import webdriver 
from selenium.webdriver.support.ui import Select
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
import pandas as pd
import requests
import requests.packages.urllib3
requests.packages.urllib3.disable_warnings()
import time
driver = webdriver.Chrome("C:\\Users\\88698\\OneDrive\\文件\\chromedriver") 
ISBN = str(9789869109321)
df_lst = []

# %%
#改館藏狀態的def

def status(df2):
    arimasu = ["可外借", "在架上" , "在架", "仍在館內", "有可用館藏", "書在館", "目前可獲得", "可獲得", "在書架上"]
    arimasen = []
    for i in df2[[0:], "館藏狀態"]: #選取每一列，館藏狀態那一行的資料

# %%
# 台大

url = "https://ntu.primo.exlibrisgroup.com/discovery/search?query=any,contains," + ISBN + "&tab=Everything&search_scope=MyInst_and_CI&vid=886NTU_INST:886NTU_INST&offset=0"
driver.get(url)
time.sleep(5)
title = driver.find_element_by_class_name('item-title').click()

time.sleep(3)
try:
    try:
        back = driver.find_element_by_css_selector(".tab-header .back-button.button-with-icon.zero-margin.md-button.md-primoExplore-theme.md-ink-ripple")
    except:
        back = None
    if back != None:
        back.click()
        
    thelist = driver.find_elements_by_class_name("layout-align-space-between-center.layout-row.flex-100")
    for row in thelist:
        plist = row.find_elements_by_tag_name("p")
        where = row.find_elements_by_tag_name("h3")
        i = len(where)
        for sth in plist:
            a = sth.find_elements_by_tag_name("span")
            for _ in range(i): 
                new_row = ['台灣大學', where[_].text, a[4].text, a[0].text, url]
                df_lst.append(new_row)
                break
            break
except:
    pass

driver.close()
# Out:
# [['台灣大學', '總圖書館', '550.187 4025', '有可用館藏', 'https://ntu.primo.exlibrisgroup.com/discovery/search?query=any,contains,9789869109321&tab=Everything&search_scope=MyInst_and_CI&vid=886NTU_INST:886NTU_INST&offset=0'], ['台灣大學', '辜振甫圖書館', '550.187 4025', '不在圖書館內', 'https://ntu.primo.exlibrisgroup.com/discovery/search?query=any,contains,9789869109321&tab=Everything&search_scope=MyInst_and_CI&vid=886NTU_INST:886NTU_INST&offset=0'], ['台灣大學', '辜振甫圖書館', '550.187 4025', '有可用館藏', 'https://ntu.primo.exlibrisgroup.com/discovery/search?query=any,contains,9789869109321&tab=Everything&search_scope=MyInst_and_CI&vid=886NTU_INST:886NTU_INST&offset=0'], ['台灣大學', '醫學圖書館', '550.187 4025', '不在圖書館內', 'https://ntu.primo.exlibrisgroup.com/discovery/search?query=any,contains,9789869109321&tab=Everything&search_scope=MyInst_and_CI&vid=886NTU_INST:886NTU_INST&offset=0']]

# %%
# 銘傳

url = "https://uco-mcu.primo.exlibrisgroup.com/discovery/search?query=any,contains," + ISBN + "&tab=Everything&search_scope=MyInst_and_CI&vid=886UCO_MCU:886MCU_INST&lang=zh-tw&offset=0"
driver.get(url)
time.sleep(5)
title = driver.find_element_by_class_name('item-title').click()

time.sleep(3)
try:
    try:
        back = driver.find_element_by_css_selector(".tab-header .back-button.button-with-icon.zero-margin.md-button.md-primoExplore-theme.md-ink-ripple")
    except:
        back = None
    if back != None:
        back.click()
    thelist = driver.find_elements_by_class_name("md-2-line.md-no-proxy._md")
    for row in thelist[:-2]:
        plist = row.find_elements_by_tag_name("p")
        where = row.find_elements_by_tag_name("h3")
        i = len(where)
        for sth in plist:
            a = sth.find_elements_by_tag_name("span")
            for _ in range(1): 
                new_row = ['銘傳大學', where[_].text, a[4].text, a[0].text, url]
                df_lst.append(new_row)
            break
except:
    pass
driver.close()
# Out:
# 9789869109321
# 銘傳大學 桃園館 有可用館藏
# 銘傳大學 臺北館 有可用館藏

# %%
# 東吳

url = "https://uco-scu.primo.exlibrisgroup.com/discovery/search?query=any,contains," + ISBN + "&tab=Everything&search_scope=MyInst_and_CI&vid=886UCO_SCU:886SCU_INST&lang=zh-tw&offset=0"
driver.get(url)
time.sleep(5)
title = driver.find_element_by_class_name('item-title').click()

time.sleep(3)
try:
    back = driver.find_element_by_css_selector(".tab-header .back-button.button-with-icon.zero-margin.md-button.md-primoExplore-theme.md-ink-ripple")
except:
    back = None
if back != None:
    back.click()
thelist = driver.find_elements_by_class_name("md-2-line.md-no-proxy._md")
for row in thelist[:-2]:
    plist = row.find_elements_by_tag_name("p")
    where = row.find_elements_by_tag_name("h3")
    i = len(where)
    for sth in plist:
        a = sth.find_elements_by_tag_name("span")
        for _ in range(1): 
            new_row = ['東吳大學', where[_].text, a[4].text, a[0].text, url]
            df_lst.append(new_row)
            break
        break 
driver.close()
# Out:
# 9789869109321
# 東吳大學 城區分館書庫 目前可獲得
# 東吳大學 城區分館書庫 目前可獲得
# 東吳大學 雙溪中正書庫 目前可獲得

# %%
# 淡江

url = "https://uco-network.primo.exlibrisgroup.com/discovery/search?query=any,contains," + ISBN + "&tab=Everything&search_scope=MyInst_and_CI&vid=886UCO_TKU:886TKU_INST&lang=zh-tw&offset=0"
driver.get(url)
time.sleep(5)
title = driver.find_element_by_class_name('item-title').click()

time.sleep(3)
try:
    back = driver.find_element_by_css_selector(".tab-header .back-button.button-with-icon.zero-margin.md-button.md-primoExplore-theme.md-ink-ripple")
except:
    back = None
if back != None:
    back.click()
thelist = driver.find_elements_by_class_name("neutralized-button.layout-full-width.layout-display-flex.md-button.md-ink-ripple.layout-row")
for row in thelist:
    plist = row.find_elements_by_tag_name("p")
    where = row.find_elements_by_tag_name("h3")
    i = len(where)
    for sth in plist:
        a = sth.find_elements_by_tag_name("span")
        for _ in range(i): 
            new_row = ['淡江大學', where[_].text, a[4].text, a[0].text, url]
            df_lst.append(new_row)
            break
driver.close()
# Out:
# 9789869109321
# 淡江大學 總館 可獲得
# 淡江大學 蘭陽校園圖書館 可獲得

# %%
# 政大(不管有幾個版本的完成版)
from selenium import webdriver 
from selenium.webdriver.support.ui import Select
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
import time

ISBN = str(9789869109321)
df_lst = []
driver = webdriver.Chrome("C:\\Users\\88698\\OneDrive\\文件\\chromedriver") 
driver.get("https://nccu.primo.exlibrisgroup.com/discovery/search?query=any,contains," + ISBN + "&tab=Everything&search_scope=MyInst_and_CI&vid=886NCCU_INST:886NCCU_INST") 
time.sleep(3)
title = driver.find_elements_by_class_name('item-title')[0].click()
time.sleep(1)

def finding(x):
    sub_df_lst = []
    try:
        back = driver.find_element_by_css_selector(".tab-header .back-button.button-with-icon.zero-margin.md-button.md-primoExplore-theme.md-ink-ripple")
    except:
        back = None
    if back != None:
        back.click()
    thelist = driver.find_elements_by_class_name("layout-align-space-between-center.layout-row.flex-100")
    for row in thelist:
        plist = row.find_elements_by_tag_name("p")
        where = row.find_elements_by_tag_name("h3")
        i = len(where)
        for sth in plist:
            a = sth.find_elements_by_tag_name("span")
            for _ in range(i): 
                new_row = ['政治大學', where[_].text, a[4].text, a[0].text, url]
                sub_df_lst.append(new_row)
                break
            break
    return sub_df_lst

try:
    editions = driver.find_elements_by_class_name('item-title')
    if len(editions) > 1:
        for i in range(len(editions)):
            into = editions[i].click()
            time.sleep(3)
            df_lst += finding(0)
            try:
                back2 = driver.find_element_by_class_name("md-icon-button.close-button.full-view-navigation.md-button.md-primoExplore-theme.md-ink-ripple").click()
            except:
                back2 = None
    else:
        time.sleep(3)
        df_lst += finding(0)
except:
    pass

driver.close()
# Out:
# [['政治大學', '綜圖', '550.187 8757 2017', '不在圖書館內', 'https://ntu.primo.exlibrisgroup.com/discovery/fulldisplay?docid=alma991012361209704786&context=L&vid=886NTU_INST:886NTU_INST&lang=zh-tw&search_scope=MyInst_and_CI&adaptor=Local%20Search%20Engine&isFrbr=true&tab=Everything&query=any,contains,9789869109321&offset=0'], ['政治大學', '達賢館', '550.187 8757 2017', '不在圖書館內', 'https://ntu.primo.exlibrisgroup.com/discovery/fulldisplay?docid=alma991012361209704786&context=L&vid=886NTU_INST:886NTU_INST&lang=zh-tw&search_scope=MyInst_and_CI&adaptor=Local%20Search%20Engine&isFrbr=true&tab=Everything&query=any,contains,9789869109321&offset=0'], ['政治大學', '綜圖', '550.187 8757', '目前可獲得', 'https://ntu.primo.exlibrisgroup.com/discovery/fulldisplay?docid=alma991012361209704786&context=L&vid=886NTU_INST:886NTU_INST&lang=zh-tw&search_scope=MyInst_and_CI&adaptor=Local%20Search%20Engine&isFrbr=true&tab=Everything&query=any,contains,9789869109321&offset=0']]

# %%
# 交大
#  
driver.get("https://ustcate0.lib.nctu.edu.tw/primo_library/libweb/action/search.do?mode=Basic&vid=NCTU&vl(freeText0)=&tab=ils_article&") # 更改網址以前往不同網頁
try:
    element = driver.find_element_by_id('search_field')
    element.send_keys(ISBN)
    search_gogogo = driver.find_element_by_id('goButton').click()
    time.sleep(2)
    place_click = driver.find_element_by_id('exlidResult0-LocationsTab').click()
    time.sleep(1)
    place = driver.find_element_by_class_name('EXLAvailabilityLibraryName')
    status = driver.find_element_by_id('rtaReturnedStatusTOP010054897964801549636893389809149347790')
    num = driver.find_element_by_xpath('//html/body/div[1]/div[3]/div[1]/div[3]/table/tbody/tr/td[4]/div[5]/form/div[2]/div[2]/div/span[2]/cite')
    new_row = ['交通大學', place.text, status.text, num.text, url]
    df_lst.append(new_row)
except:
    pass

driver.close()
# Out:
# 交通大學 交大圖書總館 有可用館藏 (550.187 2701 )

# %%
# 桃園
from selenium import webdriver # 先下載 webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
import time
ISBN = str(9789869109321)
df_lst = []
driver = webdriver.Chrome("C:\\Users\\88698\\OneDrive\\文件\\chromedriver") 

url = "https://webpac.typl.gov.tw/search?phonetic=0&queryType=0&searchField=ISBN&searchInput=" + ISBN
driver.get(url)
time.sleep(5)

try:
    show_more = driver.find_element_by_link_text("載入更多").click()
except:
    show_more = None
    
time.sleep(2) 
for i in range(2, 5): #假設最多三個版本
    try:
        edition = driver.find_element_by_xpath('//html/body/div[1]/div[1]/div/div/div/div[2]/div/div[4]/form/div/div[' + str(i) + ']/div[2]/div[1]/h2/a').click()
        time.sleep(4) 
        table = driver.find_element_by_class_name('bookplace_list')
        trlist = table.find_elements_by_tag_name('tr')
        for row in trlist:
            tdlist = row.find_elements_by_tag_name('td')
            for sth in tdlist:
                new_row = ['桃園市立圖書館', tdlist[0].text, tdlist[3].text, url]
                df_lst.append(new_row)
                break
        backtolist = driver.find_element_by_xpath('//html/body/div/div[1]/div[2]/div/div/div[2]/div/div[1]/ul/li[2]').click()
        time.sleep(1) 
    except:
        pass

# %%
#基隆市
from selenium import webdriver 
from selenium.webdriver.support.ui import Select
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
import time
driver = webdriver.Chrome("C:\\Users\\88698\\OneDrive\\文件\\chromedriver") 

url = "https://webpac.klccab.gov.tw/webpac/search.cfm?m=ss&k0=" + ISBN + "&t0=k&c0=and"
driver.get(url) 
time.sleep(2)

table = driver.find_element_by_class_name('list.list_border')
trlist = table.find_elements_by_tag_name('tr')
for row in trlist[1:]:
    tdlist = row.find_elements_by_tag_name('td')
    for sth in tdlist:
        new_row = ['基隆市立圖書館', tdlist[1].text, tdlist[3].text, tdlist[2].text, url]
        df_lst.append(new_row)
        break
# Out:
# 基隆市立圖書館 文化局開架閱覽室 仍在館內
# 基隆市立圖書館 文化局開架閱覽室 仍在館內
# 基隆市立圖書館 安樂區圖書館 借出
# 2021/07/31

# %%
# 馬偕醫
from selenium import webdriver # 先下載 webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
import time
ISBN = '9789868879348'
driver = webdriver.Chrome("C:\\Users\\88698\\OneDrive\\文件\\chromedriver") 

url = "http://aleph.library.mmc.edu.tw/F/3SSA1HL1RXHEXNGXVNGEJ9D6L33E2MHIUGGQRDNKAC773SFLCY-00548?func=find-b&find_code=WAN&request=" + ISBN + "&local_base=TOP02&adjacent=1"
driver.get(url)
time.sleep(5)

try:
    where2 = driver.find_element_by_class_name("brieftit").click()
    time.sleep(5)
    where3 = driver.find_element_by_xpath("/html/body/table[9]/tbody/tr/td[1]/table/tbody/tr[1]/td[2]/span/a[1]").click()
    time.sleep(3)
    table = driver.find_element_by_xpath('/html/body/table[10]')
    trlist = table.find_elements_by_tag_name('tr')
    for row in trlist[0:2]:
        tdlist = row.find_elements_by_tag_name('td')
        for sth in tdlist:
            new_row = ['馬偕醫學院', tdlist[2].text, tdlist[4].text, tdlist[7].text, url]
            df_lst.append(new_row)
            break
except:
    pass
# Out:
# 馬偕醫學院 醫學院圖書館 550.1657 4362 在書架上

# %%
# 北科(好像可以用pandas欸)
from selenium import webdriver # 先下載 webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
import time
driver = webdriver.Chrome("C:\\Users\\88698\\OneDrive\\文件\\chromedriver") 
 
driver.get("https://libholding.ntut.edu.tw/webpacIndex.jsp")
ISBN = input()
element = driver.find_element_by_id('search_inputS')
element.send_keys(ISBN)
select = Select(driver.find_element_by_id('search_field'))
select.select_by_value("STANDARDNO")
search_gogogo = driver.find_element_by_xpath('/html/body/div[2]/table/tbody/tr/td[1]/div/div/div[1]/div/div[1]/div/form/table/tbody/tr[2]/td/input[3]').click()


time.sleep(5)
table = driver.find_element_by_class_name('order')
trlist = table.find_elements_by_tag_name('tr')
for row in trlist:
    tdlist = row.find_elements_by_tag_name('td')
    for sth in tdlist:
        print('台北科技大學', tdlist[2].text, tdlist[4].text, tdlist[8].text, end = "\n")
        break
driver.close()

# %%
# 北醫(好像可以用pandas欸)
from selenium import webdriver # 先下載 webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
import time

driver = webdriver.Chrome("C:\\Users\mayda\Downloads\chromedriver") 
driver.get("https://libelis.tmu.edu.tw/webpacIndex.jsp") # 更改網址以前往不同網頁
ISBN = input()
element = driver.find_element_by_id('search_inputS')
element.send_keys(ISBN)
select = Select(driver.find_element_by_id('search_field'))
select.select_by_value("ISBN")
search_gogogo = driver.find_element_by_xpath('/html/body/div[2]/table/tbody/tr/td[1]/div/div/div[1]/div/div[1]/div/form/table/tbody/tr[2]/td[1]/input[2]').click()

time.sleep(5)
table = driver.find_element_by_class_name('order')
trlist = table.find_elements_by_tag_name('tr')
for row in trlist:
    tdlist = row.find_elements_by_tag_name('td')
    for sth in tdlist:
        print('台北醫學大學', tdlist[2].text, tdlist[3].text, tdlist[5].text, end = "\n")
        break
driver.close()

# %%
#北藝
from selenium import webdriver # 先下載 webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
import time
driver = webdriver.Chrome("C:\\Users\\88698\\OneDrive\\文件\\chromedriver") 
ISBN = str(9789861371955)

url = 'http://203.64.5.158/webpac/search/?q=' + ISBN + '&field=isn&op=AND&type=&match='
driver.get(url)

try:
    where = driver.find_element_by_xpath("/html/body/div/div[1]/div[2]/div/div/div[2]/div[3]/div[1]/div[3]/div/ul/li/div/div[2]/h3/a").click()
    time.sleep(2)
    table = driver.find_element_by_class_name('table.table-bordered')
    trlist = table.find_elements_by_tag_name('tr')
    for row in trlist:
        tdlist = row.find_elements_by_tag_name('td')
        for sth in tdlist:
            new_row = ['台北藝術大學', tdlist[0].text, tdlist[2].text, tdlist[5].text, url]
            df_lst.append(new_row)
            break
except:
    pass
# Out:
# 台北藝術大學 總圖 BF698 K5812 外借中

# %%
#景文(好像可以用pandas欸)
from selenium import webdriver # 先下載 webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
import time

driver = webdriver.Chrome("C:\\Users\mayda\Downloads\chromedriver") 
driver.get("https://jinwenlib.just.edu.tw/webpacIndex.jsp")
ISBN = input()
element = driver.find_element_by_id('search_inputS')
element.send_keys(ISBN)
select = Select(driver.find_element_by_id('search_field'))
select.select_by_value("ISBN")
search_gogogo = driver.find_element_by_xpath('/html/body/div[2]/table/tbody/tr/td[1]/div/div/div[1]/div/div[1]/div/form/table/tbody/tr[2]/td[1]/input[3]').click()

time.sleep(5)

table = driver.find_element_by_class_name('order')
trlist = table.find_elements_by_tag_name('tr')
for row in trlist:
    tdlist = row.find_elements_by_tag_name('td')
    for sth in tdlist:
        print(tdlist[2].text, tdlist[3].text, tdlist[5].text, end = "\n")
        break
driver.close()

# %%
# 工研院
from selenium import webdriver # 先下載 webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
import time
driver = webdriver.Chrome("C:\\Users\\88698\\OneDrive\\文件\\chromedriver") 
ISBN = str(9789869109321)

url = "https://itrilib.itri.org.tw/F/MD171BFA9JTTCVSJHS39BSIRFPARXIGEGX9BDA71L6ELK7CXA6-19389?func=find-b&find_code=ISBN&request="+ ISBN +"&local_base=ITRIBIB&adjacent=1"
driver.get(url)

time.sleep(5)
where = driver.find_element_by_class_name("brieftit").click()
time.sleep(2)
where = driver.find_element_by_xpath("/html/body/table[9]/tbody/tr/td[1]/table/tbody/tr[1]/td[2]/a").click()
time.sleep(2)
tdlist = driver.find_elements_by_class_name('td1')
new_row = [tdlist[9].text, tdlist[10].text, tdlist[6].text, tdlist[12].text, url]
df_lst.append(new_row)
driver.close()

# %%
# 國衛院
from selenium import webdriver # 先下載 webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
import time
driver = webdriver.Chrome("C:\\Users\\88698\\OneDrive\\文件\\chromedriver") 
ISBN = str(9789861371955)

url = 'http://webpac.nhri.edu.tw/webpac/search/?q=' + ISBN + '&field=text&op=AND&type=&department=&college=&dep=&searchmode=&active=1&match=smart'
driver.get(url)
time.sleep(5)
try:
    where = driver.find_element_by_xpath("/html/body/div/div[1]/div[2]/div/div/div[2]/div[3]/div[1]/div[3]/div/ul/li/div/div[2]/h3/a").click()
    time.sleep(2)
    table = driver.find_element_by_class_name('table.table-bordered')
    trlist = table.find_elements_by_tag_name('tr')
    for row in trlist:
        tdlist = row.find_elements_by_tag_name('td')
        for sth in tdlist:
            new_row = ['國家衛生研究院', tdlist[1].text, tdlist[2].text, tdlist[6].text, end = "\n")
            break
except:
    pass
driver.close()
# Out:
# 國家衛生研究院 心靈健康區 177.3 8332 2014 在書架上

# %%
# 國臺圖
from selenium import webdriver # 先下載 webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
import time
driver = webdriver.Chrome("C:\\Users\\88698\\OneDrive\\文件\\chromedriver") 
ISBN = str(9789869109321)
df_lst = []
 
url = 'https://cis2.ntl.edu.tw/webpac/search/?field=text&op=AND&type=&tab=home&department=&college=&dep=&searchmode=&active=1&q=' + ISBN + '&match=smart'
driver.get(url)

try:
    time.sleep(5)
    where = driver.find_element_by_class_name("uk-width-4-5.uk-width-xlarge-5-6").click()
    time.sleep(4)
    table = driver.find_element_by_class_name('uk-table.uk-table-condensed.uk-text-top.table-bordered')
    trlist = table.find_elements_by_tag_name('tr')
    for row in trlist[0:2]:
        tdlist = row.find_elements_by_tag_name('td')
        for sth in tdlist:
            new_row = ['國立臺灣圖書館', tdlist[1].text, tdlist[2].text, tdlist[6].text, url]
            df_lst.append(new_row)
            break
except:
    pass
# Out:
# [['國立臺灣圖書館', '三樓青少年得獎圖書區', '550.187 4025 103', '在書架上', 'https://cis2.ntl.edu.tw/webpac/search/?field=text&op=AND&type=&tab=home&department=&college=&dep=&searchmode=&active=1&q=9789869109321&match=smart']]

# %%
# 宜蘭大學(可用pandas)
from selenium import webdriver 
from selenium.webdriver.support.ui import Select
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
import time

driver = webdriver.Chrome("C:\\Users\mayda\Downloads\chromedriver") 
driver.get("https://lib.niu.edu.tw/webpacIndex.jsp") # 更改網址以前往不同網頁
ISBN = input()
element = driver.find_element_by_name('search_input')
element.send_keys(ISBN)
select = Select(driver.find_element_by_id('search_field'))
select.select_by_value("ISBN")
search_gogogo = driver.find_element_by_xpath('/html/body/div[2]/table/tbody/tr/td[1]/div/div/div[1]/div/div[1]/div/form/table/tbody/tr[2]/td/input[3]').click()
time.sleep(2)
table = driver.find_element_by_class_name('order')
trlist = table.find_elements_by_tag_name('tr')
for row in trlist:
    tdlist = row.find_elements_by_tag_name('td')
    for sth in tdlist:
        print('宜蘭大學', tdlist[2].text, tdlist[3].text, tdlist[5].text, end = "\n")
        break
    
driver.close()

# %%
# 明新科大(pandas)
from selenium import webdriver # 先下載 webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
import time

driver = webdriver.Chrome("C:\\Users\mayda\Downloads\chromedriver") 
driver.get("https://hylib.lib.must.edu.tw/webpacIndex.jsp") # 更改網址以前往不同網頁
ISBN = input()
element = driver.find_element_by_id('search_inputS')
element.send_keys(ISBN)
select = Select(driver.find_element_by_id('search_field'))
select.select_by_value("ISBN")
search_gogogo = driver.find_element_by_xpath('/html/body/div[2]/table/tbody/tr/td[1]/div/div/div[1]/div/div[1]/div/form/table/tbody/tr[2]/td[1]/input[2]').click()
time.sleep(5)

table = driver.find_element_by_class_name('order')
trlist = table.find_elements_by_tag_name('tr')
for row in trlist:
    tdlist = row.find_elements_by_tag_name('td')
    for sth in tdlist:
        print("明新科大", tdlist[2].text, tdlist[3].text, tdlist[5].text, end = "\n")
        break
driver.close()

# %%
# 龍華科大
from selenium import webdriver # 先下載 webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
import time

driver = webdriver.Chrome("C:\\Users\mayda\Downloads\chromedriver") 
driver.get("https://webpac.lhu.edu.tw/webpac/search.cfm") # 更改網址以前往不同網頁
advance = driver.find_element_by_link_text("進階檢索").click()
ISBN = input()
element = driver.find_element_by_id('as_keyword_1')
element.send_keys(ISBN)
select = Select(driver.find_element_by_id('as_type_1'))
select.select_by_value("i")
search_gogogo = driver.find_element_by_xpath("/html/body/div[4]/div[2]/div[1]/div/div[19]/div[2]/input[1]").click()
time.sleep(5)

table = driver.find_element_by_class_name('list.list_border')
trlist = table.find_elements_by_tag_name('tr')
for row in trlist[1:]:
    tdlist = row.find_elements_by_tag_name('td')
    for sth in tdlist:
        print("龍華科大", tdlist[1].text, tdlist[2].text, tdlist[3].text, end = "\n")
        break
driver.close()

# %%
# 新生醫專
from selenium import webdriver # 先下載 webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
import time
driver = webdriver.Chrome("C:\\Users\\88698\\OneDrive\\文件\\chromedriver") 
ISBN = '986729193X'


url = 'http://163.25.34.60:8080/toread/opac/Advancedsearch.page?classification_type=all&level=all&limit=20&material_type=all&q=isbn_issn%3A' + ISBN + '&source=local&view=CONTENT&wi=false'
driver.get(url) 
time.sleep(5)

try:
    where = driver.find_element_by_id("MyPageLink_1").click()
    time.sleep(5)
    table = driver.find_element_by_class_name('gridTable')
    trlist = table.find_elements_by_tag_name('tr')
    for row in trlist:
        tdlist = row.find_elements_by_tag_name('td')
        for sth in tdlist:
            new_row = ["新生醫專", tdlist[2].text, tdlist[5].text, tdlist[7].text, url]
            df_lst.append(new_row)
            break
except:
    pass
# Out:
# 新生醫專 中文木質書櫃區 在架

# %%
# 臺中市立圖書館 9570825685可
from selenium import webdriver # 先下載 webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
import time

df_lst = []
ISBN = '9789861371955'
driver = webdriver.Chrome("C:\\Users\\88698\\OneDrive\\文件\\chromedriver")

url = "https://ipac.library.taichung.gov.tw/webpac/search.cfm?m=as&k0="+ ISBN +"&t0=i&c0=and&y10=&y20=&cat0=&dt0=&l0=&lv0=&lc0="
driver.get(url)
time.sleep(5)

href = driver.current_url
index = href.find("mid=") # 得到'm'的index整數值
id = href[index+4:index+11] # 得到七位數id
newlink = "https://ipac.library.taichung.gov.tw/webpac/content.cfm?mid=" + id + "&m=as&t0=i&c0=and&list_num=300&current_page=1&mt=&at=&sj=&py=&pr=&it=&lr=&lg=&si=1&contentlistcurrent_page=1&contentlist_num=300"
driver.get(newlink)
time.sleep(10)

try: # 有的書有不只一種版本
    version = int(len(driver.find_elements_by_class_name("list_box")))
except:
    version = 0
if version != 0:
    for i in range(2, 2+version):
        edition = driver.find_element_by_xpath('/html/body/div[4]/div[4]/div[2]/div[2]/div[2]/div[2]/div[' + str(i) + ']/div[1]/ul/li[3]/a').click()
        time.sleep(4)
        try:
            table = driver.find_element_by_class_name('list.list_border')
            trlist = table.find_elements_by_tag_name('tr')
            for row in trlist:
                tdlist = row.find_elements_by_tag_name('td')
                for sth in tdlist:
                    new_row = ["臺中市立圖書館", tdlist[1].text, tdlist[2].text, tdlist[3].text, url]
                    df_lst.append(new_row)
                    break

        except: # 有的版本點進去會顯示"無館藏資料"(困惑)
            pass

        backtolist = driver.find_element_by_link_text("回檢索結果").click()
        time.sleep(1)

else: #只有一種版本        
    table = driver.find_element_by_class_name('list.list_border')
    trlist = table.find_elements_by_tag_name('tr')
    for row in trlist:
        tdlist = row.find_elements_by_tag_name('td')
        for sth in tdlist:
            new_row = ["臺中市立圖書館", tdlist[1].text, tdlist[2].text, tdlist[3].text, url]
            df_lst.append(new_row)
            break

print(df_lst)
# Out:
# [['臺中市立圖書館', '總館開架閱覽區', '177.3 2613 c.4', '送回原館藏地', 'https://ipac.library.taichung.gov.tw/webpac/search.cfm?m=as&k0=9789861371955&t0=i&c0=and&y10=&y20=&cat0=&dt0=&l0=&lv0=&lc0='], ['臺中市立圖書館', '總館開架閱覽區', '177.3 2613 c.2', '借出\n2021/07/31', 'https://ipac.library.taichung.gov.tw/webpac/search.cfm?m=as&k0=9789861371955&t0=i&c0=and&y10=&y20=&cat0=&dt0=&l0=&lv0=&lc0='], ['臺中市立圖書館', '總館開架閱覽區', '177.3 2613 c.3', '在架', 'https://ipac.library.taichung.gov.tw/webpac/search.cfm?m=as&k0=9789861371955&t0=i&c0=and&y10=&y20=&cat0=&dt0=&l0=&lv0=&lc0='], ['臺中市立圖書館', '總館開架閱覽區', '177.3 2613', '借出\n2021/07/31', 'https://ipac.library.taichung.gov.tw/webpac/search.cfm?m=as&k0=9789861371955&t0=i&c0=and&y10=&y20=&cat0=&dt0=&l0=&lv0=&lc0='], ['臺中市立圖書館', '總館開架閱覽區', '177.3 2613 c.1', '借出\n2021/07/31', 'https://ipac.library.taichung.gov.tw/webpac/search.cfm?m=as&k0=9789861371955&t0=i&c0=and&y10=&y20=&cat0=&dt0=&l0=&lv0=&lc0='], ['臺中市立圖書館', '總館開架閱覽區', '177.3 2613 2014', '借出\n2021/07/31', 'https://ipac.library.taic
# ...

# %%
# 臺南市立圖書館
from selenium import webdriver # 先下載 webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
import time

df_lst = []
ISBN = '9789861371955'
driver = webdriver.Chrome("C:\\Users\\88698\\OneDrive\\文件\\chromedriver")

url = "https://lib.tnml.tn.edu.tw/webpac/search.cfm?m=ss&k0="+ ISBN +"&t0=k&c0=and"
driver.get(url)
time.sleep(5)

href = driver.current_url
index = href.find("mid=") # 得到'm'的index整數值
id = href[index+4:index+11] # 得到七位數id
newlink = "https://lib.tnml.tn.edu.tw/webpac/content.cfm?mid=" + id + "&m=as&t0=i&c0=and&list_num=300&current_page=1&mt=&at=&sj=&py=&pr=&it=&lr=&lg=&si=1&contentlistcurrent_page=1&contentlist_num=300"
driver.get(newlink)
time.sleep(10)

try: # 有的書有不只一種版本
    version = int(len(driver.find_elements_by_class_name("list_box")))
except:
    version = 0
if version != 0:
    for i in range(2, 2+version):
        edition = driver.find_element_by_xpath('/html/body/div[4]/div[4]/div[2]/div[2]/div[2]/div[2]/div[' + str(i) + ']/div[1]/ul/li[3]/a').click()
        time.sleep(4)
        try:
            table = driver.find_element_by_class_name('list.list_border')
            trlist = table.find_elements_by_tag_name('tr')
            for row in trlist:
                tdlist = row.find_elements_by_tag_name('td')
                for sth in tdlist:
                    new_row = ["臺南市立圖書館", tdlist[1].text, tdlist[2].text, tdlist[3].text, url]
                    df_lst.append(new_row)
                    break

        except: # 有的版本點進去會顯示"無館藏資料"(困惑)
            pass

        backtolist = driver.find_element_by_link_text("回檢索結果").click()
        time.sleep(1)

else: #只有一種版本        
    table = driver.find_element_by_class_name('list.list_border')
    trlist = table.find_elements_by_tag_name('tr')
    for row in trlist:
        tdlist = row.find_elements_by_tag_name('td')
        for sth in tdlist:
            new_row = ["臺中市立圖書館", tdlist[1].text, tdlist[2].text, tdlist[3].text, url]
            df_lst.append(new_row)
            break

print(df_lst)
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-23-b82ac1cc7042> in <module>
#      46
#      47 else: #只有一種版本
# ---> 48     table = driver.find_element_by_class_name('list.list_border')
#      49     trlist = table.find_elements_by_tag_name('tr')
#      50     for row in trlist:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_class_name(self, name)
#     562             element = driver.find_element_by_class_name('foo')
#     563         """
# --> 564         return self.find_element(by=By.CLASS_NAME, value=name)
#     565
#     566     def find_elements_by_class_name(self, name):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
# ...

# %%
# 新竹
from selenium import webdriver # 先下載 webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
import time
ISBN = str(9789869109321)
df_lst = []
driver = webdriver.Chrome("C:\\Users\\88698\\OneDrive\\文件\\chromedriver") 

url = "https://book.hchcc.gov.tw/bookSearchList.do?searchtype=simplesearch&search_field=ISBN&search_input=" + ISBN + "&searchsymbol=hyLibCore.webpac.search.common_symbol&execodehidden=true&execode=&ebook=&csrfToken=D78F9B0555D0ABA2DE29EC96C7BA5389&hyftdToken=188809228&nowpage=1#searchtype=simplesearch&search_field=ISBN&search_input=" + ISBN + "&searchsymbol=hyLibCore.webpac.search.common_symbol&execodehidden=true&execode=&ebook=&csrfToken=D78F9B0555D0ABA2DE29EC96C7BA5389&hyftdToken=188809228&nowpage=1"
driver.get(url)
time.sleep(5)

edition = driver.find_element_by_xpath('//html/body/div[3]/div[4]/table/tbody/tr[2]/td/div[1]/div[1]/a').click()
time.sleep(2) 
table = driver.find_element_by_class_name('order')
trlist = table.find_elements_by_tag_name('tr')
for row in trlist:
    tdlist = row.find_elements_by_tag_name('td')
    for sth in tdlist:
        new_row = ['新竹縣立圖書館', tdlist[2].text, tdlist[3].text, tdlist[5].text, url]
        print('新竹縣立圖書館', tdlist[2].text, tdlist[3].text, tdlist[5].text, url)
        df_lst.append(new_row)
        break
backtolist = driver.find_element_by_xpath('//html/body/div[1]/div[2]/a[3]').click()
time.sleep(2)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-18-838f9fd55afa> in <module>
#      15
#      16
# ---> 17 edition = driver.find_element_by_xpath('//html/body/div[3]/div[4]/table/tbody/tr[2]/td/div[1]/div[1]/a').click()
#      18 time.sleep(2)
#      19 table = driver.find_element_by_class_name('order')
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
# ...
