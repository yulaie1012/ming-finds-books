# %%
# 臺中市立圖書館 可
from selenium import webdriver # 先下載 webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
import time
import pandas as pd
import requests
import requests.packages.urllib3
requests.packages.urllib3.disable_warnings()

# 設定 driver
my_options = Options()
my_options.add_argument("--incognito")  # 開啟無痕模式
# my_options.add_argument("--headless")  # 不開啟實體瀏覽器
capabilities = DesiredCapabilities.CHROME
capabilities["pageLoadStrategy"] = "none"
df_lst = []
ISBN = '986729193X'
driver = webdriver.Chrome("C:\\Users\mayda\Downloads\chromedriver")

url = "https://ipac.library.taichung.gov.tw/webpac/search.cfm?m=as&k0="+ ISBN +"&t0=i&c0=and&y10=&y20=&cat0=&dt0=&l0=&lv0=&lc0="
driver.get(url)
time.sleep(5)

href = driver.current_url
index = href.find("mid=") # 得到'm'的index整數值
id = href[index+4:index+11] # 得到七位數id
newlink = "https://ipac.library.taichung.gov.tw/webpac/content.cfm?mid=" + id + "&m=as&t0=i&c0=and&list_num=300&current_page=1&mt=&at=&sj=&py=&pr=&it=&lr=&lg=&si=1&contentlistcurrent_page=1&contentlist_num=300"
driver.get(newlink)
time.sleep(10)

try: # 有的書有不只一種版本
    version = int(len(driver.find_elements_by_class_name("list_box")))
except:
    version = 0

if version != 0:
    for i in range(2, 2+version):
        edition = driver.find_element_by_xpath('/html/body/div[4]/div[4]/div[2]/div[2]/div[2]/div[2]/div[' + str(i) + ']/div[1]/ul/li[3]/a').click()
        time.sleep(4)
        try:
            table = driver.find_element_by_class_name('list.list_border')
            trlist = table.find_elements_by_tag_name('tr')
            for row in trlist:
                tdlist = row.find_elements_by_tag_name('td')
                for sth in tdlist:
                    new_row = ["臺中市立圖書館", tdlist[1].text, tdlist[2].text, tdlist[3].text, url]
                    df_lst.append(new_row)
                    break

        except: # 有的版本點進去會顯示"無館藏資料"(困惑)
            pass

        backtolist = driver.find_element_by_link_text("回檢索結果").click()
        time.sleep(1)

else: #只有一種版本        
    table = driver.find_element_by_class_name('list.list_border')
    trlist = table.find_elements_by_tag_name('tr')
    for row in trlist:
        tdlist = row.find_elements_by_tag_name('td')
        for sth in tdlist:
            new_row = ["臺中市立圖書館", tdlist[1].text, tdlist[2].text, tdlist[3].text, url]
            df_lst.append(new_row)
            break
driver.close()
print(df_lst)

# %%
https://lib.tnml.tn.edu.tw/webpac/content.cfm?mid=842527&m=ss&k0=9789861371955&t0=k&c0=and&si=&content=&300&list_num=10&current_page=1&mt=&at=&sj=&py=&pr=&it=&lr=&lg=&si=1&content=&contentlistcurrent_page=1&contentlist_num=300
https://lib.tnml.tn.edu.tw/webpac/content.cfm?mid=842527&m=as&k0=9789861371955&t0=i&c0=and&y10=&y20=&cat0=&dt0=&l0=&lv0=&lc0=&si=&content&list_num=300&current_page=1&mt=&at=&sj=&py=&pr=&it=&lr=&lg=&si=1
#V https://lib.tnml.tn.edu.tw/webpac/content.cfm?mid=842527&m=as&k0=9789861371955&t0=i&c0=and&y10=&y20=&cat0=&dt0=&l0=&lv0=&lc0=&si=&content=&content&list_num=300&current_page=1&contentlistcurrent_page=1&contentlist_num=300
&content=&contentlistcurrent_page=1&contentlist_num=300
        href = driver.current_url
        str1 = href.find("&si=&content") # 得到第一個'&'的index整數值
        front = href[:str1+11] # 得到前半段
        newlink = front+"=&content&list_num=300&current_page=1&contentlistcurrent_page=1&contentlist_num=300"
        driver.get(newlink)
si=
https://lib.tnml.tn.edu.tw/webpac/content.cfm?mid=844370&m=ss&k0=9789573317241&t0=k&c0=and&si=&content=&300&list_num=300&current_page=1&mt=&at=&sj=&py=&pr=&it=&lr=&lg=&si=1&content=&contentlistcurrent_page=1&contentlist_num=300
https://lib.tnml.tn.edu.tw/webpac/content.cfm?mid=842527&m=ss&k0=9789861371955&t0=k&c0=and&si=&content=&300&list_num=10&current_page=1&mt=&at=&sj=&py=&pr=&it=&lr=&lg=&si=1&content=&contentlistcurrent_page=1&contentlist_num=300

# %%
# 臺南市立圖書館
from selenium import webdriver # 先下載 webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
import time
import pandas as pd
import requests
import requests.packages.urllib3
requests.packages.urllib3.disable_warnings()

# 設定 driver
my_options = Options()
my_options.add_argument("--incognito")  # 開啟無痕模式
# my_options.add_argument("--headless")  # 不開啟實體瀏覽器
capabilities = DesiredCapabilities.CHROME
capabilities["pageLoadStrategy"] = "none"
df_lst = []
ISBN = '9789861371955'
driver = webdriver.Chrome("C:\\Users\mayda\Downloads\chromedriver")

url = "https://lib.tnml.tn.edu.tw/webpac/search.cfm?m=ss&k0="+ ISBN +"&t0=k&c0=and"
driver.get(url)
time.sleep(5)

try: # 有的書有不只一種版本
    version = int(len(driver.find_elements_by_class_name("list_box")))
except:
    version = 0
if version != 0:
    for i in range(2, 2+version):
        edition = driver.find_element_by_xpath('/html/body/div[4]/div[3]/div/div[2]/div[1]/div[2]/div[' + str(i) + ']/div[1]/ul/li[3]/a').click()
        time.sleep(4)

        href = driver.current_url
        newlink = href +"&content=&contentlistcurrent_page=1&contentlist_num=300"
        driver.get(newlink)
        time.sleep(10)

        
        try:
            table = driver.find_element_by_class_name('list.list_border')
            trlist = table.find_elements_by_tag_name('tr')
            for row in trlist:
                tdlist = row.find_elements_by_tag_name('td')
                for sth in tdlist:
                    new_row = ["臺南市立圖書館", tdlist[1].text, tdlist[2].text, tdlist[3].text, url]
                    df_lst.append(new_row)
                    break
        except: # 有的版本點進去會顯示"無館藏資料"(困惑)
            pass

        backtolist = driver.find_element_by_link_text("回檢索結果").click()
        time.sleep(1)

else: #只有一種版本 
    href = driver.current_url
    newlink = href +"&content=&contentlistcurrent_page=1&contentlist_num=300"
    driver.get(newlink)
    time.sleep(10)

    table = driver.find_element_by_class_name('list.list_border')
    trlist = table.find_elements_by_tag_name('tr')
    for row in trlist:
        tdlist = row.find_elements_by_tag_name('td')
        for sth in tdlist:
            new_row = ["臺南市立圖書館", tdlist[1].text, tdlist[2].text, tdlist[3].text, url]
            df_lst.append(new_row)
            break
driver.close()
print(df_lst)
# Out:
# [['臺南市立圖書館', '典藏館', '目前所在館', '索書號', 'https://lib.tnml.tn.edu.tw/webpac/search.cfm?m=ss&k0=9789861371955&t0=k&c0=and'], ['臺南市立圖書館', '新總館3F開架閱覽區', '市圖(公園總館)24H取書站浮動館藏區', '177.3 2613 2020 c.2', 'https://lib.tnml.tn.edu.tw/webpac/search.cfm?m=ss&k0=9789861371955&t0=k&c0=and'], ['臺南市立圖書館', '新總館3F開架閱覽區', '學甲區圖書館浮動館藏區', '177.3 2613 2015 c.3', 'https://lib.tnml.tn.edu.tw/webpac/search.cfm?m=ss&k0=9789861371955&t0=k&c0=and'], ['臺南市立圖書館', '新總館3F開架閱覽區', '市圖(公園總館)浮動館藏區', '177.3 2613 2015 c.3', 'https://lib.tnml.tn.edu.tw/webpac/search.cfm?m=ss&k0=9789861371955&t0=k&c0=and'], ['臺南市立圖書館', '新總館3F開架閱覽區', '市圖(新總館)24H取書站浮動館藏區', '177.3 2613 2019', 'https://lib.tnml.tn.edu.tw/webpac/search.cfm?m=ss&k0=9789861371955&t0=k&c0=and'], ['臺南市立圖書館', '新總館3F開架閱覽區', '市圖(新總館)浮動館藏區', '177.3 2613 2019', 'https://lib.tnml.tn.edu.tw/webpac/search.cfm?m=ss&k0=9789861371955&t0=k&c0=and'], ['臺南市立圖書館', '台江文化中心開架閱覽區', '台江文化中心圖書館浮動館藏區', '177.3 2613 2019', 'https://lib.tnml.tn.edu.tw/webpac/search.cfm?m=ss&k0=9789861371955&t0=k&c0=and'], ['臺南市立圖書館', '鹽埕開架閱覽區', '市圖(公園總館)24H取書站浮動館藏區', '177.3 2613 2014 c.2', 'https://lib.tnml.tn.edu.tw/webpac/search.cfm?m=ss&k0=9789861371955&t0=k&c0=and'], ['臺南市立圖書館', '關廟青少年區', '安南區安南圖書館浮動館藏區', 'Y 177.3 8662 2014', 'https://lib.tnml.tn.edu.tw/webpac/search.cfm?m=ss&k0=9789861371955&t0=k&c0=and'], ['臺南市立圖書館', '關廟開架閱覽區', '永康區圖書館浮動館藏區', '177.3 8662 c.1', 'https://lib.tnml.tn.edu.tw/webpac/search.cfm?m=ss&k0=9789861371955&t0=k&c0=and'], ['臺南市立圖書館', '鹽水開架閱覽區', '新營文化中心圖書館3F浮動館藏區', '177.3 8662 c.1', 'https://lib.tnml.tn.edu.tw/webpac/search.cfm?m=ss&k0=9789861371955&t0=k&c0=and']]

# %%
# 臺南市立圖書館
from selenium import webdriver # 先下載 webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
import time
import pandas as pd
import requests
import requests.packages.urllib3
requests.packages.urllib3.disable_warnings()

# 設定 driver
my_options = Options()
my_options.add_argument("--incognito")  # 開啟無痕模式
# my_options.add_argument("--headless")  # 不開啟實體瀏覽器
capabilities = DesiredCapabilities.CHROME
capabilities["pageLoadStrategy"] = "none"
df_lst = []
ISBN = '9789861371955'
driver = webdriver.Chrome("C:\\Users\mayda\Downloads\chromedriver")

url = "https://lib.tnml.tn.edu.tw/webpac/search.cfm?m=ss&k0="+ ISBN +"&t0=k&c0=and"
driver.get(url)
time.sleep(5)

try: # 有的書有不只一種版本
    version = int(len(driver.find_elements_by_class_name("list_box")))
except:
    version = 0
if version != 0:
    for i in range(2, 2+version):
        edition = driver.find_element_by_xpath('/html/body/div[4]/div[3]/div/div[2]/div[1]/div[2]/div[' + str(i) + ']/div[1]/ul/li[3]/a').click()
        time.sleep(4)

        href = driver.current_url
        newlink = href+"=&content&list_num=300&current_page=1&contentlistcurrent_page=1&contentlist_num=300"
        driver.get(newlink)
        time.sleep(5)
        
        try:
            table = driver.find_element_by_class_name('list.list_border')
            trlist = table.find_elements_by_tag_name('tr')
            for row in trlist:
                tdlist = row.find_elements_by_tag_name('td')
                for sth in tdlist:
                    new_row = ["臺南市立圖書館", tdlist[1].text, tdlist[2].text, tdlist[3].text, url]
                    df_lst.append(new_row)
                    break
        except: # 有的版本點進去會顯示"無館藏資料"(困惑)
            pass

        backtolist = driver.find_element_by_link_text("回檢索結果").click()
        time.sleep(1)

else: #只有一種版本 

    href = driver.current_url
    newlink = href+"=&content&list_num=300&current_page=1&contentlistcurrent_page=1&contentlist_num=300"
    driver.get(newlink)
    time.sleep(5)

    table = driver.find_element_by_class_name('list.list_border')
    trlist = table.find_elements_by_tag_name('tr')
    for row in trlist:
        tdlist = row.find_elements_by_tag_name('td')
        for sth in tdlist:
            new_row = ["臺南市立圖書館", tdlist[1].text, tdlist[2].text, tdlist[3].text, url]
            df_lst.append(new_row)
            break
driver.close()
print(df_lst)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-1-9c66d39c1de0> in <module>
#      51             pass
#      52
# ---> 53         backtolist = driver.find_element_by_link_text("回檢索結果").click()
#      54         time.sleep(1)
#      55
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_link_text(self, link_text)
#     426             element = driver.find_element_by_link_text('Sign In')
#     427         """
# --> 428         return self.find_element(by=By.LINK_TEXT, value=link_text)
#     429
#     430     def find_elements_by_link_text(self, text):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#     978             'value': value})['value']
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"link text","selector":"回檢索結果"}
#   (Session info: chrome=91.0.4472.77)
