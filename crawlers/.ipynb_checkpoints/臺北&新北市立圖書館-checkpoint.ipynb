# %%
# 環境設置
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.keys import Keys  # 鍵盤操作
from selenium.common.exceptions import NoSuchElementException
import pandas as pd
import requests
import requests.packages.urllib3
requests.packages.urllib3.disable_warnings()
from urllib.request import HTTPError
from bs4 import BeautifulSoup
import time

ISBN = "9789573317241"
title = "哈利波特(1)：神秘的魔法石"

my_options = Options()
my_options.add_argument("--incognito")  # 開啟無痕模式
# my_options.add_argument("--headless")  # 不開啟實體瀏覽器

# %%
# 台大

url = "https://ntu.primo.exlibrisgroup.com/discovery/search?query=any,contains," + ISBN + "&tab=Everything&search_scope=MyInst_and_CI&vid=886NTU_INST:886NTU_INST&offset=0"
driver.get(url)
time.sleep(5)
title = driver.find_element_by_class_name('item-title').click()

time.sleep(3)
try:
    try:
        back = driver.find_element_by_css_selector(".tab-header .back-button.button-with-icon.zero-margin.md-button.md-primoExplore-theme.md-ink-ripple")
    except:
        back = None
    if back != None:
        back.click()
        
    thelist = driver.find_elements_by_class_name("layout-align-space-between-center.layout-row.flex-100")
    for row in thelist:
        plist = row.find_elements_by_tag_name("p")
        where = row.find_elements_by_tag_name("h3")
        i = len(where)
        for sth in plist:
            a = sth.find_elements_by_tag_name("span")
            for _ in range(i): 
                new_row = ['台灣大學', where[_].text, a[4].text, a[0].text, url]
                df_lst.append(new_row)
                break
            break
except:
    pass

driver.close()

# %%
df_lst
# Out:
# [         條碼號              典藏地名稱   館藏流通類別   資料類型                  索書號 館藏狀態  \
#  0   A0062098            淡水青少年專區  圖書可借30天  青少年資料         Y 873.57 857   在架
#  1   A0237650  汐止大同分館開架閱覽[原汐止分館]  圖書可借30天   中文圖書      873.57 857 2000   在架
#  2   A0238369  汐止大同分館開架閱覽[原汐止分館]  圖書可借30天   中文圖書  873.57 857 2000 c.2   在架
#  3   A0325256             新莊開架閱覽  圖書可借30天   中文圖書       873.57 857 c.2   在架
#  4   A0780438             林口開架閱覽  圖書可借30天   中文圖書       873.57 857 c.2   在架
#  5   A1137476         新莊頭前智圖開架閱覽  圖書可借30天   中文圖書           873.57 857   在架
#  6   A1393067     總館6樓開架閱覽[8-9類]  圖書可借30天   中文圖書           873.57 857   在架
#  7  BAB066651             五股開架閱覽  圖書可借30天   中文圖書           873.57 857   在架
#  8  BBB008528           五股成州開架閱覽  圖書可借30天   中文圖書          873.57 8666   在架
#  9  BCB014596           五股水碓開架閱覽  圖書可借30天   中文圖書       873.57 857 c.2   在架
#
#     預約人數   備註  附件  預約
#  0     0   3F NaN  預約
#  1     0  NaN NaN  預約
#  2     0  NaN NaN  預約
#  3     0  NaN NaN  預約
#  4     0  NaN NaN  預約
#  5     0  NaN NaN  預約
#  6     0  NaN NaN  預約
#  7     0  NaN NaN  預約
#  8     0  NaN NaN  預約
#  9     0  NaN NaN  預約  ,
#           條碼號     典藏地名稱   館藏流通類別  資料類型                  索書號 館藏狀態  預約人數  備註  附件  \
#  0  BCB027945  五股水碓開架閱覽  圖書可借30天  中文圖書           873.57 857   在架     0 NaN NaN
#  1  BDB011560  五股更新開架閱覽  圖書可借30天  中文圖書           873.57 857   在架     0 NaN NaN
#  2  BEB013527  五股成功開架閱覽  圖書可借30天  中文圖書           873.57 857   在架     0 NaN NaN
#  3  BEB013621  五股成功開架閱覽  圖書可借30天  中文圖書           873.57 857   在架     0 NaN NaN
#  4  CAB037256    三峽開架閱覽  圖書可借30天  中文圖書       873.57 857 c.4   在架     0 NaN NaN
#  5  CAB041958    三峽開架閱覽  圖書可借30天  中文圖書       873.57 857 c.5   在架     0 NaN NaN
#  6  DAB058388    三芝開架閱覽  圖書可借30天  中文圖書      873.57 8666 c.2   在架     0 NaN NaN
#  7  EBB009520  鶯歌二甲開架閱覽  圖書可借30天  中文圖書   873.57 857 2007.11   在架     0 NaN NaN
#  8  EBB010497  鶯歌二甲開架閱覽  圖書可借30天  中文圖書  873.57 857 V.1 2001   在架     0 NaN NaN
#  9  FAB048381    永和開架閱覽  圖書可借30天  中文圖書       873.57 857 c.2   在架     0 NaN NaN
#
#     預約
#  0  預約
#  1  預約
#  2  預約
#  3  預約
#  4  預約
#  5  預約
#  6  預約
#  7  預約
#  8  預約
#  9  預約  ,
#           條碼號     典藏地名稱   館藏流通類別  資料類型             索書號 館藏狀態  預約人數  備註  附件  預約
#  0  FAB048382    永和開架閱覽  圖書可借30天  中文圖書      873.57 857   在架     0 NaN NaN  預約
#  1  FAB102381    永和開架閱覽  圖書可借30天  中文圖書      873.57 857   在架     0 NaN NaN  預約
#  2  FCB019383  永和民權開架閱覽  圖書可借30天  中文圖書      873.57 857   在架     0 NaN NaN  預約
#  3  FCB050707  永和民權開架閱覽  圖書可借30天  中文圖書      873.57 857   在架     0 NaN NaN  預約
#  4  FCB069537  永和民權開架閱覽  圖書可借30天  中文圖書      873.57 857   在架     0 NaN NaN  預約
#  5  FCB069539  永和民權開架閱覽  圖書可借30天  中文圖書      873.57 857   在架     0 NaN NaN  預約
#  6  FDB001768  永和忠孝開架閱覽  圖書可借30天  中文圖書      873.57 857   在架     0 NaN NaN  預約
#  7  FDB002709  永和忠孝開架閱覽  圖書可借30天  中文圖書  873.57 857 c.2   在架     0 NaN NaN  預約
#  8  GAB100720    林口套書專區  圖書可借30天  中文圖書      873.57 857   在架     0 NaN NaN  預約
#  9  HFB032501  三重南區開架閱覽  圖書可借30天  中文圖書      873.57 857   在架     0 NaN NaN  預約,
#           條碼號     典藏地名稱   館藏流通類別  資料類型             索書號 館藏狀態  預約人數  備註  附件  預約
#  0  IAB028931  新莊福營開架閱覽  圖書可借30天  中文圖書      873.57 857   在架     0 NaN NaN  預約
#  1  IAB067086  新莊福營開架閱覽  圖書可借30天  中文圖書  873.57 857 c.2   在架     0 NaN NaN  預約
#  2  IAB067979  新莊福營開架閱覽  圖書可借30天  中文圖書      873.57 857   在架     0 NaN NaN  預約
#  3  IAB070811  新莊福營開架閱覽  圖書可借30天  中文圖書      873.57 857   在架     0 NaN NaN  預約
#  4  ICB038985  新莊中港開架閱覽  圖書可借30天  中文圖書  873.57 857 c.3   在架     0 NaN NaN  預約
#  5  ICB072856  新莊中港開架閱覽  圖書可借30天  中文圖書      873.57 857   在架     0 NaN NaN  預約
#  6  JDB006560  土城祖田開架閱覽  圖書可借30天  中文圖書     873.57 8666   在架     0 NaN NaN  預約
#  7  JEB013351  土城親子開架閱覽  圖書可借30天  中文圖書      873.57 857   在架     0 NaN NaN  預約
#  8  KBB036795  蘆洲集賢開架閱覽  圖書可借30天  中文圖書      873.57 857   在架     0 NaN NaN  預約
#  9  KEB035478  蘆洲集賢開架閱覽  圖書可借30天  中文圖書      873.57 857   在架     0 NaN NaN  預約,
#           條碼號     典藏地名稱   館藏流通類別  資料類型             索書號 館藏狀態  預約人數   備註  附件  預約
#  0  LAB027137    泰山開架閱覽  圖書可借30天  中文圖書  873.57 857 c.2   在架     0  獨28 NaN  預約
#  1  MAB020730    平溪開架閱覽  圖書可借30天  中文圖書     873.57 8666   在架     0  NaN NaN  預約
#  2  NAB036398    樹林開架閱覽  圖書可借30天  中文圖書  873.57 857 v.1   在架     0  NaN NaN  預約
#  3  NAB056509    樹林開架閱覽  圖書可借30天  中文圖書  873.57 857 v.1   在架     0  NaN NaN  預約
#  4  NBB005563  樹林大安開架閱覽  圖書可借30天  中文圖書      873.57 857   在架     0  NaN NaN  預約
#  5  NDB005447  樹林三多開架閱覽  圖書可借30天  中文圖書  873.57 857 c.2   在架     0  NaN NaN  預約
#  6  NEB008588  樹林大安開架閱覽  圖書可借30天  中文圖書  873.57 857 c.2   在架     0  NaN NaN  預約
#  7  NFB005119    樹林開架閱覽  圖書可借30天  中文圖書      873.57 857   在架     0  NaN NaN  預約
#  8  OAB035881  中和員山開架閱覽  圖書可借30天  中文圖書  873.57 857 民96   在架     0  NaN NaN  預約
#  9  OCB040385    中和開架閱覽  圖書可借30天  中文圖書      873.57 857   在架     0  NaN NaN  預約,
#           條碼號       典藏地名稱   館藏流通類別   資料類型                   索書號 館藏狀態  預約人數  \
#  0  OCB045483      中和開架閱覽  圖書可借30天   中文圖書        873.57 857 c.2   在架     0
#  1  PAB011937      八里開架閱覽  圖書可借30天   中文圖書            873.57 857   在架     0
#  2  QAB501807  青少年圖書館開架閱覽  圖書可借30天   中文圖書            873.57 857   在架     0
#  3  QAB501810  青少年圖書館開架閱覽  圖書可借30天   中文圖書        873.57 857 c.5   在架     0
#  4  QBB032097    新店寶興開架閱覽  圖書可借30天   中文圖書            873.57 857   在架     0
#  5  QDB008291    新店中央開架閱覽  圖書可借30天   中文圖書            873.57 857   在架     0
#  6  QJB005489    新店仁愛開架閱覽  圖書可借30天   中文圖書  873.57 8666 V.2 2000   在架     0
#  7  QKB006972    新店柴埕開架閱覽  圖書可借30天   中文圖書            873.57 857   在架     0
#  8  RAB033958      深坑開架閱覽  圖書可借30天  青少年資料     Y 873.57 6014 c.2   在架     0
#  9  RAB038896      深坑開架閱覽  圖書可借30天  青少年資料          Y 873.57 857   在架     0
#
#      備註  附件  預約
#  0  NaN NaN  預約
#  1  NaN NaN  預約
#  2    N NaN  預約
#  3  NaN NaN  預約
#  4  NaN NaN  預約
#  5  NaN NaN  預約
#  6  NaN NaN  預約
#  7  NaN NaN  預約
#  8  NaN NaN  預約
#  9  NaN NaN  預約  ,
#           條碼號     典藏地名稱   館藏流通類別  資料類型             索書號 館藏狀態  預約人數     備註  附件  \
#  0  SAB022568    石碇開架閱覽  圖書可借30天  中文圖書      873.59 857   在架     0  158.0 NaN
#  1  TAB053239    板橋開架閱覽  圖書可借30天  中文圖書  873.57 857 c.5   在架     0    NaN NaN
#  2  TAB059669    板橋開架閱覽  圖書可借30天  中文圖書      873.57 857   在架     0    NaN NaN
#  3  TDB013799  板橋國光開架閱覽  圖書可借30天  中文圖書      873.57 857   在架     0    NaN NaN
#  4  TEB032871  板橋四維開架閱覽  圖書可借30天  中文圖書      873.57 857   在架     0    NaN NaN
#  5  TGB018228  板橋忠孝開架閱覽  圖書可借30天  中文圖書      873.57 857   在架     0    1.0 NaN
#  6  THB007350  板橋溪北開架閱覽  圖書可借30天  中文圖書  873.57 857 c.2   在架     0    NaN NaN
#  7  THB013525  板橋溪北開架閱覽  圖書可借30天  中文圖書      873.57 857   在架     0    NaN NaN
#  8  THB022478  板橋溪北開架閱覽  圖書可借30天  中文圖書      873.57 857   在架     0    NaN NaN
#  9  TIB006009  板橋浮洲開架閱覽  圖書可借30天  中文圖書      873.57 857   在架     0    NaN NaN
#
#     預約
#  0  預約
#  1  預約
#  2  預約
#  3  預約
#  4  預約
#  5  預約
#  6  預約
#  7  預約
#  8  預約
#  9  預約  ,
#           條碼號     典藏地名稱   館藏流通類別   資料類型                 索書號 館藏狀態  預約人數   備註  \
#  0  TIB016062  板橋浮洲開架閱覽  圖書可借30天   中文圖書  873.57 857 2001/02   在架     0  NaN
#  1  UAB054330   淡水青少年專區  圖書可借30天  青少年資料    Y 873.57 857 c.4   在架     0   3F
#  2  UBB007484  淡水竹圍開架閱覽  圖書可借30天   中文圖書          873.57 857   在架     0  NaN
#  3  UBB012287  淡水竹圍開架閱覽  圖書可借30天   中文圖書      873.57 857 c.2   在架     0  NaN
#  4  WAB028175    金山開架閱覽  圖書可借30天   中文圖書          873.57 857   在架     0  NaN
#  5  XAB020578    雙溪開架閱覽  圖書可借30天   中文圖書          873.57 857   在架     0  NaN
#  6  YCB000320  汐止北峰開架閱覽  圖書可借30天   中文圖書      873.57 857 c.2   在架     0  NaN
#  7  YCB007075  汐止北峰開架閱覽  圖書可借30天   中文圖書          873.57 857   在架     0  NaN
#  8  YDB013475  汐止茄苳開架閱覽  圖書可借30天   中文圖書      873.57 857 c.2   在架     0  NaN
#  9  ZAB048223    萬里開架閱覽  圖書可借30天   中文圖書          873.57 857   在架     0  NaN
#
#     附件  預約
#  0 NaN  預約
#  1 NaN  預約
#  2 NaN  預約
#  3 NaN  預約
#  4 NaN  預約
#  5 NaN  預約
#  6 NaN  預約
#  7 NaN  預約
#  8 NaN  預約
#  9 NaN  預約  ,
#           條碼號       典藏地名稱   館藏流通類別   資料類型             索書號              館藏狀態  \
#  0  ZBB025025      坪林開架閱覽  圖書可借30天   中文圖書      873.57 857                在架
#  1  ZDB017724      貢寮開架閱覽  圖書可借30天   中文圖書  873.57 857 c.2                在架
#  2   A0228711      林口套書專區  圖書可借30天   中文圖書  873.57 857 c.5  借出  : 2020/02/14
#  3   A0268322    新莊聯合開架閱覽  圖書可借30天   中文圖書      873.57 857  借出  : 2021/04/12
#  4   A0325022      新莊開架閱覽  圖書可借30天   中文圖書      873.57 857  借出  : 2021/08/01
#  5   A0343596    三重培德開架閱覽  圖書可借30天   中文圖書      873.57 857  借出  : 2021/08/01
#  6   A0770023    新莊西盛開架閱覽  圖書可借30天   中文圖書     873.57 8666  借出  : 2021/04/28
#  7   A0980600      林口套書專區  圖書可借30天   中文圖書  873.57 857 c.6  借出  : 2021/08/01
#  8   A1045635      三峽開架閱覽  圖書可借30天   中文圖書  873.57 857 c.7  借出  : 2021/08/01
#  9   A1137467  蘆洲仁愛智圖開架閱覽  圖書可借30天  青少年資料    Y 873.57 857  借出  : 2020/02/02
#
#     預約人數  備註  附件  預約
#  0     0 NaN NaN  預約
#  1     0 NaN NaN  預約
#  2     0 NaN NaN  預約
#  3     0 NaN NaN  預約
#  4     0 NaN NaN  預約
#  5     0 NaN NaN  預約
#  6     0 NaN NaN  預約
#  7     0 NaN NaN  預約
#  8     0 NaN NaN  預約
#  9     0 NaN NaN  預約  ,
#          條碼號           典藏地名稱   館藏流通類別  資料類型              索書號              館藏狀態  \
#  0  A1267044          林口套書專區  圖書可借30天  中文圖書   873.57 857 c.4  借出  : 2021/08/01
#  1  A1393003  總館6樓開架閱覽[8-9類]  圖書可借30天  中文圖書   873.57 857 c.5  借出  : 2021/08/01
#  2  A1620249        三峽北大開架閱覽  圖書可借30天  中文圖書   873.57 857 c.3  借出  : 2021/08/01
#  3  A1620796        三峽北大開架閱覽  圖書可借30天  中文圖書   873.57 857 c.3  借出  : 2021/08/01
#  4  A2031467        板橋四維開架閱覽  圖書可借30天  中文圖書       873.57 857  借出  : 2021/08/01
#  5  A2089108        三峽北大開架閱覽  圖書可借30天  中文圖書       873.57 857  借出  : 2018/12/05
#  6  A2492319        林口西林開架閱覽  圖書可借30天  中文圖書       857.57 857  借出  : 2021/08/01
#  7  A2569644        三峽北大開架閱覽  圖書可借30天  中文圖書       873.57 857  借出  : 2021/08/01
#  8   B265307  總館6樓開架閱覽[8-9類]  圖書可借30天  中文圖書       873.57 857  借出  : 2021/08/01
#  9   B295421  總館6樓開架閱覽[8-9類]  圖書可借30天  中文圖書  873.57 857 c.11  借出  : 2021/08/01
#
#     預約人數  備註  附件  預約
#  0     0 NaN NaN  預約
#  1     0 NaN NaN  預約
#  2     1 NaN NaN  預約
#  3     0 NaN NaN  預約
#  4     0 NaN NaN  預約
#  5     0 NaN NaN  預約
#  6     0 NaN NaN  預約
#  7     0 NaN NaN  預約
#  8     0 NaN NaN  預約
#  9     0 NaN NaN  預約  ,
#           條碼號     典藏地名稱   館藏流通類別  資料類型             索書號              館藏狀態  預約人數  \
#  0  BBB017498  五股成功開架閱覽  圖書可借30天  中文圖書  873.57 857 c.2  借出  : 2021/08/01     0
#  1  BBB017771  五股成州開架閱覽  圖書可借30天  中文圖書     873.57 8666  借出  : 2021/04/28     0
#  2  CAB032098    三峽開架閱覽  圖書可借30天  中文圖書  873.57 857 c.2  借出  : 2018/05/01     0
#  3  CAB070856    三峽開架閱覽  圖書可借30天  中文圖書  873.57 857 c.6  借出  : 2021/08/01     0
#  4  EAB025310    鶯歌開架閱覽  圖書可借30天  中文圖書      873.57 857  借出  : 2020/07/26     0
#  5  EAB035335    鶯歌開架閱覽  圖書可借30天  中文圖書  873.57 857 C.2  借出  : 2021/08/01     0
#  6  FAB047486    永和開架閱覽  圖書可借30天  中文圖書      873.57 857  借出  : 2021/08/01     0
#  7  FBB004925  永和親子開架閱覽  圖書可借30天  中文圖書      873.57 857  借出  : 2021/08/01     0
#  8  FCB002684  永和民權開架閱覽  圖書可借30天  中文圖書      873.57 857  借出  : 2021/08/01     0
#  9  FCB040961  永和民權開架閱覽  圖書可借30天  中文圖書      873.57 857  借出  : 2021/08/01     0
#
#     備註  附件  預約
#  0 NaN NaN  預約
#  1 NaN NaN  預約
#  2 NaN NaN  預約
#  3 NaN NaN  預約
#  4 NaN NaN  預約
#  5 NaN NaN  預約
#  6 NaN NaN  預約
#  7 NaN NaN  預約
#  8 NaN NaN  預約
#  9 NaN NaN  預約  ,
#           條碼號     典藏地名稱   館藏流通類別  資料類型             索書號              館藏狀態  預約人數  \
#  0  FCB069548  永和民權開架閱覽  圖書可借30天  中文圖書      873.57 857  借出  : 2021/08/01     0
#  1  FEB000107  永和保生開架閱覽  圖書可借30天  中文圖書      873.57 857  借出  : 2021/08/01     0
#  2  HAB100455    三重開架閱覽  圖書可借30天  中文圖書      873.57 857  借出  : 2021/08/01     0
#  3  HAB119732    三重開架閱覽  圖書可借30天  中文圖書      873.57 857  借出  : 2021/08/01     0
#  4  HAB162876    三重開架閱覽  圖書可借30天  中文圖書      873.57 857  借出  : 2021/08/01     0
#  5  HEB016162  三重東區開架閱覽  圖書可借30天  中文圖書  873.57 857 c.2  借出  : 2021/08/01     0
#  6  HFB003381  三重南區開架閱覽  圖書可借30天  中文圖書  873.57 857 民94  借出  : 2021/08/01     0
#  7  HFB032500  三重南區開架閱覽  圖書可借30天  中文圖書      873.57 857  借出  : 2021/08/01     0
#  8  ICB009446  新莊中港開架閱覽  圖書可借30天  中文圖書  873.57 857 c.2  借出  : 2021/08/01     0
#  9  KAB034587  蘆洲長安開架閱覽  圖書可借30天  中文圖書  873.57 857 v.1  借出  : 2021/04/16     1
#
#     備註  附件  預約
#  0 NaN NaN  預約
#  1 NaN NaN  預約
#  2 NaN NaN  預約
#  3 NaN NaN  預約
#  4 NaN NaN  預約
#  5 NaN NaN  預約
#  6 NaN NaN  預約
#  7 NaN NaN  預約
#  8 NaN NaN  預約
#  9 NaN NaN  預約  ,
#           條碼號           典藏地名稱   館藏流通類別  資料類型             索書號              館藏狀態  \
#  0  KCB027912        蘆洲永平開架閱覽  圖書可借30天  中文圖書      873.57 857  借出  : 2021/08/01
#  1  KEB031077        蘆洲集賢開架閱覽  圖書可借30天  中文圖書      873.57 857  借出  : 2021/08/01
#  2  LAB045207          泰山開架閱覽  圖書可借30天  中文圖書      873.57 857  借出  : 2021/02/20
#  3  LBB008685        泰山貴子開架閱覽  圖書可借30天  中文圖書      873.57 857  借出  : 2021/08/01
#  4  LBB011224        泰山貴子開架閱覽  圖書可借30天  中文圖書  873.57 857 c.2  借出  : 2021/08/01
#  5  MAB032529        新莊裕民開架閱覽  圖書可借30天  中文圖書      873.57 857  借出  : 2021/04/02
#  6  NEB002712  總館6樓開架閱覽[8-9類]  圖書可借30天  中文圖書      873.57 857  借出  : 2021/08/01
#  7  OAB007096        中和員山開架閱覽  圖書可借30天  中文圖書      873.57 857  借出  : 2021/04/07
#  8  OBB100296        中和大同開架閱覽  圖書可借30天  中文圖書      873.57 857  借出  : 2021/08/01
#  9  OCB041954          中和開架閱覽  圖書可借30天  中文圖書      873.57 857  借出  : 2021/08/01
#
#     預約人數   備註  附件  預約
#  0     0  NaN NaN  預約
#  1     0  NaN NaN  預約
#  2     0  獨28 NaN  預約
#  3     0  NaN NaN  預約
#  4     0  NaN NaN  預約
#  5     1  NaN NaN  預約
#  6     0  NaN NaN  預約
#  7     0  NaN NaN  預約
#  8     0  NaN NaN  預約
#  9     0  NaN NaN  預約  ,
#           條碼號           典藏地名稱   館藏流通類別  資料類型              索書號  \
#  0  PAB031159          八里開架閱覽  圖書可借30天  中文圖書   873.57 857 c.2
#  1  QAB054054          新店開架閱覽  圖書可借30天  中文圖書   873.57 857 c.4
#  2  QAB502548      青少年圖書館開架閱覽  圖書可借30天  中文圖書   873.57 857 c.6
#  3  QEB013520        新店碧潭開架閱覽  圖書可借30天  中文圖書       873.57 857
#  4  QNB004021        新店龜山開架閱覽  圖書可借30天  中文圖書       873.57 857
#  5  TEB011079        板橋四維開架閱覽  圖書可借30天  中文圖書       873.57 857
#  6  TFB022626        板橋民生開架閱覽  圖書可借30天  中文圖書       873.57 857
#  7  YHB011150  總館6樓開架閱覽[8-9類]  圖書可借30天  中文圖書  873.57 857 c.10
#  8  ZDB020246          貢寮開架閱覽  圖書可借30天  中文圖書       873.57 857
#  9  ZFB006201  總館6樓開架閱覽[8-9類]  圖書可借30天  中文圖書   873.57 857 c.9
#
#                 館藏狀態  預約人數  備註  附件  預約
#  0  借出  : 2021/08/01     0 NaN NaN  預約
#  1  借出  : 2021/04/28     0 NaN NaN  預約
#  2  借出  : 2021/08/01     0 NaN NaN  預約
#  3  借出  : 2021/08/01     0 NaN NaN  預約
#  4  借出  : 2021/08/01     0 NaN NaN  預約
#  5  借出  : 2021/04/28     0 NaN NaN  預約
#  6  借出  : 2021/08/01     0 NaN NaN  預約
#  7  借出  : 2021/08/01     0 NaN NaN  預約
#  8  借出  : 2021/08/01     0 NaN NaN  預約
#  9  借出  : 2021/08/01     0 NaN NaN  預約  ,
#           條碼號      典藏地名稱   館藏流通類別   資料類型               索書號  館藏狀態  預約人數   備註  \
#  0   A0305809   新店三民開架閱覽  圖書可借30天   中文圖書        873.57 857  預約保留     0  NaN
#  1   A1002387    淡水青少年專區  圖書可借30天  青少年資料  Y 873.57 857 c.3  預約保留     0   3F
#  2  JCB017134  土城柑林埤開架閱覽  圖書可借30天   中文圖書   873.57 8666 c.2  預約保留     0  NaN
#  3  KCB000358   蘆洲永平開架閱覽  圖書可借30天   中文圖書        873.57 857  預約保留     0  NaN
#  4  KDB000552   蘆洲永安開架閱覽  圖書可借30天   中文圖書        873.57 857  預約保留     0  NaN
#  5  HAB064265     三重開架閱覽  圖書可借30天   中文圖書        873.57 857  遺失處理     0  NaN
#  6  TDB004352   板橋國光開架閱覽  圖書可借30天   中文圖書        873.57 857  遺失處理     0  NaN
#  7  TGB018112   板橋忠孝開架閱覽  圖書可借30天   中文圖書        873.57 857  遺失處理     0    1
#  8  ZDB015460     貢寮開架閱覽  圖書可借30天   中文圖書    873.57 857 c.3  遺失處理     0  NaN
#  9  FAB073851     永和開架閱覽  圖書可借30天   中文圖書        873.57 857  盤點未到     0  NaN
#
#     附件  預約
#  0 NaN  預約
#  1 NaN  預約
#  2 NaN  預約
#  3 NaN  預約
#  4 NaN  預約
#  5 NaN  預約
#  6 NaN  預約
#  7 NaN  預約
#  8 NaN  預約
#  9 NaN  預約  ,
#           條碼號        典藏地名稱   館藏流通類別   資料類型               索書號       館藏狀態  預約人數  \
#  0  HFB011320     三重南區開架閱覽  圖書可借30天   中文圖書        873.57 857       盤點未到     0
#  1  OCB013534       中和開架閱覽  圖書可借30天   中文圖書        873.57 857       盤點未到     0
#  2  VAB010160       石門開架閱覽  圖書可借30天   中文圖書        873.57 857       盤點未到     0
#  3   A0070549       深坑開架閱覽  圖書可借30天  青少年資料      Y 873.57 857   等待送回原館藏地     0
#  4    B317402  板橋江子翠分館開架閱覽  圖書可借30天   中文圖書        873.57 857   等待送回原館藏地     0
#  5  FAB048949       永和開架閱覽  圖書可借30天   中文圖書        873.57 857   等待送回原館藏地     0
#  6  UAB008349      淡水青少年專區  圖書可借30天  青少年資料  Y 873.57 857 c.2   等待送回原館藏地     0
#  7  YEB018972     汐止江北開架閱覽  圖書可借30天   中文圖書        873.57 857   等待送回原館藏地     0
#  8   A0036554     五股成功開架閱覽  圖書可借30天   中文圖書        873.57 857  等待轉送其他館藏地     0
#  9   A0080491     新店百忍開架閱覽  圖書可借30天   中文圖書    873.57 857 c.2  等待轉送其他館藏地     0
#
#      備註  附件  預約
#  0  NaN NaN  預約
#  1  NaN NaN  預約
#  2  NaN NaN  預約
#  3  NaN NaN  預約
#  4  NaN NaN  預約
#  5  NaN NaN  預約
#  6   3F NaN  預約
#  7  NaN NaN  預約
#  8  NaN NaN  預約
#  9  NaN NaN  預約  ,
#           條碼號        典藏地名稱   館藏流通類別  資料類型             索書號                館藏狀態  \
#  0   A0405461     三重培德開架閱覽  圖書可借30天  中文圖書  873.57 857 c.2           等待轉送其他館藏地
#  1  CAB032097       三峽開架閱覽  圖書可借30天  中文圖書      873.57 857           等待轉送其他館藏地
#  2  CAB036723       三峽開架閱覽  圖書可借30天  中文圖書  873.57 857 c.3           等待轉送其他館藏地
#  3  HBB040401     三重田中開架閱覽  圖書可借30天  中文圖書  873.57 857 c.2           等待轉送其他館藏地
#  4  NCB001882     三峽北大開架閱覽  圖書可借30天  中文圖書      873.57 857           等待轉送其他館藏地
#  5  QFB031828     三峽北大開架閱覽  圖書可借30天  中文圖書  873.57 857 c.2           等待轉送其他館藏地
#  6    B265305  板橋江子翠分館開架閱覽  圖書可借30天  中文圖書  873.57 857 c.2               跨館轉送中
#  7  JBB030890     土城清水開架閱覽  圖書可借30天  中文圖書     873.57 8666  久借未還  : 2012/11/30
#  8  JBB041412     土城清水開架閱覽  圖書可借30天  中文圖書     873.57 8666  久借未還  : 2012/11/30
#  9  HAB085575       三重開架閱覽  圖書可借30天  中文圖書      873.57 857                 D破損
#
#     預約人數  備註  附件  預約
#  0     0 NaN NaN  預約
#  1     0 NaN NaN  預約
#  2     0 NaN NaN  預約
#  3     0 NaN NaN  預約
#  4     0 NaN NaN  預約
#  5     0 NaN NaN  預約
#  6     0 NaN NaN  預約
#  7     0 NaN NaN  預約
#  8     0 NaN NaN  預約
#  9     0 NaN NaN  預約  ,
#           條碼號     典藏地名稱   館藏流通類別  資料類型              索書號         館藏狀態  預約人數  備註  \
#  0  HAB051028    三重開架閱覽  圖書可借30天  中文圖書   873.57 857 c.2  M圖書掛失(開架遺失)     0 NaN
#  1  HCB036722  三重五常罕用書庫  圖書可借30天  中文圖書    873.57 857 1櫃  M圖書掛失(開架遺失)     0 NaN
#  2  JBB017980  土城清水開架閱覽  圖書可借30天  中文圖書  873.57 8666 c.2  M圖書掛失(開架遺失)     0 NaN
#
#     附件  預約
#  0 NaN  預約
#  1 NaN  預約
#  2 NaN  預約  ,
#  ['台灣大學',
#   '總圖書館',
#   '873.57 6014H 4220',
#   '有可用館藏',
#   'https://ntu.primo.exlibrisgroup.com/discovery/search?query=any,contains,9789573317241&tab=Everything&search_scope=MyInst_and_CI&vid=886NTU_INST:886NTU_INST&offset=0']]

# %%
# 臺北市立圖書館
# 進入《臺北市立圖書館》館藏系統
driver = webdriver.Chrome(options=my_options)
url = "https://book.tpml.edu.tw/webpac/webpacIndex.jsp"
driver.get(url)

# 定位選擇欄，以 ISBN 搜尋方式搜尋
select = Select(driver.find_element_by_name("search_field"))
select.select_by_visible_text(u"ISBN")
search_input = driver.find_element_by_name("search_input")
search_input.send_keys(ISBN)
search_input.submit()

# %%
# 取得當前網頁的 html 進行解析，以取得 DataFrame
html_text = driver.page_source

# %%
dfs = pd.read_html(html_text, encoding="utf-8")
tgt2 = dfs[19]
tgt2

# 清理資料
# tgt2["索書號"] = tgt2["索書號"].fillna(method="ffill", axis=0) + " " + tgt2["編號"].apply(str)
# tgt2.drop(["編號", "館藏類型", "註記"], axis=1, inplace=True)
# tgt2.rename(columns={
#     "典藏館": "館藏地",
#     "館藏位置(到期日期僅為期限，不代表上架日期)": "館藏狀態"
# }, inplace=True)
# tgt2.insert(0, "圖書館", ["臺北市立圖書館" for i in range(tgt2.shape[0])])
# Out:
#                        典藏館          索書號  編號 館藏類型 館藏位置(到期日期僅為期限，不代表上架日期)   註記
# 0           A11松山(館藏特色:攝影)  873.57 6014   1   書刊                    兒童室  NaN
# 1           A11松山(館藏特色:攝影)          NaN   2   書刊                    兒童室  NaN
# 2           A11松山(館藏特色:攝影)          NaN   3   書刊                    兒童室  NaN
# 3         A12民生(館藏特色:親職教育)  873.57 6014   1   書刊                    兒童室  NaN
# 4         A12民生(館藏特色:親職教育)          NaN   2   書刊                  預約待借中  NaN
# ..                     ...          ...  ..  ...                    ...  ...
# 144         L14清江(館藏特色:體育)          NaN   4   書刊                    待修補  NaN
# 145         L14清江(館藏特色:體育)          NaN   5   書刊      已借出/到期:2021-08-15  NaN
# 146         L15吉利(特色館藏:動物)  873.57 6014   1   書刊      已借出/到期:2021-08-15  NaN
# 147                  L21永明  873.57 6014   1   書刊                  預約待借中  NaN
# 148  L23秀山(代理稻香、關渡宮預約取書服務)  873.57 6014   1   書刊                    兒童室  NaN
#
# [149 rows x 6 columns]

# %%
# 新北市立圖書館
# 進入《新北市立圖書館》館藏系統
driver = webdriver.Chrome(options=my_options)
url = "https://webpac.tphcc.gov.tw/webpac/search.cfm"
driver.get(url)

# 進階搜尋，以 ISBN 搜尋方式搜尋
driver.find_element_by_xpath('//*[@id="change_adv"]').click()
select = Select(driver.find_element_by_name("as_type"))
select.select_by_visible_text(u"ISBN/ISSN")
search_input = driver.find_element_by_name("as_keyword")
search_input.send_keys(ISBN)
# search_input.submit()  # 不知道為什麼無法 submit()？
search_input.send_keys(Keys.ENTER)  # 改使用鍵盤控制，按下「ENTER」鍵

# 進入詳細書目
time.sleep(1)
driver.find_element_by_xpath('//*[@id="autolink"]/h3').click()

# 選擇書目排序方式：館藏狀態(由小到大)
time.sleep(1)
select = Select(driver.find_element_by_name("sort"))
select.select_by_visible_text(u"館藏狀態(由小到大)")

# %%
# 確定搜尋結果的頁數，跑迴圈用
num_of_pages = driver.find_element_by_xpath('//*[@id="wrap"]/div[3]/div/div[2]/div[5]/div/div[6]/div/span').text\
.replace("1 - ", "")\
.replace("頁，跳頁至", "")
num_of_pages
# Out:
# '18'

# %%
df_lst = []
for pagination in range(1, int(num_of_pages) + 1):
    go_page = driver.find_element_by_name('page')
    go_page.send_keys(pagination)
    go_page.send_keys(Keys.ENTER)
    time.sleep(1)
    
    html_text = driver.page_source
    dfs = pd.read_html(html_text, encoding="utf-8")
    df_lst.append(dfs[0])

# %%
# tgt1 = pd.concat(df_lst, axis=0, ignore_index=True)
# tgt1.drop(["條碼號", "館藏流通類別", "資料類型", "預約人數", "備註", "附件", "預約"], axis=1, inplace=True)
# tgt1.rename(columns={
#     "典藏地名稱": "館藏地"
# }, inplace=True)
# tgt1.insert(0, "圖書館", ["新北市立圖書館" for i in range(tgt1.shape[0])])

# %%
# all-in-one
df_final = pd.concat([tgt1], axis=0, ignore_index=True)
df_final
# Out:
#          圖書館                館藏地                  索書號                館藏狀態
# 0    新北市立圖書館            淡水青少年專區         Y 873.57 857                  在架
# 1    新北市立圖書館  汐止大同分館開架閱覽[原汐止分館]      873.57 857 2000                  在架
# 2    新北市立圖書館  汐止大同分館開架閱覽[原汐止分館]  873.57 857 2000 c.2                  在架
# 3    新北市立圖書館             新莊開架閱覽       873.57 857 c.2                  在架
# 4    新北市立圖書館             林口開架閱覽       873.57 857 c.2                  在架
# ..       ...                ...                  ...                 ...
# 168  新北市立圖書館           土城清水開架閱覽          873.57 8666  久借未還  : 2012/11/30
# 169  新北市立圖書館             三重開架閱覽           873.57 857                 D破損
# 170  新北市立圖書館             三重開架閱覽       873.57 857 c.2         M圖書掛失(開架遺失)
# 171  新北市立圖書館           三重五常罕用書庫        873.57 857 1櫃         M圖書掛失(開架遺失)
# 172  新北市立圖書館           土城清水開架閱覽      873.57 8666 c.2         M圖書掛失(開架遺失)
#
# [173 rows x 4 columns]

# %%
df_final["館藏地"] = df_final["館藏地"].str.replace("栅", "柵")

# %%
# 輸出成 csv 格式
df_final.to_csv(f"《{title}》的搜尋結果.csv", encoding="big5", index=True, errors="strict")

# %%
# 輸出成 excel
abc = df_final.to_excel(f"《{title}》的搜尋結果.xlsx", encoding="big5", index=True)
