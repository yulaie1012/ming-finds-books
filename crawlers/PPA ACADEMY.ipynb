# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup

# %%
my_options = Options()
my_options.add_argument("--incognito")  # 開啟無痕模式

# %%
driver = webdriver.Chrome(options=my_options)

# %%
url = "https://www.pressplay.cc/project/vippPage/%E8%B6%85%E6%95%88%E7%8E%87%E5%AD%B8%E7%BF%92%E6%B3%95~/1CF3FF61991002F515CA07912A42D972"
driver.get(url)

# %%
html_text = driver.page_source

# %%
soup = BeautifulSoup(html_text, "html.parser")

# %%
for h3 in soup.find_all("h3", {"dir": "ltr"}):
    print(h3.text)
# Out:
# 不自覺樂在其中，才是學習的最高境界
# 面對大量知識與資訊，該如何吸收和整理？
# 讓輸出成為最好的輸入
# 對抗懶惰，讓你產生學習動力

# %%
soup
# Out:
# <html><head> <title>超效率學習法 - PressPlay Academy 訂閱學習｜線上課程平台</title> <meta content="text/html; charset=utf-8" http-equiv="content-type"/> <meta content="IE=edge" http-equiv="X-UA-Compatible"/> <meta content="啾啾鞋" name="author"/> <meta content=" 啾音好書-超效率學習法不自覺樂在其中，才是學習的最高境界你想要開始學習新事物，卻找不到方法嗎？你每天都覺得時間不夠，拼命學習，但是總是半途而廢，就像無頭蒼蠅一樣，越學越差嗎？哈囉大家好，歡迎來到《啾音好書》，我是啾啾鞋！今天要和大家介紹的" name="description"/> <meta content="超效率學習法， " name="keywords"/> <meta content="width=device-width, initial-scale=1, shrink-to-fit=no, user-scalable=no, minimum-scale=1, maximum-scale=1" name="viewport"/> <meta content="PressPlayWeb" name="apple-mobile-web-app-title"/> <meta content="white" name="apple-mobile-web-app-status-bar-style"/> <meta content="ppacademy:/project/vippPage/%E8%B6%85%E6%95%88%E7%8E%87%E5%AD%B8%E7%BF%92%E6%B3%95%7E/1CF3FF61991002F515CA07912A42D972" property="al:ios:url"/> <meta content="1330531123" property="al:ios:app_store_id"/> <meta content="PressPlay Academy" property="al:ios:app_name"/> <meta content="ppacademy:/project/vippPage/%E8%B6%85%E6%95%88%E7%8E%87%E5%AD%B8%E7%BF%92%E6%B3%95%7E/1CF3FF61991002F515CA07912A42D972" property="al:android:url"/> <meta content="cc.pressplay.user" property="al:android:package"/> <meta content="PressPlay Academy" property="al:android:app_name"/> <meta content="/project/vippPage/%E8%B6%85%E6%95%88%E7%8E%87%E5%AD%B8%E7%BF%92%E6%B3%95%7E/1CF3FF61991002F515CA07912A42D972" property="al:web:url"/> <meta content="app-id=1330531123, app-argument=https://www.pressplay.cc/project/vippPage/%E8%B6%85%E6%95%88%E7%8E%87%E5%AD%B8%E7%BF%92%E6%B3%95%7E/1CF3FF61991002F515CA07912A42D972" name="apple-itunes-app"/> <meta content="zh_TW" property="og:locale"/> <meta content="website" property="og:type"/> <meta content="超效率學習法 - PressPlay Academy 訂閱學習｜線上課程平台" property="og:title"/> <meta content=" 啾音好書-超效率學習法不自覺樂在其中，才是學習的最高境界你想要開始學習新事物，卻找不到方法嗎？你每天都覺得時間不夠，拼命學習，但是總是半途而廢，就像無頭蒼蠅一樣，越學越差嗎？哈囉大家好，歡迎來到《啾音好書》，我是啾啾鞋！今天要和大家介紹的" property="og:description"/> <meta content="https://www.pressplay.cc/project/vippPage/%E8%B6%85%E6%95%88%E7%8E%87%E5%AD%B8%E7%BF%92%E6%B3%95%7E/1CF3FF61991002F515CA07912A42D972" property="og:url"/> <meta content="https://static.pressplay.cc/static/uploads/timeline_cover/20210415/21C00D0C1BA00FC17A8803AD45C2D147/6077df1a8c1d021C00D0C1BA00FC17A8803AD45C2D14720210415143714.jpg" property="og:image"/> <meta content="啾啾鞋" property="article_author"/> <meta content="PressPlay Academy 訂閱學習｜線上課程平台" property="og:site_name"/> <meta content="943487429041504" property="fb:app_id"/> <meta content="PressPlay Academy" property="article:author"/> <meta content="PressPlay Academy" property="article:publisher"/> <link href="https://www.pressplay.cc" rel="preconnect"/> <link href="https://static.pressplay.cc" rel="preconnect"/> <link href="https://cdnjs.cloudflare.com" rel="preconnect"/> <link href="https://www.pressplay.cc" rel="dns-prefetch"/> <link href="https://static.pressplay.cc" rel="dns-prefetch"/> <link href="https://cdnjs.cloudflare.com" rel="dns-prefetch"/> <link as="style" href="https://www.pressplay.cc/public/93fb319f9/css/icomoon/style.css" rel="preload"/> <link as="style" href="https://www.pressplay.cc/public/93fb319f9/css/page/main.css" rel="preload"/> <link crossorigin="anonymous" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/5.12.1/css/all.min.css" rel="stylesheet" type="text/css"/> <link href="https://cdnjs.cloudflare.com/ajax/libs/animate.css/3.7.2/animate.min.css" rel="stylesheet" type="text/css"/> <link href="https://www.pressplay.cc/public/93fb319f9/css/main/main.css" rel="stylesheet" type="text/css"/> <link href="https://www.pressplay.cc/public/93fb319f9/css/layout/pressplay-layout.css" rel="stylesheet" type="text/css"/> <link href="https://www.pressplay.cc/public/93fb319f9/css/icomoon/style.css" rel="stylesheet" type="text/css"/> <link href="https://www.pressplay.cc/public/93fb319f9/css/page/main.css" rel="stylesheet" type="text/css"/> <link href="https://www.pressplay.cc/project/vippPage/%E8%B6%85%E6%95%88%E7 ...
# </style><script charset="utf-8" src="/public/93fb319f9/js/chunk/components/project/page/vipp.bundle.js?v=162ecacf1c3c25cdef65"></script><script charset="utf-8" src="/public/93fb319f9/js/chunk/components/common/GlobalPlayer/component/plugin.bundle.js?v=7713f09bb702e659aff4"></script><script charset="utf-8" src="/public/93fb319f9/js/32.bundle.js?v=e8ebbb11533633242bf6"></script><script charset="utf-8" src="/public/93fb319f9/js/chunk/components/common/header/v2/loginModal.bundle.js?v=c6dfc8f548c625cacf67"></script><style type="text/css">
# #close[data-v-215e51e2] {
#     top: 8px;
#     right: 8px;
#     cursor: pointer;
# }
# </style><link href="https://www.pressplay.cc/public/93fb319f9/css/page/common/global-player/player.css" rel="stylesheet" type="text/css"/><style type="text/css">
# .slide-fade-enter-active,
# .slide-fade-leave-active {
#     opacity: 1;
#     transition: all .3s ease;
# }
# .slide-fade-enter,
# .slide-fade-leave-to {
#     opacity: 0;
# }
# </style><link href="https://www.pressplay.cc/public/93fb319f9/css/page/common/loginModal.css" rel="stylesheet" type="text/css"/><link href="https://www.pressplay.cc/public/93fb319f9/css/page/project/timeline_article.css" rel="stylesheet" type="text/css"/><script charset="utf-8" src="/public/93fb319f9/js/chunk/components/common/GlobalPlayer/component/PlayerWrapper.bundle.js?v=99d9472b54860b623df5"></script><script charset="utf-8" src="/public/93fb319f9/js/chunk/components/common/GlobalPlayer/component/PlayerMiniBox.bundle.js?v=2427e2f98eef85913bdf"></script><script charset="utf-8" src="/public/93fb319f9/js/chunk/components/common/discuss.bundle.js?v=9342c3c413e45d62cde4"></script><script charset="utf-8" src="/public/93fb319f9/js/chunk/components/common/articleContentBox.bundle.js?v=f5db0e9a1f1e59ec4200"></script><script charset="utf-8" src="/public/93fb319f9/js/0.bundle.js?v=24d0803807c88cbfa200"></script><link href="https://www.pressplay.cc/public/93fb319f9/css/vendor/froala-wysiwyg-editor/css/froala_style.min.css" rel="stylesheet" type="text/css"/><link href="https://www.pressplay.cc/public/93fb319f9/css/vendor/froala-wysiwyg-editor/custom-theme.css" rel="stylesheet" type="text/css"/><link href="https://www.pressplay.cc/public/93fb319f9/css/page/common/article-content-box.css" rel="stylesheet" type="text/css"/><link href="https://www.pressplay.cc/public/93fb319f9/css/vendor/photoSwipe/photoswipe.min.css" rel="stylesheet" type="text/css"/><link href="https://www.pressplay.cc/public/93fb319f9/css/vendor/photoSwipe/default-skin/default-skin.css" rel="stylesheet" type="text/css"/><style type="text/css">[data-v-344b464c] strong{color:#212529}
# </style><link href="https://www.pressplay.cc/public/93fb319f9/css/page/common/discussions.css" rel="stylesheet" type="text/css"/><style type="text/css">
# @keyframes lds-pacman-1-data-v-2469a97e {
# 0% {
#         transform: rotate(0deg);
# }
# 50% {
#         transform: rotate(-45deg);
# }
# 100% {
#         transform: rotate(0deg);
# }
# }
# @-webkit-keyframes lds-pacman-1-data-v-2469a97e {
# 0% {
#         transform: rotate(0deg);
# }
# 50% {
#         transform: rotate(-45deg);
# }
# 100% {
#         transform: rotate(0deg);
# }
# }
# @keyframes lds-pacman-2-data-v-2469a97e {
# 0% {
#         transform: rotate(180deg);
# }
# 50% {
#         transform: rotate(225deg);
# }
# 100% {
#         transform: rotate(180deg);
# }
# }
# @-webkit-keyframes lds-pacman-2-data-v-2469a97e {
# 0% {
#         transform: rotate(180deg);
# }
# 50% {
#         transform: rotate(225deg);
# }
# 100% {
#         transform: rotate(180deg);
# }
# }
# @keyframes lds-pacman-3-data-v-2469a97e {
# 0% {
#         transform: translate(190px, 0);
#         opacity: 0;
# }
# 20% {
#         opacity: 1;
# }
# 100% {
#         transform: translate(70px, 0);
#         opacity: 1;
# }
# }
# @-webkit-keyframes lds-pacman-3-data-v-2469a97e {
# 0% {
#         transform: translate(190px, 0);
#         opacity: 0;
# }
# 20% {
#         opacity: 1;
# }
# 100% {
#         transform: translate(70px, 0);
#         opacity: 1;
# }
# }
# .lds-pacman[data-v-2469a97e] {
#     position: relative;
# }
# .lds-pacman>div:nth-child(2) div[data-v-2469a97e] {
#     position: absolute;
#     top: 40px;
#     left: 40px;
#     width: 120px;
#     height: 60px;
#     border-radius: 120px 120px 0 0;
#     background: #f08000;
#     -webkit-animation: lds-pacman-1-data-v-2469a97e 0.6s linear infinite;
#     animation: lds-pacman-1-data-v-2469a97e 0.6s linear infinite;
#     transform-origin: 60px 60px;
# }
# .lds-pacman>div:nth-child(2) div[data-v-2469a97e]:nth-child(2) {
#     -webkit-animation: lds-pacman-2-data-v-2469a97e 0.6s linear infinite;
#     animation: lds-pacman-2-data-v-2469a97e 0.6s linear infinite;
# }
# .lds-pacman>div:nth-child(1) div[data-v-2469a97e] {
#     position: absolute;
#     top: 92px;
#     left: -8px;
#     width: 16px;
#     height: 16px;
#     border-radius: 50%;
#     background: #c0c0c0;
#     -webkit-animation: lds-pacman-3-data-v-2469a97e 0.6s linear infinite;
#     animation: lds-pacman-3-data-v-2469a97e 0.6s linear infinite;
# }
# .lds-pacman>div:nth-child(1) div[data-v-2469a97e]:nth-child(1) {
#     -webkit-animation-delay: -0.402s;
#     animation-delay: -0.402s;
# }
# .lds-pacman>div:nth-child(1) div[data-v-2469a97e]:nth-child(2) {
#     -webkit-animation-delay: -0.198s;
#     animation-delay: -0.198s;
# }
# .lds-pacman>div:nth-child(1) div[data-v-2469a97e]:nth-child(3) {
#     -webkit-animation-delay: 0s;
#     animation-delay: 0s;
# }
# .lds-pacman[data-v-2469a97e] {
#     width: 70px !important;
#     height: 70px !important;
#     transform: translate(-35px, -35px) scale(0.35) translate(35px, 35px);
# }
# </style><script charset="utf-8" src="/public/93fb319f9/js/chunk/components/common/header/newsfeed.bundle.js?v=2c8c2f654dae3cc5ddd1"></script><link href="https://www.pressplay.cc/public/93fb319f9/css/page/common/pp-newsfeed.css" rel="stylesheet" type="text/css"/><script charset="utf-8" src="/public/93fb319f9/js/chunk/components/common/editJsContent.bundle.js?v=73fc21041b13279e1f14"></script><link href="https://www.pressplay.cc/public/93fb319f9/css/page/common/edit-js-content.css" rel="stylesheet" type="text/css"/><script charset="utf-8" src="/public/93fb319f9/js/chunk/components/common/GlobalPlayer/component/PlayerMainBox.bundle.js?v=b26646668317ac911e26"></script><script charset="utf-8" src="/public/93fb319f9/js/chunk/components/common/stringMarqueeBox.bundle.js?v=46754fc8aafcfcf52d6b"></script><style type="text/css">.string-marquee[data-v-4e6a1012]{position:relative;width:100%;height:100%}.string-marquee .string-marquee-warpper[data-v-4e6a1012]{overflow:hidden;width:100%;height:100%;white-space:nowrap;transition:all 0.3s ease}.string-marquee[data-v-4e6a1012]::before{content:'';position:absolute;top:0px;left:0px;display:inline-block;width:0px;height:100%;background:#fff;background:linear-gradient(to left, rgba(255,255,255,0), #fff 100%);transition:all 0.3s cubic-bezier(0, 0.83, 0.39, 1)}.string-marquee[data-v-4e6a1012]::after{content:'';position:absolute;top:0px;right:0px;display:inline-block;width:0px;height:100%;background:#fff;background:linear-gradient(to right, rgba(255,255,255,0), #fff 100%);transition:all 0.3s cubic-bezier(0, 0.83, 0.39, 1)}.string-marquee.before[data-v-4e6a1012]::before{width:5%;max-width:30px}.string-marquee.after[data-v-4e6a1012]::after{width:5%;max-width:30px}
# </style><style data-fbcssmodules="css:fb.css.base css:fb.css.dialog css:fb.css.iframewidget css:fb.css.customer_chat_plugin_iframe" type="text/css">.fb_hidden{position:absolute;top:-10000px;z-index:10001}.fb_reposition{overflow:hidden;position:relative}.fb_invisible{display:none}.fb_reset{background:none;border:0;border-spacing:0;color:#000;cursor:auto;direction:ltr;font-family:"lucida grande", tahoma, verdana, arial, sans-serif;font-size:11px;font-style:normal;font-variant:normal;font-weight:normal;letter-spacing:normal;line-height:1;margin:0;overflow:visible;padding:0;text-align:left;text-decoration:none;text-indent:0;text-shadow:none;text-transform:none;visibility:visible;white-space:normal;word-spacing:normal}.fb_reset>div{overflow:hidden}@keyframes fb_transform{from{opacity:0;transform:scale(.95)}to{opacity:1;transform:scale(1)}}.fb_animate{animation:fb_transform .3s forwards}
# .fb_dialog{background:rgba(82, 82, 82, .7);position:absolute;top:-10000px;z-index:10001}.fb_dialog_advanced{border-radius:8px;padding:10px}.fb_dialog_content{background:#fff;color:#373737}.fb_dialog_close_icon{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yq/r/IE9JII6Z1Ys.png) no-repeat scroll 0 0 transparent;cursor:pointer;display:block;height:15px;position:absolute;right:18px;top:17px;width:15px}.fb_dialog_mobile .fb_dialog_close_icon{left:5px;right:auto;top:5px}.fb_dialog_padding{background-color:transparent;position:absolute;width:1px;z-index:-1}.fb_dialog_close_icon:hover{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yq/r/IE9JII6Z1Ys.png) no-repeat scroll 0 -15px transparent}.fb_dialog_close_icon:active{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yq/r/IE9JII6Z1Ys.png) no-repeat scroll 0 -30px transparent}.fb_dialog_iframe{line-height:0}.fb_dialog_content .dialog_title{background:#6d84b4;border:1px solid #365899;color:#fff;font-size:14px;font-weight:bold;margin:0}.fb_dialog_content .dialog_title>span{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yd/r/Cou7n-nqK52.gif) no-repeat 5px 50%;float:left;padding:5px 0 7px 26px}body.fb_hidden{height:100%;left:0;margin:0;overflow:visible;position:absolute;top:-10000px;transform:none;width:100%}.fb_dialog.fb_dialog_mobile.loading{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/ya/r/3rhSv5V8j3o.gif) white no-repeat 50% 50%;min-height:100%;min-width:100%;overflow:hidden;position:absolute;top:0;z-index:10001}.fb_dialog.fb_dialog_mobile.loading.centered{background:none;height:auto;min-height:initial;min-width:initial;width:auto}.fb_dialog.fb_dialog_mobile.loading.centered #fb_dialog_loader_spinner{width:100%}.fb_dialog.fb_dialog_mobile.loading.centered .fb_dialog_content{background:none}.loading.centered #fb_dialog_loader_close{clear:both;color:#fff;display:block;font-size:18px;padding-top:20px}#fb-root #fb_dialog_ipad_overlay{background:rgba(0, 0, 0, .4);bottom:0;left:0;min-height:100%;position:absolute;right:0;top:0;width:100%;z-index:10000}#fb-root #fb_dialog_ipad_overlay.hidden{display:none}.fb_dialog.fb_dialog_mobile.loading iframe{visibility:hidden}.fb_dialog_mobile .fb_dialog_iframe{position:sticky;top:0}.fb_dialog_content .dialog_header{background:linear-gradient(from(#738aba), to(#2c4987));border-bottom:1px solid;border-color:#043b87;box-shadow:white 0 1px 1px -1px inset;color:#fff;font:bold 14px Helvetica, sans-serif;text-overflow:ellipsis;text-shadow:rgba(0, 30, 84, .296875) 0 -1px 0;vertical-align:middle;white-space:nowrap}.fb_dialog_content .dialog_header table{height:43px;width:100%}.fb_dialog_content .dialog_header td.header_left{font-size:12px;padding-left:5px;vertical-align:middle;width:60px}.fb_dialog_content .dialog_header td.header_right{font-size:12px;padding-right:5px;vertical-align:middle;width:60px}.fb_dialog_content .touchable_button{background:linear-gradient(from(#4267B2), to(#2a4887));background-clip:padding-box;border:1px solid #29487d;border-radius:3px;display:inline-block;line-height:18px;margin-top:3px;max-width:85px;padding:4px 12px;position:relative}.fb_dialog_content .dialog_header .touchable_button input{background:none;border:none;color:#fff;font:bold 12px Helvetica, sans-serif;margin:2px -12px;padding:2px 6px 3px 6px;text-shadow:rgba(0, 30, 84, .296875) 0 -1px 0}.fb_dialog_content .dialog_header .header_center{color:#fff;font-size:16px;font-weight:bold;line-height:18px;text-align:center;vertical-align:middle}.fb_dialog_content .dialog_content{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/y9/r/jKEcVPZFk-2.gif) no-repeat 50% 50%;border:1px solid #4a4a4a;border-bottom:0;border-top:0;height:150px}.fb_dialog_content .dialog_footer{background:#f5f6f7;border:1px solid #4a4a4a;border-top-color:#ccc;height:40px}#fb_dialog_loader_close{float:left}.fb_dialog.fb_dialog_mobile .fb_dialog_close_icon{visibility:hidden}#fb_dialog_loader_spinner{animation:rotateSpinner 1.2s linear infinite;background-color:transpar ...
# .fb_iframe_widget{display:inline-block;position:relative}.fb_iframe_widget span{display:inline-block;position:relative;text-align:justify}.fb_iframe_widget iframe{position:absolute}.fb_iframe_widget_fluid_desktop,.fb_iframe_widget_fluid_desktop span,.fb_iframe_widget_fluid_desktop iframe{max-width:100%}.fb_iframe_widget_fluid_desktop iframe{min-width:220px;position:relative}.fb_iframe_widget_lift{z-index:1}.fb_iframe_widget_fluid{display:inline}.fb_iframe_widget_fluid span{width:100%}
# .fb_mpn_mobile_landing_page_slide_out{animation-duration:200ms;animation-name:fb_mpn_landing_page_slide_out;transition-timing-function:ease-in}.fb_mpn_mobile_landing_page_slide_out_from_left{animation-duration:200ms;animation-name:fb_mpn_landing_page_slide_out_from_left;transition-timing-function:ease-in}.fb_mpn_mobile_landing_page_slide_up{animation-duration:500ms;animation-name:fb_mpn_landing_page_slide_up;transition-timing-function:ease-in}.fb_mpn_mobile_bounce_in{animation-duration:300ms;animation-name:fb_mpn_bounce_in;transition-timing-function:ease-in}.fb_mpn_mobile_bounce_out{animation-duration:300ms;animation-name:fb_mpn_bounce_out;transition-timing-function:ease-in}.fb_mpn_mobile_bounce_out_v2{animation-duration:300ms;animation-name:fb_mpn_fade_out;transition-timing-function:ease-in}.fb_customer_chat_bounce_in_v2{animation-duration:300ms;animation-name:fb_bounce_in_v2;transition-timing-function:ease-in}.fb_customer_chat_bounce_in_from_left{animation-duration:300ms;animation-name:fb_bounce_in_from_left;transition-timing-function:ease-in}.fb_customer_chat_bounce_out_v2{animation-duration:300ms;animation-name:fb_bounce_out_v2;transition-timing-function:ease-in}.fb_customer_chat_bounce_out_from_left{animation-duration:300ms;animation-name:fb_bounce_out_from_left;transition-timing-function:ease-in}.fb_customer_chat_bubble_animated_no_badge{box-shadow:0 3px 12px rgba(0, 0, 0, .15);transition:box-shadow 150ms linear}.fb_customer_chat_bubble_animated_no_badge:hover{box-shadow:0 5px 24px rgba(0, 0, 0, .3)}.fb_customer_chat_bubble_animated_with_badge{box-shadow:-5px 4px 14px rgba(0, 0, 0, .15);transition:box-shadow 150ms linear}.fb_customer_chat_bubble_animated_with_badge:hover{box-shadow:-5px 8px 24px rgba(0, 0, 0, .2)}.fb_invisible_flow{display:inherit;height:0;overflow-x:hidden;width:0}.fb_new_ui_mobile_overlay_active{overflow:hidden}@keyframes fb_mpn_landing_page_slide_in{0%{border-radius:50%;margin:0 24px;width:60px}40%{border-radius:18px}100%{margin:0 12px;width:100% - 24px}}@keyframes fb_mpn_landing_page_slide_in_from_left{0%{border-radius:50%;left:12px;margin:0 24px;width:60px}40%{border-radius:18px}100%{left:12px;margin:0 12px;width:100% - 24px}}@keyframes fb_mpn_landing_page_slide_out{0%{margin:0 12px;width:100% - 24px}60%{border-radius:18px}100%{border-radius:50%;margin:0 24px;width:60px}}@keyframes fb_mpn_landing_page_slide_out_from_left{0%{left:12px;width:100% - 24px}60%{border-radius:18px}100%{border-radius:50%;left:12px;width:60px}}@keyframes fb_mpn_landing_page_slide_up{0%{bottom:0;opacity:0}100%{bottom:24px;opacity:1}}@keyframes fb_mpn_bounce_in{0%{opacity:.5;top:100%}100%{opacity:1;top:0}}@keyframes fb_mpn_fade_out{0%{bottom:30px;opacity:1}100%{bottom:0;opacity:0}}@keyframes fb_mpn_bounce_out{0%{opacity:1;top:0}100%{opacity:.5;top:100%}}@keyframes fb_bounce_in_v2{0%{opacity:0;transform:scale(0, 0);transform-origin:bottom right}50%{transform:scale(1.03, 1.03);transform-origin:bottom right}100%{opacity:1;transform:scale(1, 1);transform-origin:bottom right}}@keyframes fb_bounce_in_from_left{0%{opacity:0;transform:scale(0, 0);transform-origin:bottom left}50%{transform:scale(1.03, 1.03);transform-origin:bottom left}100%{opacity:1;transform:scale(1, 1);transform-origin:bottom left}}@keyframes fb_bounce_out_v2{0%{opacity:1;transform:scale(1, 1);transform-origin:bottom right}100%{opacity:0;transform:scale(0, 0);transform-origin:bottom right}}@keyframes fb_bounce_out_from_left{0%{opacity:1;transform:scale(1, 1);transform-origin:bottom left}100%{opacity:0;transform:scale(0, 0);transform-origin:bottom left}}@keyframes fb_bounce_out_v2_mobile_chat_started{0%{opacity:1;top:0}100%{opacity:0;top:20px}}@keyframes fb_customer_chat_bubble_bounce_in_animation{0%{bottom:6pt;opacity:0;transform:scale(0, 0);transform-origin:center}70%{bottom:18pt;opacity:1;transform:scale(1.2, 1.2)}100%{transform:scale(1, 1)}}@keyframes slideInFromBottom{0%{opacity:.1;transform:translateY(100%)}100%{opacity:1;transform:translateY(0)}}@keyframes sli ...
#                                     註冊
#                                 </button> <button class="btn btn-outline-gray" data-v-f019c660="">
#                                     登入
#                                 </button></div> <div class="header-drop-down-info" data-v-f019c660="" rel="hr"></div> <div class="header-drop-down-menu-item" data-v-f019c660=""><div class="header-drop-down-info text-center" data-v-f019c660=""><div class="dot-loading" data-v-4e05eb63="" data-v-f019c660=""><span data-v-4e05eb63="" style="width: 8px; height: 8px; margin: 16px 2px;"></span> <span data-v-4e05eb63="" style="width: 8px; height: 8px; margin: 16px 2px;"></span> <span data-v-4e05eb63="" style="width: 8px; height: 8px; margin: 16px 2px;"></span></div></div></div></div><div class="ps__scrollbar-x-rail" style="left: 0px; bottom: 0px;"><div class="ps__scrollbar-x" style="left: 0px; width: 0px;" tabindex="0"></div></div><div class="ps__scrollbar-y-rail" style="top: 0px; right: 0px;"><div class="ps__scrollbar-y" style="top: 0px; height: 0px;" tabindex="0"></div></div></section> <!-- --> <!-- --></div></div></div></li></ul></nav></div> <div class="pp-header-item" data-v-26d04444="" data-v-dc85437e="" rel="logo"><a aria-current="page" class="pressplay-logo" data-v-905de9e2="" data-v-dc85437e="" href="/"><img alt="PressPlay 訂閱學習，時刻精進" class="pressplay-logo" data-v-dc85437e="" src="/public/img/logo/logo.png" srcset="/public/img/logo/logo@2x.png 2x, /public/img/logo/logo@3x.png 3x"/></a> <!-- --></div> <div class="pp-header-item" data-v-26d04444="" rel="left"><nav class="pp-header-nav" data-v-26d04444=""><ul class="pp-header-nav-wrapper" data-v-26d04444=""><!-- --> <li class="pp-header-nav-item" data-v-20b4507e="" data-v-26d04444="" rel="category"><div class="header-drop-down" data-v-20b4507e=""><div class="header-drop-down-btn" data-v-20b4507e=""><div class="header-drop-down-btn-wrapper" data-v-20b4507e="">
#                 內容探索
#                 <i class="icon icon-arrow_down_M" data-v-20b4507e=""></i></div></div> <div class="header-drop-down-menu" data-v-20b4507e=""><div class="header-drop-down-menu-wrapper" data-v-20b4507e=""><div class="header-drop-down-menu-group" data-v-20b4507e=""><div class="header-drop-down-menu-item" data-v-20b4507e=""><div class="header-drop-down-info text-center" data-v-20b4507e=""><div class="dot-loading" data-v-20b4507e="" data-v-4e05eb63=""><span data-v-4e05eb63="" style="width: 8px; height: 8px; margin: 16px 2px;"></span> <span data-v-4e05eb63="" style="width: 8px; height: 8px; margin: 16px 2px;"></span> <span data-v-4e05eb63="" style="width: 8px; height: 8px; margin: 16px 2px;"></span></div></div></div></div></div></div></div></li> <li class="pp-header-nav-item" data-v-26d04444="" data-v-76d77cfe="" rel="search" type="pc"><div class="header-drop-down" data-v-76d77cfe=""><div class="header-drop-down-btn" data-v-76d77cfe=""><form action="/search" data-v-76d77cfe="" method="get"><label class="header-search" data-v-76d77cfe="" for="header-search-input"><input autocomplete="off" data-v-76d77cfe="" id="header-search-input" placeholder="航運股漲停" type="text"/> <i class="icon icon-search" data-v-76d77cfe=""></i></label></form></div> <!-- --> <div class="header-drop-down-menu" data-v-76d77cfe=""><div class="header-drop-down-menu-wrapper no-gutters" data-v-76d77cfe=""><div class="header-drop-down-menu-tab" data-v-76d77cfe=""><!-- --> <section class="ps-container header-drop-down-menu-tab-item ps ps--theme_default" data-ps-id="0e0085f0-1906-1436-9e23-e7d6505949c4" data-v-76d77cfe="" rel="content"><div class="header-drop-down-menu-item" data-v-76d77cfe=""><div class="header-drop-down-info" data-v-76d77cfe="" rel="title-bar"><div class="header-drop-down-info-item" data-v-76d77cfe="" rel="title">
#                                     熱門關鍵字
#                                 </div> <div class="header-drop-down-info-item" data-v-76d77cfe="" rel="tool"></div></div> <div class="header-drop-down-info" data-v-76d77cfe="" rel="search-tags"><div class="header-drop-down-info-item" data-v-76d77cfe="" rel="tag">航運股漲停</div><div class="header-drop-down-info-item" data-v-76d77cfe="" rel="tag">PPA週年慶</div><div class="header-drop-down-info-item" data-v-76d77cfe="" rel="tag">浦惠投顧</div><div class="header-drop-down-info-item" data-v-76d77cfe="" rel="tag">設計館</div><div class="header-drop-down-info-item" data-v-76d77cfe="" rel="tag">權證小哥</div><div class="header-drop-down-info-item" data-v-76d77cfe="" rel="tag">Jasper</div><div class="header-drop-down-info-item" data-v-76d77cfe="" rel="tag">無聊詹</div><div class="header-drop-down-info-item" data-v-76d77cfe="" rel="tag">Ashin</div></div> <!-- --></div><div class="ps__scrollbar-x-rail" style="left: 0px; bottom: 0px;"><div class="ps__scrollbar-x" style="left: 0px; width: 0px;" tabindex="0"></div></div><div class="ps__scrollbar-y-rail" style="top: 0px; right: 0px;"><div class="ps__scrollbar-y" style="top: 0px; height: 0px;" tabindex="0"></div></div></section></div></div></div></div></li></ul></nav></div> <div class="pp-header-item" data-v-26d04444="" rel="space"></div> <div class="pp-header-item" data-v-26d04444="" rel="right"><nav class="pp-header-nav" data-v-26d04444=""><ul class="pp-header-nav-wrapper" data-v-26d04444=""><li class="pp-header-nav-item" data-v-26d04444="" data-v-47dedb4a="" rel="pp-promote-event"><a data-v-47dedb4a="" data-v-905de9e2="" href="/link/3737B810" title="PPA週年慶"><img alt="PPA週年慶" class="pp-promote-event-img" data-v-47dedb4a="" data-v-905de9e2="" src="https://static.pressplay.cc/static/uploads/pp_Commercial/1DDA24D6730F3E17D48C05E145EE0D0B/20210714/60ee5021e4b2120210714104657.gif"/></a></li> <li class="pp-header-nav-item" data-v-26d04444="" data-v-28db9624="" rel="creator"><a class="pp-header-nav-button" data-v-28db9624="" href="https://www.pressplay.cc/support/index/%E7%94%B3%E8%AB%8B%E6%88%90%E7%82%BA%E5%89%B5%E4%BD%9C%E8%80%85~/DDFA028AA3D38802A1C1C8950ED00ED1">
#             成為創作者
#         </a></li> <!-- --> <!-- --> <li class="pp-header-nav-item" data-v-20248d7c="" data-v-26d04444="" rel="notice"><div class="header-drop-down" data-direction="right" data-v-20248d7c=""><div class="header-drop-down-btn" data-v-20248d7c=""><div class="header-drop-down-btn-wrapper" data-v-20248d7c="" rel="icon-btn"><i class="icon icon-newsfeed" data-v-20248d7c=""></i> <!-- --></div></div> <div class="header-drop-down-menu" data-v-20248d7c=""><div data-v-20248d7c="" data-v-f196598a=""><div class="header-drop-down-menu-wrapper no-gutters" data-v-f196598a=""><div class="header-drop-down-menu-tab" data-v-f196598a=""><div class="header-drop-down-menu-tab-item" data-v-f196598a="" rel="header"><div class="header-drop-down-menu-tab-header-wrapper" data-v-f196598a=""><div class="header-drop-down-menu-tab-header-item active" data-v-f196598a=""><i class="icon icon-newsfeed" data-v-f196598a=""></i>
#                             公告
#                             <!-- --> <!-- --></div></div></div> <section class="ps-container header-drop-down-menu-tab-item ps ps--theme_default" data-ps-id="79f771f1-67ef-b358-b213-07052cc5c549" data-v-f196598a=""><div class="header-drop-down-menu-item" data-v-f196598a=""><!-- --> <div class="header-drop-down-info cursor-pointer hover" data-v-f196598a="" name="header-bar_123" rel="pic-info-item"><div class="header-drop-down-info-item" data-v-f196598a="" rel="pic"><div class="pic lazyload lazy-bind done" data-src="/public/img/icon/logo/logo-avatar.png" data-v-f196598a="" style='background-image: url("/public/img/icon/logo/logo-avatar.png");'></div></div> <div class="header-drop-down-info-item" data-v-f196598a="" rel="info"><div class="header-drop-down-info-item-one" data-v-f196598a="" rel="title">
#                                         2021 PPA 週年慶｜設計生活館 85 折
#                                     </div> <div class="header-drop-down-info-item-one" data-v-f196598a="">
#                                         2021 PPA 週年慶｜設計生活館琢磨生活的美好07.20&amp;nbsp;前購買指定課程，結帳輸入 DLIFE 即享&amp;nbsp;85&amp;nbsp;折使用優惠碼完成訂單，再抽知名品牌正負零除濕機一台設計 X 生活 X 親子 X 手作 ｜PPA 與你一起享受日常時光
#                                     </div> <div class="header-drop-down-info-item-one" data-v-f196598a=""><i class="icon icon-time_clock_S" data-v-f196598a=""></i> <time class="relativeTime" data-time="2021-07-15T00:00:00+08:00" data-v-f196598a="">1 天前</time></div></div></div></div><div class="ps__scrollbar-x-rail" style="left: 0px; bottom: 0px;"><div class="ps__scrollbar-x" style="left: 0px; width: 0px;" tabindex="0"></div></div><div class="ps__scrollbar-y-rail" style="top: 0px; right: 0px;"><div class="ps__scrollbar-y" style="top: 0px; height: 0px;" tabindex="0"></div></div></section> <div class="header-drop-down-menu-tab-item" data-v-f196598a="" rel="footer"><div class="header-drop-down-menu-item" data-v-f196598a=""><a class="header-drop-down-info" data-v-905de9e2="" data-v-f196598a="" href="/member/notification#newsfeed" rel="button">
#                             查看全部
#                         </a></div></div> <!-- --></div></div> <!-- --></div></div></div></li> <li class="pp-header-nav-item" data-v-26d04444="" data-v-f25a98e0="" rel="login"><button class="btn btn-outline-gray" data-v-f25a98e0="">
#         登入
#     </button> <button class="btn btn-primary" data-v-f25a98e0="">
#         註冊
#     </button></li></ul></nav></div> <div class="pp-header-item" data-v-26d04444="" rel="space-last"></div></div></header> <div aria-hidden="true" class="pp-login-modal modal fade" data-backdrop="static" data-theme="notice" data-v-26d04444="" id="pp-login-modal" style="display: none;" tabindex="-1"><div class="modal-dialog modal-dialog-centered justify-content-center" role="document"><div class="modal-content"><div class="modal-header"><img alt="PressPlay 訂閱學習，時刻精進" class="logo" src="/public/img/PressPlay-logo-inverse.png" srcset="/public/img/PressPlay-logo-inverse@2x.png 2x, /public/img/PressPlay-logo-inverse@3x.png 3x"/> <button aria-label="Close" class="close" data-dismiss="modal" type="button"><i class="icon icon-close"></i></button></div> <div class="modal-body subtitle">一鍵加入會員<br/>追蹤 啾啾鞋 看更多優質內容</div> <div class="modal-body"><!-- --></div> <!-- --></div></div></div></div> <div class="header-backdrop"></div> <div class="site-content"><div class="pp-system-notice-box"><!-- --></div> <div class="main-page" style="min-height: 508px;"><div class="project-timeline-article-page" data-v-5bc5e4aa="" timeline_key="1CF3FF61991002F515CA07912A42D972" timeline_title="超效率學習法~"><div class="project-timeline-article" data-v-5bc5e4aa=""><div class="container" data-v-5bc5e4aa=""><div class="row justify-content-center" data-v-5bc5e4aa=""><div class="col-12 col-lg-10" data-v-5bc5e4aa=""><nav data-v-58ad60d0="" data-v-5bc5e4aa="" style="display: none;"><ol class="pp-breadcrumb" data-v-58ad60d0="" ins-init-condition="#LnBwLWJyZWFkY3J1bWI=" itemscope="itemscope" itemtype="https://schema.org/BreadcrumbList" style="opacity: 1;"><li class="pp-breadcrumb-item" data-v-58ad60d0="" itemprop="itemListElement" itemscope="itemscope" itemtype="https://schema.org/ListItem"><a class="" data-v-58ad60d0="" data-v-905de9e2="" href="/project?type=1253D7A4E325A3D03205A79DC59DDEB8" itemprop="item"><span data-v-58ad60d0="" itemprop="name">職場技能</span></a> <meta content="1" data-v-58ad60d0="" itemprop="position"/></li><li class="pp-breadcrumb-item" data-v-58ad60d0="" itemprop="itemListElement" itemscope="itemscope" itemtype="https://schema.org/ListItem"><a class="" data-v-58ad60d0="" data-v-905de9e2="" href="/project/082A3A85B647A6210495A9C0DCCC0FCC/about" itemprop="item"><span data-v-58ad60d0="" itemprop="name">啾音好書｜用說書開啟閱讀的新方式</span></a> <meta content="2" data-v-58ad60d0="" itemprop="position"/></li><li class="pp-breadcrumb-item" data-v-58ad60d0="" itemprop="itemListElement" itemscope="itemscope" itemtype="https://schema.org/ListItem"><a class="" data-v-58ad60d0="" data-v-905de9e2="" href="/project/082A3A85B647A6210495A9C0DCCC0FCC/vipp" itemprop="item"><span data-v-58ad60d0="" itemprop="name">學習專區</span></a> <meta content="3" data-v-58ad60d0="" itemprop="position"/></li><li class="pp-breadcrumb-item is-active" data-v-58ad60d0="" itemprop="itemListElement" itemscope="itemscope" itemtype="https://schema.org/ListItem"><span data-v-58ad60d0="" itemprop="name">超效率學習法</span> <a data-v-58ad60d0="" href="/project/vippPage/%E8%B6%85%E6%95%88%E7%8E%87%E5%AD%B8%E7%BF%92%E6%B3%95%7E/1CF3FF61991002F515CA07912A42D972" itemprop="item"></a> <meta content="4" data-v-58ad60d0="" itemprop="position"/></li></ol></nav> <!-- --> <!-- --> <div class="article-info-box" data-v-5bc5e4aa=""><div class="article-info-item" data-v-5bc5e4aa="" data-v-60dc4ba2="" itemscope="itemscope" itemtype="http://schema.org/Article"><h1 class="article-info-title" content="超效率學習法" data-v-60dc4ba2=""><!-- -->
#         超效率學習法
#     </h1> <!-- --></div> <div class="article-info-item" data-v-5bc5e4aa="" data-v-77b5d684="" rel="rewardInfo"><div class="article-info-reward-box" data-v-77b5d684=""><div class="article-info-reward-list" data-v-77b5d684=""><div class="article-info-reward" data-v-77b5d684="" rel="public" title="公開文章">
#                     公開
#                 </div></div></div></div> <div class="article-info-item" data-v-5bc5e4aa="" data-v-6b2c3b2d="" rel="moreInfo"><div class="article-info-project-box" data-v-6b2c3b2d=""><div class="article-info-wrapper" data-v-6b2c3b2d=""><a class="article-info-project-image-wrapper lazyload js-insite-link border-0 lazy-bind done" data-src="https://static.pressplay.cc/static/uploads/member_author/20210426/21C00D0C1BA00FC17A8803AD45C2D147/608625721e26121C00D0C1BA00FC17A8803AD45C2D14720210426102906.png" data-v-6b2c3b2d="" data-v-905de9e2="" href="/project/082A3A85B647A6210495A9C0DCCC0FCC/vipp" itemscope="itemscope" itemtype="http://schema.org/Product" otherappdata="[object Object]" style='background-image: url("https://static.pressplay.cc/static/uploads/member_author/20210426/21C00D0C1BA00FC17A8803AD45C2D147/608625721e26121C00D0C1BA00FC17A8803AD45C2D14720210426102906.png");'><meta content="082A3A85B647A6210495A9C0DCCC0FCC" data-v-6b2c3b2d="" itemprop="productID"/> <meta content="082A3A85B647A6210495A9C0DCCC0FCC" data-v-6b2c3b2d="" itemprop="mpn"/> <meta content="082A3A85B647A6210495A9C0DCCC0FCC" data-v-6b2c3b2d="" itemprop="sku"/> <meta content="啾音好書｜用說書開啟閱讀的新方式" data-v-6b2c3b2d="" itemprop="name"/> <meta content="https://www.pressplay.cc/https://static.pressplay.cc/static/uploads/project/082A3A85B647A6210495A9C0DCCC0FCC/project_image/20210316/21C00D0C1BA00FC17A8803AD45C2D147/605088413951d21C00D0C1BA00FC17A8803AD45C2D14720210316182817.png" data-v-6b2c3b2d="" itemprop="image"/> <meta content="每天用十分鐘投資自己，聽說書人啾啾鞋、Neko嗚喵、生鮮時書鮪魚等各領域創作者為你說書，讓知識像複利一樣累積！時間有限，啾音好書 讓你知識無限。" data-v-6b2c3b2d="" itemprop="description"/> <meta content="啾啾鞋" data-v-6b2c3b2d="" itemprop="brand"/> <div data-v-6b2c3b2d="" itemprop="offers" itemscope="itemscope" itemtype="http://schema.org/AggregateOffer"><meta content="240" data-v-6b2c3b2d="" itemprop="lowPrice"/> <meta content="16200" data-v-6b2c3b2d="" itemprop="highPrice"/> <meta content="TWD" data-v-6b2c3b2d="" itemprop="priceCurrency"/> <meta content="100" data-v-6b2c3b2d="" itemprop="offerCount"/> <link data-v-6b2c3b2d="" href="http://schema.org/UsedCondition" itemprop="itemCondition"/> <link data-v-6b2c3b2d="" href="http://schema.org/InStock" itemprop="availability"/> <div data-v-6b2c3b2d="" itemprop="seller" itemscope="itemscope" itemtype="http://schema.org/Organization"><meta content="Pressplay" data-v-6b2c3b2d="" itemprop="name"/></div></div></a> <div class="article-info-project-wrapper" data-v-6b2c3b2d=""><div class="article-info-project-title-wrapper" data-v-6b2c3b2d=""><div class="article-info-project-title" data-v-6b2c3b2d=""><a class="link--secondary js-insite-link" data-v-6b2c3b2d="" data-v-905de9e2="" href="/project/082A3A85B647A6210495A9C0DCCC0FCC/vipp">
#                             啾音好書｜用說書開啟閱讀的新方式
#                         </a></div> <div class="article-info-project-follow" data-v-6b2c3b2d=""><button class="btn btn-sm u-fontSize12 follow-btn btn-outline-error" data-v-6b2c3b2d="" role="button"><i class="icon icon-follow_outline" data-v-6b2c3b2d=""></i> <span data-v-6b2c3b2d="">追蹤</span></button></div></div> <div class="article-info-project-state-wrapper" data-v-6b2c3b2d=""><div class="article-info-article-date" data-release="曝光" data-v-6b2c3b2d=""><i class="icon-time" data-v-6b2c3b2d=""></i> <time data-v-6b2c3b2d="">
#                             2021/05/10 15:00
#                         </time></div> <div class="article-info-article-article-state" data-v-6b2c3b2d=""><span data-v-6b2c3b2d=""><i class="icon icon-read" data-v-6b2c3b2d=""></i> <span data-v-6b2c3b2d="">7,131</span></span></div></div></div></div></div></div></div> <div class="article-manager-box" data-v-5bc5e4aa="" data-v-61d8cc94=""><div class="btn btn-sm change-font-btn" data-v-61d8cc94="" role="button"><div class="pp-dropdown dropdown dropdown" data-v-61d8cc94=""><div aria-expanded="false" aria-haspopup="false" class="" data-flip="false" data-offset="0" data-toggle="dropdown"><!-- --> <div class="before-icon"><i class="icon-text_size mx-1"></i></div> <div class="dropdown-title">
#             預設
#         </div> <div class="icon"><i class="gear icon-down"></i></div></div> <div aria-labelledby="dropdownMenuButton" class="dropdown-menu dropdown-menu-right"><!-- --> <div class="dropdown-body"><a class="dropdown-item" href="javascript:void(0);"><div class="dropdown-select-box checked"><div class="select-item" rel="title">
#                                 預設
#                             </div> <div class="select-item" rel="check"><div class="icon-check"></div></div></div></a><a class="dropdown-item" href="javascript:void(0);"><div class="dropdown-select-box"><div class="select-item" rel="title">
#                                 較大
#                             </div> <div class="select-item" rel="check"><div class="icon-check"></div></div></div></a><a class="dropdown-item" href="javascript:void(0);"><div class="dropdown-select-box"><div class="select-item" rel="title">
#                                 特大
#                             </div> <div class="select-item" rel="check"><div class="icon-check"></div></div></div></a></div></div></div></div> <!-- --></div> <div class="article-content-box-wrap" data-v-5bc5e4aa="" data-v-6a299cd6=""><div data-v-6a299cd6=""><div class="article-content-box fr-box fr-view clearfix"><h3 dir="ltr" style="font-size: 28px;"><img class="fr-fic fr-dii pp_atteche pp-lightbox cursor-pointer" data-data="[object Object]" data-filekey="D49F4C21827E75E6C7AA2FDEE541FB92" data-filetype="image" data-height="750" data-message="success" data-src="https://static.pressplay.cc/static/uploads/timeline/20210415/21C00D0C1BA00FC17A8803AD45C2D147/6077de4449b9921C00D0C1BA00FC17A8803AD45C2D14720210415143340.jpg" data-status="success" data-uuid="224eaf2f-05ee-4c8a-9395-67f974e954fd" data-width="1350" src="https://static.pressplay.cc/static/uploads/timeline/20210415/21C00D0C1BA00FC17A8803AD45C2D147/6077de4449b9921C00D0C1BA00FC17A8803AD45C2D14720210415143340.jpg" style="font-size: 28px;"/></h3>
# <p style="font-size: 16px;"><img class="fr-fic fr-dii pp_atteche pp-lightbox cursor-pointer" data-data="[object Object]" data-filekey="5518A55588897254AD1799D8D0D646D3" data-filetype="image" data-height="750" data-message="success" data-src="https://static.pressplay.cc/static/uploads/timeline/20210415/21C00D0C1BA00FC17A8803AD45C2D147/6077de5429f6021C00D0C1BA00FC17A8803AD45C2D14720210415143356.jpg" data-status="success" data-uuid="12a86a45-09d5-4c0f-b84d-a3e7cd6e57e0" data-width="1350" src="https://static.pressplay.cc/static/uploads/timeline/20210415/21C00D0C1BA00FC17A8803AD45C2D147/6077de5429f6021C00D0C1BA00FC17A8803AD45C2D14720210415143356.jpg" style="font-size: 16px;"/></p>
# <hr style="font-size: 16px;"/>
# <p style="font-size: 16px;"><div class="fr-audio-wrapper cursor-pointer" style="font-size: 16px;"><audio class="fr-audio pp-audio pp_atteche" controls="" data-duration="671.89551" data-filekey="AB499AE41A0E1B6959215EFA098A0D1C" data-filetype="audio" data-uuid="a82a2f09-ed4b-4b96-9d70-dc731727dc9b" style="width: 100%; font-size: 16px;"><source src="https://audio.pressplay.cc/timeline%2F20210511%2F21C00D0C1BA00FC17A8803AD45C2D147%2F1620720111185-71.%E8%B6%85%E6%95%88%E7%8E%87%E5%AD%B8%E7%BF%92%E6%B3%95+%281%29.mp3" style="font-size: 16px;"/></audio>
# <div class="mask" style="font-size: 16px;">
# <div class="icon-box" style="font-size: 16px;">
# <div class="playlist-icon-btn" style="font-size: 16px;">
# <span style="font-size: 16px;"><i class="icon icon-add_border" style="font-size: 20px;"></i></span>
# </div>
# </div>
# <div class="time-box" style="font-size: 16px;">
# <div class="time" style="font-size: 16px;">11:11</div>
# </div>
# <div class="text-box" style="font-size: 16px;">
# <span class="mr-1" style="font-size: 16px;"><i class="icob icon-title" style="font-size: 16px;"></i></span>
# <span class="text" style="font-size: 16px;">點擊播放音檔</span>
# </div>
# </div></div><span style="font-size: 14px;"><em style="font-size: 14px;"> 啾音好書-超效率學習法</em></span></p>
# <hr style="font-size: 16px;"/>
# <h3 dir="ltr" style="font-size: 28px;">不自覺樂在其中，才是學習的最高境界</h3>
# <p dir="ltr" style="font-size: 16px;">你想要開始學習新事物，卻找不到方法嗎？你每天都覺得時間不夠，拼命學習，但是總是半途而廢，就像無頭蒼蠅一樣，越學越差嗎？</p>
# <p data-empty="true" style="font-size: 16px;">哈囉大家好，歡迎來到《啾音好書》，我是啾啾鞋！今天要和大家介紹的這本書叫做《超效率學習法》，作者是一位日本人，叫做 pha。在介紹這本書以前，我要先分享一下這位作者的故事，因為實在太有趣了。pha 他大學念的是京都大學綜合人類學系，畢業之後，他跟大家一樣進入職場工作，但是因為壓力太大，三年後決定離開職場。後來，他開始在家靠寫程式賺錢，開了一個叫做「Geek House」（怪咖宿舍）的合租公寓，和一群跟他一樣靠著網路生活的人住在一起分攤租金。現在他還能靠著出書的版稅生活，「在家躺著也能賺錢」這句話根本就是他的人生寫照，聽了讓人超級羨慕。</p>
# <p dir="ltr" style="font-size: 16px;">而這樣的人，是如何靠著自我學習培養出不同技能？感覺一定是非常拼命對吧，不過作者 pha 在這本書開宗名義的就寫了這句話：「比起認真、拼命努力的人，不自覺地樂在其中的人更厲害。」這也是我想要跟大家分享這本書的原因，高效學習不是分秒必爭的胡亂吸收，而是找到真正能引發你興趣的領域與學習方式，不用強迫自己每天早上五點起床，坐在書桌前讀著數不完的書。</p>
# <p dir="ltr" style="font-size: 16px;">接下來將會跟大家分享，作者是如何挑選並消化大量資訊，以及如何梳理混亂的思緒，有系統地產出，以及他是如何對抗「懶惰」這個天敵。</p>
# <h3 dir="ltr" style="font-size: 28px;">面對大量知識與資訊，該如何吸收和整理？</h3>
# <p dir="ltr" style="font-size: 16px;">對於學習，你是不是也和曾經的我一樣持有這種態度？那就是「要一次學到最正統、100% 正確的知識」，所以光是在比較篩選來源就花了很多時間。這裏作者就特別強調了，當我們在尋找要輸入大腦的資訊時，追求過度正確的記憶並沒什麼用，反而是模糊曖昧的記憶，更為實用。</p>
# <p dir="ltr" style="font-size: 16px;">什麼意思？比方當我們今天看到一則新聞時，就會急著去搜尋某個喜愛的 KOL 的論點，然後僅憑著兩三篇貼文，就決定踩好某個立場，或者為新聞事件下定論，而不是多方吸取觀點再進行判斷；閱讀也是如此，當你在學習新的領域，保持知識的模糊性是很重要的，例如你今天想要鑽研某個哲學家的思想，那麼除了直接翻開他的自傳或著作，也可以翻翻別人對他的評論或解析，這就是作者在書中說的「將知識混合著讀」，每當他接觸新領域時，一定會讀過至少三本相關書籍（可以是兩本新手入門，搭配一本跟該領域相關的小說、散文，或者理論書都可以），最終你會漸漸在心中構築初步的觀點，而且是屬於你自己的觀點，而不是從書上死記硬背來的。我真的非常推薦想要透過閱讀建立個人觀點的你，可以試試這種方法。但是別誤會，將知識混著讀，不代表我們可以隨意吸收任何錯誤知識或假消息，不去做任何思考判斷。</p>
# <p dir="ltr" style="font-size: 16px;">再來作者提到了一個讓資訊自然而然進入大腦的方法，那就是善用社群的連結力。網路讓我們在最短的時間內，汲取他人的觀點和想法，而不需要花大把鈔票搭飛機到某地聽某人演講，且聲音變得更多元，麥克風不再為位高權重者所有，我們可以輕易在 FB、IG、Twitter 上吸收各種資訊。但也因為人人都有權利發聲，許多假消息、垃圾新聞也就跟著出現。</p>
# <p dir="ltr" style="font-size: 16px;">為了找到真正值得吸收的資訊，作者提出「追蹤策展人」的概念，來幫助我們在社群媒體上更容易取得所需。美術館裡的策展人，具有獨到的眼光，能將不同材質、主題的作品，用系統性的方式重新安排配置，策展人知道如何將作品的核心理念傳遞給大眾；社群媒體上的策展人也是如此，你可以去追蹤幾位感興趣領域的「策展人」，也就是常常會發表該領域評論的 KOL，並順著去追蹤策展人追蹤的帳號，透過社群的連結，你能夠獲取的資訊範圍也就越來越大。那麼以後除了在新聞帳號獲取消息，你也能同時看見不同人針對新聞消息發表的評論。</p>
# <h3 dir="ltr" style="font-size: 28px;">讓輸出成為最好的輸入</h3>
# <p dir="ltr" style="font-size: 16px;">該如何確保你確實吸收消化新知識呢？作者說最好的驗證方式就是「輸出資訊」，也就是將知識重新整理，像介紹給完全不懂的朋友一樣，用自己的話重新解說一遍。</p>
# <p dir="ltr" style="font-size: 16px;">在書中，作者提供了兩種方式，分別為網路活用術與紙筆活用術，前者是較為簡單的輸出方法，可以更快上手進行，不用構築好自己的觀點理論，隨意打幾行字發出即可；後者則是更進階複雜的輸出方式，較難上手，但是更能幫助你建立完整的論述。</p>
# <p dir="ltr" style="font-size: 16px;">首先談談網路輸出，不管你使用什麼平台，FB、IG 或 Blog，在寫下自己的心得、紀錄想法和延伸思考時，都要放輕鬆來寫，比方你今天閱讀了一本關於習慣養成的書，那就可以簡單幾句話，分享作者提到的三種養成方式，或者是你實踐後的結果；假如你還想了解更多培養習慣的方法，甚至可以將網路上類似的演講影片、Medium 文章等整理進自己的貼文中，把網路當作擴充大腦的工具，假如有人看到貼文，留言和你交流，你就又能獲得不同的思考方式了！但網路輸出的前提是，必須以「自己感興趣的內容」為優先，而不是只為了增加曝光率或賺錢為唯一目的，不然很快就會想放棄。</p>
# <p dir="ltr" style="font-size: 16px;">有了平時在網路上輸出的經驗，接下來就能進入到幫助你建立完整論述的方式——紙筆活用術。作者將其分為三個階段：</p>
# <ol style="font-size: 16px;">
# <li dir="ltr" style="font-size: 16px;"><p dir="ltr" style="font-size: 16px;">激發靈感</p></li>
# <li dir="ltr" style="font-size: 16px;"><p dir="ltr" style="font-size: 16px;">思考架構</p></li>
# <li dir="ltr" style="font-size: 16px;"><p dir="ltr" style="font-size: 16px;">執行</p></li>
# </ol>
# <p dir="ltr" style="font-size: 16px;">在閱讀玩喜歡的書後，你的腦中一定會冒出很多詞彙和想法，想要寫成一篇文章，卻又不知道該如何把彼此串接起來，所以在第一個階段「激發靈感」時，請你挑選一大張紙，並且把紙擺成橫的，寫上主題後，就什麼邏輯都不要想，一股腦地將所有詞彙寫在白紙上，過程中也不要去想對錯與否。</p>
# <p dir="ltr" style="font-size: 16px;">在第一階段要盡可能把大腦天馬行空的想法倒出來，所以工具很重要，假如你挑的紙張太小，你可能就會想「寫滿就好了吧」，而不是「我要把所有靈感寫完」，想法會因為紙張受限；而將紙張擺成橫的，與人們對空間的認知有關，我們會將上下與順序、階級連結，左右則跟多元、並列連結。也就是當紙張是直的，會比較適合羅列代辦事項，也會覺得上比下更重要；而當紙張是橫的，會讓我們的靈感得以擴張、不受限制。</p>
# <p dir="ltr" style="font-size: 16px;">接著在第二階段思考架構，則開始將寫文章時會用到的想法圈起來，並且將類似的概念組合起來，同時，你也可以思考整篇文章的邏輯順序，讀起來是否順暢，此時你的文章架構已經初步成型了。</p>
# <p dir="ltr" style="font-size: 16px;">到了第三階段的執行，前面有了骨架，接下來只要填肉就好，這個階段通常不會有太大問題，唯一需要注意的是：不用一次把文章寫到位。作者說，你一開始寫作的完整度大約抓五到七成即可，接著反覆修改三四次，完整度到八成、九成，最後達到目標。我個人也認為，比起一次就做到完美，循序漸進的方式會讓你比較有成就感，就不會文章寫到一半，因為到不了標準就放棄。</p>
# <h3 dir="ltr" style="font-size: 28px;">對抗懶惰，讓你產生學習動力</h3>
# <p dir="ltr" style="font-size: 16px;">前面講了那麼多方法來幫助我們提升學習知識的效率，但是真的要開始執行時，你會發現原來最大的敵人就是自己的惰性。</p>
# <p dir="ltr" style="font-size: 16px;">針對懶惰癌發作的我們，作者提供了幾個方法，其中一種叫做「改變姿勢」，也就是透過肢體行為，加強你的幹勁。假如你今天給自己的目標是讀完一本書，但整個人發懶，那你就讓自己先坐在書桌前，只看一頁也好，先透過行為讓你的潛意識「累積幹勁」。我也曾經在自己的書中分享如何開始閱讀的方法，首先就是培養身體感，讓自己的身體習慣「閱讀」這個動作，從而影響心理，發現自己其實是可以閱讀的人。</p>
# <p dir="ltr" style="font-size: 16px;">當我們在為自己設計學習進度時，作者也特別提醒，務必放低標準，把自己「狀態不好」的情況也考慮進去。比方說你打算在一個月內讀完 10 本書，進度安排上大約每週就要讀完 2.5 本，在設計計畫表時，你可能充滿動力，還會覺得一週看 2.5 本太少，但是通常執行個一兩天後，你會發現事情真的不是原本想的那麼簡單。可能你原訂 1 小時的閱讀時間，必須照顧小孩、洗衣服、洗碗，或者是你當天精神不好，根本沒辦法專注讀完一頁了，要不然就是工作太忙，最後決定把一小時的讀書時間讓給睡眠⋯⋯一個月 10 本好像很容易，拼一下就看完，可人真的不要低估自己的惰性。</p>
# <p dir="ltr" style="font-size: 16px;">所以作者建議，如果你是和他一樣常常犯懶，對事情容易感到厭倦的人，在你預估任務能完成的時間內，再加上對自己缺點的評估，假如你認為正常情況下 3 天能看完一本書，那麼就加入 2 天犯懶的時間，設定在 5 天內看完一本書。如此一來，完成了會更成就感，過程中也能更從容。</p>
# <p dir="ltr" style="font-size: 16px;">以上，就是今天關於《超效率學習法》的分享，我們下次見囉，掰掰。</p>
# <p dir="ltr" style="font-size: 16px;"><img class="fr-fic fr-dii pp_atteche pp-lightbox cursor-pointer" data-data="[object Object]" data-filekey="3813648E5A30AD8921C4FD6F92249274" data-filetype="image" data-height="750" data-message="success" data-src="https://static.pressplay.cc/static/uploads/timeline/20210415/21C00D0C1BA00FC17A8803AD45C2D147/6077de78840cd21C00D0C1BA00FC17A8803AD45C2D14720210415143432.jpg" data-status="success" data-uuid="b91e355b-7437-487f-be5f-b3abba9342bc" data-width="1350" src="https://static.pressplay.cc/static/uploads/timeline/20210415/21C00D0C1BA00FC17A8803AD45C2D147/6077de78840cd21C00D0C1BA00FC17A8803AD45C2D14720210415143432.jpg" style="font-size: 16px;"/></p>
# <p style="font-size: 16px;"><img class="fr-fic fr-dii pp_atteche pp-lightbox cursor-pointer" data-data="[object Object]" data-filekey="380A08D59B6CFC92E6A89CC741D4B0CE" data-filetype="image" data-height="750" data-message="success" data-src="https://static.pressplay.cc/static/uploads/timeline/20210415/21C00D0C1BA00FC17A8803AD45C2D147/6077de839eabe21C00D0C1BA00FC17A8803AD45C2D14720210415143443.jpg" data-status="success" data-uuid="9d10b30d-83f5-439b-bc03-dd0e0d5c874c" data-width="1350" src="https://static.pressplay.cc/static/uploads/timeline/20210415/21C00D0C1BA00FC17A8803AD45C2D147/6077de839eabe21C00D0C1BA00FC17A8803AD45C2D14720210415143443.jpg" style="font-size: 16px;"/></p>
# <h4 style="text-align: center; font-size: 24px;"><strong style="font-size: 24px;">【想要閱讀這本書？】</strong></h4>
# ...
#         11:11
#     </div> <div class="global-player-track-item" data-v-1e891f82="" rel="track-collect"><div class="global-player-track-btn" data-v-1e891f82=""><i class="icon icon-add_border" data-v-1e891f82=""></i></div></div> <!-- --></div><div class="global-player-track disabled" data-v-0177ee7e="" data-v-1e891f82="" head_title="啾音好書｜用說書開啟閱讀的新方式" head_title_url="https://www.pressplay.cc/project/082A3A85B647A6210495A9C0DCCC0FCC/vipp" index="15" publish_time="2021-05-19T19:00:00+0800" queue-index="99" style="display: none;" subscribed_rewards="" track_title_url="https://www.pressplay.cc/project/vippPage/%E6%89%8D%E8%83%BD%E7%9A%84%E7%9C%9F%E7%9B%B8%7E/648B8FFD1E5ECA30D3E7D4E766743ED1"><div class="global-player-track-item" data-v-1e891f82="" rel="track-cover"><div class="track-cover lazyload done lazy-bind lazy-empty" data-src="https://static.pressplay.cc/static/uploads/project/082A3A85B647A6210495A9C0DCCC0FCC/project_image_square/20210323/10B82A10626EC1830C00943930667F2B/6059be422118710B82A10626EC1830C00943930667F2B20210323180906.png" data-v-1e891f82="" style='background-image: url("https://i1.sndcdn.com/avatars-zTAfWVDdIylXIFWy-Jxyfaw-original.jpg");'></div></div> <div class="global-player-track-item" data-v-1e891f82="" rel="track-title"><div class="string-marquee after" data-v-1e891f82="" data-v-4e6a1012=""><div class="string-marquee-warpper" data-v-4e6a1012="">
#             才能的真相
#         </div></div></div> <div class="global-player-track-item" data-v-1e891f82="" rel="track-duration">
#         09:48
#     </div> <div class="global-player-track-item" data-v-1e891f82="" rel="track-collect"><div class="global-player-track-btn" data-v-1e891f82=""><i class="icon icon-add_border" data-v-1e891f82=""></i></div></div> <!-- --></div><div class="global-player-track disabled" data-v-0177ee7e="" data-v-1e891f82="" head_title="啾音好書｜用說書開啟閱讀的新方式" head_title_url="https://www.pressplay.cc/project/082A3A85B647A6210495A9C0DCCC0FCC/vipp" index="16" publish_time="2021-05-19T19:00:00+0800" queue-index="100" style="display: none;" subscribed_rewards="" track_title_url="https://www.pressplay.cc/project/vippPage/%E5%AF%82%E5%AF%9E%E7%9A%84%E8%AA%95%E7%94%9F%7E/6263C400EE99A73CDD039E8AC14A1AF8"><div class="global-player-track-item" data-v-1e891f82="" rel="track-cover"><div class="track-cover lazyload done lazy-bind lazy-empty" data-src="https://static.pressplay.cc/static/uploads/project/082A3A85B647A6210495A9C0DCCC0FCC/project_image_square/20210323/10B82A10626EC1830C00943930667F2B/6059be422118710B82A10626EC1830C00943930667F2B20210323180906.png" data-v-1e891f82="" style='background-image: url("https://static.pressplay.cc/static/uploads/album_cover/20210601/60F6285FF9905F531FE60FA16D1890D6/60b516772e81160F6285FF9905F531FE60FA16D1890D620210601010143.jpg");'></div></div> <div class="global-player-track-item" data-v-1e891f82="" rel="track-title"><div class="string-marquee" data-v-1e891f82="" data-v-4e6a1012=""><div class="string-marquee-warpper" data-v-4e6a1012="">
#             寂寞的誕生
#         </div></div></div> <div class="global-player-track-item" data-v-1e891f82="" rel="track-duration">
#         14:58
#     </div> <div class="global-player-track-item" data-v-1e891f82="" rel="track-collect"><div class="global-player-track-btn" data-v-1e891f82=""><i class="icon icon-add_border" data-v-1e891f82=""></i></div></div> <!-- --></div><div class="global-player-track disabled" data-v-0177ee7e="" data-v-1e891f82="" head_title="啾音好書｜用說書開啟閱讀的新方式" head_title_url="https://www.pressplay.cc/project/082A3A85B647A6210495A9C0DCCC0FCC/vipp" index="17" publish_time="2021-05-19T19:00:00+0800" queue-index="101" style="display: none;" subscribed_rewards="" track_title_url="https://www.pressplay.cc/project/vippPage/%E5%8F%AA%E6%9C%89%E8%AE%80%E6%9B%B8%E8%83%BD%E6%8A%B5%E9%81%94%E7%9A%84%7E/4B293048572A1E4AEF3B8869722C799A"><div class="global-player-track-item" data-v-1e891f82="" rel="track-cover"><div class="track-cover lazyload done lazy-bind lazy-empty" data-src="https://static.pressplay.cc/static/uploads/project/082A3A85B647A6210495A9C0DCCC0FCC/project_image_square/20210323/10B82A10626EC1830C00943930667F2B/6059be422118710B82A10626EC1830C00943930667F2B20210323180906.png" data-v-1e891f82="" style='background-image: url("https://static.pressplay.cc/static/uploads/album_cover/20200528/8E0CAC28BC7D11B61A9BF90442951388/5ecfa27f56a808E0CAC28BC7D11B61A9BF9044295138820200528193735.jpg");'></div></div> <div class="global-player-track-item" data-v-1e891f82="" rel="track-title"><div class="string-marquee" data-v-1e891f82="" data-v-4e6a1012=""><div class="string-marquee-warpper" data-v-4e6a1012="">
#             只有讀「書」能抵達的境界
#         </div></div></div> <div class="global-player-track-item" data-v-1e891f82="" rel="track-duration">
#         13:08
#     </div> <div class="global-player-track-item" data-v-1e891f82="" rel="track-collect"><div class="global-player-track-btn" data-v-1e891f82=""><i class="icon icon-add_border" data-v-1e891f82=""></i></div></div> <!-- --></div><div class="global-player-track" data-v-0177ee7e="" data-v-1e891f82="" head_title="啾音好書｜用說書開啟閱讀的新方式" head_title_url="https://www.pressplay.cc/project/082A3A85B647A6210495A9C0DCCC0FCC/vipp" index="18" publish_time="2021-05-10T15:00:00+0800" queue-index="102" subscribed_rewards="" track_title_url="https://www.pressplay.cc/project/vippPage/%E5%90%88%E4%BD%9C%E6%80%9D%E7%B6%AD%7E/B370F27D5394971B73111D52DD074015"><div class="global-player-track-item" data-v-1e891f82="" rel="track-cover"><div class="track-cover lazyload done lazy-bind" data-src="https://static.pressplay.cc/static/uploads/project/082A3A85B647A6210495A9C0DCCC0FCC/project_image_square/20210323/10B82A10626EC1830C00943930667F2B/6059be422118710B82A10626EC1830C00943930667F2B20210323180906.png" data-v-1e891f82="" style='background-image: url("https://static.pressplay.cc/static/uploads/project/082A3A85B647A6210495A9C0DCCC0FCC/project_image_square/20210323/10B82A10626EC1830C00943930667F2B/6059be422118710B82A10626EC1830C00943930667F2B20210323180906.png");'></div></div> <div class="global-player-track-item" data-v-1e891f82="" rel="track-title"><div class="string-marquee" data-v-1e891f82="" data-v-4e6a1012=""><div class="string-marquee-warpper" data-v-4e6a1012="">
#             合作思維
#         </div></div></div> <div class="global-player-track-item" data-v-1e891f82="" rel="track-duration">
#         00:00
#     </div> <div class="global-player-track-item" data-v-1e891f82="" rel="track-collect"><div class="global-player-track-btn" data-v-1e891f82=""><i class="icon icon-add_border" data-v-1e891f82=""></i></div></div> <!-- --></div><div class="global-player-track" data-v-0177ee7e="" data-v-1e891f82="" head_title="啾音好書｜用說書開啟閱讀的新方式" head_title_url="https://www.pressplay.cc/project/082A3A85B647A6210495A9C0DCCC0FCC/vipp" index="19" publish_time="2021-05-10T15:00:00+0800" queue-index="103" subscribed_rewards="" track_title_url="https://www.pressplay.cc/project/vippPage/%E8%8F%AF%E9%A0%93%E5%95%86%E5%AD%B8%E9%99%A2%E7%B5%A6%E5%85%A7%E5%90%91%7E/AB4EBD424A1AD8C9E507E7A2B8EB4F84"><div class="global-player-track-item" data-v-1e891f82="" rel="track-cover"><div class="track-cover lazyload done lazy-bind" data-src="https://static.pressplay.cc/static/uploads/project/082A3A85B647A6210495A9C0DCCC0FCC/project_image_square/20210323/10B82A10626EC1830C00943930667F2B/6059be422118710B82A10626EC1830C00943930667F2B20210323180906.png" data-v-1e891f82="" style='background-image: url("https://static.pressplay.cc/static/uploads/project/082A3A85B647A6210495A9C0DCCC0FCC/project_image_square/20210323/10B82A10626EC1830C00943930667F2B/6059be422118710B82A10626EC1830C00943930667F2B20210323180906.png");'></div></div> <div class="global-player-track-item" data-v-1e891f82="" rel="track-title"><div class="string-marquee" data-v-1e891f82="" data-v-4e6a1012=""><div class="string-marquee-warpper" data-v-4e6a1012="">
#             華頓商學院給內向者的表達課
#         </div></div></div> <div class="global-player-track-item" data-v-1e891f82="" rel="track-duration">
#         12:28
#     </div> <div class="global-player-track-item" data-v-1e891f82="" rel="track-collect"><div class="global-player-track-btn" data-v-1e891f82=""><i class="icon icon-add_border" data-v-1e891f82=""></i></div></div> <!-- --></div><div class="global-player-track focus" data-v-0177ee7e="" data-v-1e891f82="" head_title="啾音好書｜用說書開啟閱讀的新方式" head_title_url="https://www.pressplay.cc/project/082A3A85B647A6210495A9C0DCCC0FCC/vipp" index="20" publish_time="2021-05-10T15:00:00+0800" queue-index="104" subscribed_rewards="" track_title_url="https://www.pressplay.cc/project/vippPage/%E8%B6%85%E6%95%88%E7%8E%87%E5%AD%B8%E7%BF%92%E6%B3%95%7E/1CF3FF61991002F515CA07912A42D972"><div class="global-player-track-item" data-v-1e891f82="" rel="track-cover"><div class="track-cover lazyload lazy-bind done" data-src="https://static.pressplay.cc/static/uploads/project/082A3A85B647A6210495A9C0DCCC0FCC/project_image_square/20210323/10B82A10626EC1830C00943930667F2B/6059be422118710B82A10626EC1830C00943930667F2B20210323180906.png" data-v-1e891f82="" style='background-image: url("https://static.pressplay.cc/static/uploads/project/082A3A85B647A6210495A9C0DCCC0FCC/project_image_square/20210323/10B82A10626EC1830C00943930667F2B/6059be422118710B82A10626EC1830C00943930667F2B20210323180906.png");'></div></div> <div class="global-player-track-item" data-v-1e891f82="" rel="track-title"><div class="string-marquee" data-v-1e891f82="" data-v-4e6a1012=""><div class="string-marquee-warpper" data-v-4e6a1012="">
#             超效率學習法
#         </div></div></div> <div class="global-player-track-item" data-v-1e891f82="" rel="track-duration">
#         11:11
#     </div> <div class="global-player-track-item" data-v-1e891f82="" rel="track-collect"><div class="global-player-track-btn" data-v-1e891f82=""><i class="icon icon-add_border" data-v-1e891f82=""></i></div></div> <!-- --></div> <!-- --> <!-- --><div class="ps__scrollbar-x-rail" style="left: 0px; bottom: -166px;"><div class="ps__scrollbar-x" style="left: 0px; width: 0px;" tabindex="0"></div></div><div class="ps__scrollbar-y-rail" style="top: 166px; height: 89px; right: 0px;"><div class="ps__scrollbar-y" style="top: 58px; height: 31px;" tabindex="0"></div></div></section></div></div> <div class="global-player-playlist-toggle-bar" data-v-0177ee7e=""><div class="global-player-playlist-toggle-btn" data-v-0177ee7e=""><i class="icon icon-down_line" data-v-0177ee7e=""></i></div></div></div></div> <div class="global-player-main-box-layout" data-v-2931c3b3=""></div></div></div> <!-- --></div> <script type="application/ld+json">{"@context":"https:\/\/schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"item":{"@id":"https:\/\/www.pressplay.cc\/","name":"\u9996\u9801"}}]}</script></div> <script> /* Facebook JavaScript SDK Init */ window.fbAsyncInit = function() { FB.init({ appId : '943487429041504', autoLogAppEvents : true, xfbml : false, version : 'v2.11', status : true }); }; (function(d, s, id){ var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) {return;} js = d.createElement(s); js.id = id; js.src = "https://connect.facebook.net/zh_tw/sdk.js"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk')); </script> <!-- 載入 gtag --> <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-73798928-1"></script> <script> window.dataLayer = window.dataLayer || []; function gtag(){ dataLayer.push(arguments); } gtag('js', new Date()); gtag('config', 'UA-73798928-1', {"custom_map":{"dimension1":"register"}}); </script> <script src="https://appleid.cdn-apple.com/appleauth/static/jsapi/appleid/1/en_US/appleid.auth.js" type="text/javascript"></script> <!-- Start of pressplay Zendesk Widget script --> <!-- End of pressplay Zendesk Widget script --> <!-- Start Alexa Certify Javascript --> <script type="text/javascript"> _atrk_opts = { atrk_acct:"xX6yk1agMW00W5", domain:"pressplay.cc",dynamic: true}; (function() { var as = document.createElement('script'); as.type = 'text/javascript'; as.async = true; as.src = "https://d31qbv1cthcecs.cloudfront.net/atrk.js"; var s = document.getElementsByTagName('script')[0];s.parentNode.insertBefore(as, s); })(); </script> <noscript><img alt="alexa" height="1" src="https://d5nxst8fruw4z.cloudfront.net/atrk.gif?account=xX6yk1agMW00W5" style="display:none" width="1"/></noscript> <!-- End Alexa Certify Javascript --> <!-- Facebook Pixel Code --> <script> !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod? n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n; n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0; t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window, document,'script','https://connect.facebook.net/en_US/fbevents.js'); fbq('init', '964224507070009'); fbq('track', 'PageView'); </script> <noscript> <img alt="fb_pixel" src="https://www.facebook.com/tr?id=964224507070009&amp;ev=PageView&amp;noscript=1" style="display: none; overflow: hidden; width: unset;"> </img></noscript> <!-- End Facebook Pixel Code --> <script src="https://www.pressplay.cc/public/93fb319f9/js/app/main/index.bundle.js" type="text/javascript"></script> <script id="" src="//pressplaytw.api.useinsider.com/ins.js?id=10005389" type="text/javascript"></script><iframe id="insider-worker" src="https://pressplaytw.api.useinsider.com/worker-new.html" style="display: none;"></iframe><style id="ins-free-style" innerhtml=""></style><div class="popup-layout" style="display: none;">
# </div><div align="top" class="popup-wrapper" style="display: none;">
# <div class="popup-main" style="display: none;"><div class="pp-news-feed" data-v-4291aa0c="" data-v-566fdf37="" rel="flash"><div class="pp-news-feed-wrapper" data-v-4291aa0c=""><div class="pp-news-feed-header" data-v-4291aa0c="">2021 PPA 週年慶｜設計生活館 85 折</div> <div class="pp-news-feed-content" data-v-4291aa0c=""><div class="edit-js-content" data-v-4291aa0c="" data-v-9ed1fed2="" refs="box"><div class="ce-block"><p><span class="cdx-font-color cdx-font-color_hashf79420" data-color="#f79420" style="color: rgb(247, 148, 32);"><b>2021 PPA 週年慶｜設計生活館</b></span><br/><b>琢磨生活的美好<br/><br/>07.20</b> 前購買指定課程，<br/>結帳輸入 <b>DLIFE</b> 即享 <b>85</b> 折<br/>使用優惠碼完成訂單，再抽知名品牌<b>正負零除濕機一台</b></p></div>
# <div class="ce-block"><figure class="image-tool image-tool--filled">
# <div class="image-tool__image">
# <div class="image-tool__image-preloader"></div>
# <img alt="" class="image-tool__image-picture" src="https://static.pressplay.cc/static/uploads/pressplayNewsFeed/123/20210714/60ee51ad91d1920210714105333.png"/>
# </div>
# <figure></figure></figure></div>
# <div class="ce-block"><p>設計 X 生活 X 親子 X 手作 ｜PPA 與你一起享受日常時光</p></div>
# <div class="ce-block"><figure class="image-tool image-tool--filled image-tool--center">
# <div class="image-tool__image">
# <div class="image-tool__image-preloader"></div>
# <img alt="" class="image-tool__image-picture" src="https://static.pressplay.cc/static/uploads/pressplayNewsFeed/123/20210714/60ee6607048e520210714122023.png"/>
# </div>
# <figure></figure></figure></div></div></div> <div class="pp-news-feed-footer text-center" data-v-4291aa0c=""><div class="pp-news-feed-footer-wrapper" data-v-4291aa0c=""><div class="pp-news-feed-footer-item" data-v-4291aa0c=""><button class="btn btn-sm pp-news-feed-flash-button secondary_btn_pporange" data-layout_confirm="1" data-url="https://www.pressplay.cc/link/B7CF9612" data-v-4291aa0c="">🎁 手刀領 85 折</button></div><div class="pp-news-feed-footer-item" data-v-4291aa0c=""><button class="btn btn-sm pp-news-feed-flash-button primary_btn_pporange" data-layout_confirm="1" data-url="https://www.pressplay.cc/link/E85FDEA9" data-v-4291aa0c="">逛逛活動頁👀</button></div></div></div></div> <div class="pp-news-feed-close-btn pp-confirm" data-v-4291aa0c=""><div class="icon-close" data-v-4291aa0c=""></div></div></div></div></div><div class="fb_reset" id="fb-root"><div style="position: absolute; top: -10000px; width: 0px; height: 0px;"><div></div></div></div></body></html>
