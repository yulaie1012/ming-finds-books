# %%
# 廢

# 處理下拉選單 選ISBN
import requests
re = requests.get("https://metacat.ntu.edu.tw")
from bs4 import BeautifulSoup
soup = BeautifulSoup(re.text, "html.parser")
tabs = soup2.find('div', {'class', 'input-group-btn'}).findAll('select') #棒球的範例是找所有選單，Metacat只有一個，但反正沒差
ISBN = tabs[0].findAll('option')[2]['value'] # ISBN選項的位置

# 處理輸入
from selenium import webdriver
driver = webdriver.Chrome()
driver.get("https://metacat.ntu.edu.tw")

element = driver.find_element_by_class_name(“simpleSearchText.form-control”) # 搜尋欄的位置(但不知道有沒有"#"，還沒run過)

# %%
#自由input版

import time
from selenium import webdriver # 先下載 webdriver
from selenium.webdriver.support.ui import Select
ISBN = str(input())
driver = webdriver.Chrome("C:\\Users\\88698\\OneDrive\\文件\\chromedriver") # 要改成自己電腦的路徑
driver.get("https://metacat.ntu.edu.tw/") # 更改網址以前往不同網頁

element = driver.find_element_by_name('simpleSearchText')
element.send_keys(ISBN) #我把原本的ISBN改成 input
select = Select(driver.find_element_by_id('simpleType'))
select.select_by_value("ISBN")

button = driver.find_element_by_id('simpleSearchButton')
button.click()
time.sleep(2)

library = driver.find_element_by_class_name('institution-list').text
print(library)

www = driver.find_element_by_class_name('institution-list').get_attribute('href')
print(www)
# Out:
# 9789869109321
# 國立臺灣大學
# https://ntu.primo.exlibrisgroup.com/discovery/fulldisplay?context=L&vid=886NTU_INST:886NTU_INST&lang=zh-tw&docid=alma991012361209704786

# %%
#可以爬出各大學和超連結的大致完成版

from selenium import webdriver # 先下載 webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
import time

driver = webdriver.Chrome("C:\\Users\\88698\\OneDrive\\文件\\chromedriver") 
driver.get("https://metacat.ntu.edu.tw/") # 更改網址以前往不同網頁

ISBN = input()
element = driver.find_element_by_name('simpleSearchText')
element.send_keys(ISBN)
select = Select(driver.find_element_by_id('simpleType'))
select.select_by_value("ISBN")

button = driver.find_element_by_id('simpleSearchButton')
button.click()
time.sleep(70)

# 有"顯示更多"就按下去
more = driver.find_elements_by_name('collapseLink')
for i in range(len(more)):
    more[i].click()

# 每頁顯示 100 項搜尋結果
show = Select(driver.find_element_by_name("resultTable_length"))
show.select_by_value("100")
    
books = driver.find_elements_by_class_name('institution-list')
for i in range(len(books)):
    print(books[i].text)

www = driver.find_elements_by_class_name('institution-list')
for i in range(len(www)):
    place = www[i].get_attribute('href')
    if place != None:
        print(place)
    else:
        www[i].click()
        www2 = driver.find_elements_by_class_name('institution-list')
        print(www2[-1].get_attribute('href'))
        ActionChains(driver).move_by_offset(5, 5).click().perform()
        for i in range(len(more)):
            more[i].click()
# Out:
# 986729193X
# 國立臺灣大學
# 國立交通大學(多筆書目)
# 國立臺灣圖書館(多筆書目)
# 國立政治大學
# 國立清華大學
# 國立勤益科技大學
# 國立成功大學
# 國立中山大學
# 國立高雄師範大學
# 國立嘉義大學
# 義守大學
# 南臺科技大學
# 國立屏東科技大學
# 高苑科技大學
# 文藻外語大學
# 國立臺灣大學
# 工業技術研究院
# 中央研究院
# 國家衛生研究院
# 國立臺灣海洋大學
# 國立臺灣科技大學
# 國立陽明大學
# 國立臺灣師範大學
# 國家圖書館
# 義守大學
# 國立屏東大學
# 國立中正大學
# 國立暨南國際大學
# 國立臺北護理健康大學
# 國立中央大學(多筆書目)
# 元智大學(多筆書目)
# 國立臺北科技大學
# 國立宜蘭大學
# 景文科技大學(多筆書目)
# 臺北醫學大學(多筆書目)
# 新生醫專
# 國立臺中科技大學(多筆書目)
# 中原大學
# 彰化縣公共圖書館(多筆書目)
# 靜宜大學(多筆書目)
# 東海大學
# 國立臺中教育大學
# 中臺科技大學
# 國立東華大學
# 亞東技術學院
# 高雄市立圖書館(多筆書目)
# 高雄醫學大學(多筆書目)
# 遠東科技大學
# 崑山科技大學
# 和春技術學院
# 輔仁大學(多筆書目)
# 國立中興大學
# 銘傳大學
# 東吳大學
# 淡江大學
# 逢甲大學(多筆書目)
# 中國文化大學
# 國立臺南大學
# 長榮大學
# 國立屏東大學(多筆書目)
# 國立中正大學
# https://ntu.primo.exlibrisgroup.com/discovery/fulldisplay?context=L&vid=886NTU_INST:886NTU_INST&lang=zh-tw&docid=alma991032746609704786
# http://ustcate.lib.nctu.edu.tw/NCTU:NCTU_ALEPH001004060
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# <ipython-input-15-7a716b2e5012> in <module>
#      39         print(place)
#      40     else:
# ---> 41         www[i].click()
#      42         www2 = driver.find_elements_by_class_name('institution-list')
#      43         print(www2[-1].get_attribute('href'))
#
# c:\users\88698\appdata\local\programs\python\python39\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# c:\users\88698\appdata\local\programs\python\python39\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# c:\users\88698\appdata\local\programs\python\python39\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# c:\users\88698\appdata\local\programs\python\python39\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# ElementClickInterceptedException: Message: element click intercepted: Element <a class="institution-list" onclick="showResultModal('0', '2');">...</a> is not clickable at point (486, 260). Other element would receive the click: <div class="modal fade in" id="resultModal" role="dialog" aria-labelledby="resultModalLabel" tabindex="-1" style="display: block; padding-right: 6px;">...</div>
#   (Session info: chrome=90.0.4430.212)

# %%
#可以爬出各大學和超連結的大致完成版

from selenium import webdriver # 先下載 webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
import time

driver = webdriver.Chrome("C:\\Users\\88698\\OneDrive\\文件\\chromedriver") 
driver.get("https://metacat.ntu.edu.tw/") # 更改網址以前往不同網頁

ISBN = input()
element = driver.find_element_by_name('simpleSearchText')
element.send_keys(ISBN)
select = Select(driver.find_element_by_id('simpleType'))
select.select_by_value("ISBN")

button = driver.find_element_by_id('simpleSearchButton')
button.click()
time.sleep(70)

# 有"顯示更多"就按下去
more = driver.find_elements_by_name('collapseLink')
for i in range(len(more)):
    more[i].click()

# 每頁顯示 100 項搜尋結果
show = Select(driver.find_element_by_name("resultTable_length"))
show.select_by_value("100")
    
books = driver.find_elements_by_class_name('institution-list')
for i in range(len(books)):
    print(books[i].text)

www = driver.find_elements_by_class_name('institution-list')
xnum = 1
for i in range(len(www)):
    place = www[i].get_attribute('href')
    if place != None:
        print(place)
    else:
        www[i].click()
        www2 = driver.find_elements_by_class_name('institution-list')
        print(www2[-1].get_attribute('href'))
        X = driver.find_elements_by_class_name('close')
        X[xnum].click()
        xnum += 1
# Out:
# 986729193X
# 國立臺灣大學
# 國立臺灣圖書館(多筆書目)
# 國立清華大學
# 國立交通大學(多筆書目)
# 國立勤益科技大學
# 國立政治大學
# 國立嘉義大學
# 國立高雄師範大學
# 國立屏東科技大學
# 義守大學
# 南臺科技大學
# 國立中山大學
# 高苑科技大學
# 國立成功大學
# 文藻外語大學
# 國立臺灣大學
# 國家圖書館
# 國家衛生研究院
# 工業技術研究院
# 中央研究院
# 國立臺灣海洋大學
# 國立臺灣科技大學
# 國立暨南國際大學
# 國立陽明大學
# 國立中正大學
# 義守大學
# 國立臺灣師範大學
# 國立屏東大學
# 國立臺北護理健康大學
# 元智大學(多筆書目)
# 國立中央大學(多筆書目)
# 國立臺北科技大學
# 國立宜蘭大學
# 臺北醫學大學(多筆書目)
# 景文科技大學(多筆書目)
# 新生醫專
# 中原大學
# 國立臺中科技大學(多筆書目)
# 彰化縣公共圖書館(多筆書目)
# 靜宜大學(多筆書目)
# 國立臺中教育大學
# 東海大學
# 國立東華大學
# 高雄市立圖書館(多筆書目)
# 中臺科技大學
# 高雄醫學大學(多筆書目)
# 亞東技術學院
# 崑山科技大學
# 遠東科技大學
# 和春技術學院
# 輔仁大學(多筆書目)
# 國立中興大學
# 東吳大學
# 銘傳大學
# 淡江大學
# 逢甲大學(多筆書目)
# 國立中正大學
# 長榮大學
# 國立臺南大學
# 中國文化大學
# 國立屏東大學(多筆書目)
# https://ntu.primo.exlibrisgroup.com/discovery/fulldisplay?context=L&vid=886NTU_INST:886NTU_INST&lang=zh-tw&docid=alma991032746609704786
# http://cis.ntl.edu.tw/F?func=direct&l_base=NTL02&format=999&doc_number=000426179
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# <ipython-input-22-f3ad4da3c9fa> in <module>
#      44         print(www2[-1].get_attribute('href'))
#      45         X = driver.find_elements_by_class_name('close')
# ---> 46         X[xnum].click()
#      47         xnum += 1
#      48
#
# c:\users\88698\appdata\local\programs\python\python39\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# c:\users\88698\appdata\local\programs\python\python39\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# c:\users\88698\appdata\local\programs\python\python39\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# c:\users\88698\appdata\local\programs\python\python39\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# ElementNotInteractableException: Message: element not interactable
#   (Session info: chrome=90.0.4430.212)

# %%
#可以爬出各大學和超連結的完成版

from selenium import webdriver # 先下載 webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
import time

driver = webdriver.Chrome("C:\\Users\\88698\\OneDrive\\文件\\chromedriver") 
driver.get("https://metacat.ntu.edu.tw/") # 更改網址以前往不同網頁

ISBN = input()
element = driver.find_element_by_name('simpleSearchText')
element.send_keys(ISBN)
select = Select(driver.find_element_by_id('simpleType'))
select.select_by_value("ISBN")

button = driver.find_element_by_id('simpleSearchButton')
button.click()
time.sleep(70)

# 有"顯示更多"就按下去
more = driver.find_elements_by_name('collapseLink')
for i in range(len(more)):
    more[i].click()
    time.sleep(3)

# 每頁顯示 100 項搜尋結果
show = Select(driver.find_element_by_name("resultTable_length"))
show.select_by_value("100")
    
books = driver.find_elements_by_class_name('institution-list')
for i in range(len(books)):
    print(books[i].text)

www = driver.find_elements_by_class_name('institution-list')
for i in range(len(www)):
    place = www[i].get_attribute('href')
    if place != None:
        print(place)
    else:
        www[i].click()
        www2 = driver.find_elements_by_class_name('institution-list')
        print(www2[-1].get_attribute('href'))
        ActionChains(driver).move_by_offset(150, 200).click().perform()
        ActionChains(driver).move_by_offset(-150, -200).perform()
driver.close()
# Out:
# 986729193X
# 國立臺灣大學
# 國立臺灣圖書館(多筆書目)
# 國立交通大學(多筆書目)
# 國立清華大學
# 國立勤益科技大學
# 國立政治大學
# 國立屏東科技大學
# 國立高雄師範大學
# 南臺科技大學
# 國立中山大學
# 高苑科技大學
# 文藻外語大學
# 國立成功大學
# 義守大學
# 國立嘉義大學
# 國立臺灣大學
# 國家衛生研究院
# 工業技術研究院
# 中央研究院
# 國立臺灣海洋大學
# 國立臺灣科技大學
# 國家圖書館
# 國立陽明大學
# 國立臺灣師範大學
# 國立中正大學
# 國立屏東大學
# 國立暨南國際大學
# 義守大學
# 元智大學(多筆書目)
# 國立臺北護理健康大學
# 國立中央大學(多筆書目)
# 國立臺北科技大學
# 國立宜蘭大學
# 臺北醫學大學(多筆書目)
# 景文科技大學(多筆書目)
# 新生醫專
# 中原大學
# 國立臺中科技大學(多筆書目)
# 彰化縣公共圖書館(多筆書目)
# 靜宜大學(多筆書目)
# 國立臺中教育大學
# 東海大學
# 高雄市立圖書館(多筆書目)
# 國立東華大學
# 中臺科技大學
# 亞東技術學院
# 高雄醫學大學(多筆書目)
# 崑山科技大學
# 遠東科技大學
# 和春技術學院
# 輔仁大學(多筆書目)
# 國立中興大學
# 銘傳大學
# 東吳大學
# 淡江大學
# 逢甲大學(多筆書目)
# 國立中正大學
# 國立臺南大學
# 長榮大學
# 中國文化大學
# 國立屏東大學(多筆書目)
# https://ntu.primo.exlibrisgroup.com/discovery/fulldisplay?context=L&vid=886NTU_INST:886NTU_INST&lang=zh-tw&docid=alma991032746609704786
# http://cis.ntl.edu.tw/F?func=direct&l_base=NTL02&format=999&doc_number=000426179
# http://ustcate.lib.nctu.edu.tw/NCTU:NCTU_ALEPH001004060
# http://webpac.lib.nthu.edu.tw/F?func=direct&l_base=TOP01&format=999&doc_number=000273599
# http://140.128.95.6/F?func=direct&l_base=TOP02&format=999&doc_number=001173731
# https://nccu.primo.exlibrisgroup.com/discovery/fulldisplay?context=L&vid=886NCCU_INST:886NCCU_INST&lang=zh-tw&docid=alma991010195759705721
# http://primo.lib.npust.edu.tw/NPUST:NPUST_ALEPH005148651
# http://nknulib.nknu.edu.tw/search*cht/?searchtype=i&searcharg=986729193X
# http://webpac.lib.stust.edu.tw/F?func=direct&l_base=TOP02&format=999&doc_number=005140372
# http://dec.lib.nsysu.edu.tw/search~S1*cht/?searchtype=i&searcharg=986729193X
# http://lib-aleph2.kyu.edu.tw/F?func=direct&l_base=TOP01&format=999&doc_number=000077226
# http://libpac.wzu.edu.tw/search*cht/?searchtype=i&searcharg=986729193X
# http://weblis.lib.ncku.edu.tw/search~S1*cht/?searchtype=i&searcharg=986729193X
# http://webpac.isu.edu.tw/webpac/refid/005273244
# https://libaleph.ncyu.edu.tw/F?func=direct&l_base=TOP02&format=999&doc_number=005283822
# https://ntu.primo.exlibrisgroup.com/discovery/fulldisplay?context=L&vid=886NTU_INST:886NTU_INST&lang=zh-tw&docid=alma991029463179704786
# http://aleph.nhri.edu.tw/F?func=direct&l_base=NHR01&format=999&doc_number=000028024
# http://itrilib.itri.org.tw/F?func=direct&l_base=ITRIBIB&format=999&doc_number=002102702
# https://las.sinica.edu.tw/search*cht/?searchtype=i&searcharg=986729193X
# http://ocean.ntou.edu.tw/search*cht/?searchtype=i&searcharg=986729193X
# https://sierra.lib.ntust.edu.tw/search~S1*cht/?searchtype=i&searcharg=986729193X
# http://aleweb.ncl.edu.tw/F?func=direct&l_base=TOP02&format=999&doc_number=001429008
# http://library.ym.edu.tw/search~S7*cht/?searchtype=i&searcharg=986729193X
# http://opac.lib.ntnu.edu.tw/search*cht/i?SEARCH=986729193X
# http://webpac.lib.ccu.edu.tw/F?func=direct&l_base=TOP02&format=999&doc_number=006010206
# http://lib1.nptu.edu.tw/search*cht?/i986729193X/i986729193x/1%2C1%2C3%2CB/frameset&FF=i986729193x{213c63}{215765}&3%2C%2C3
# http://primo.lib.ncnu.edu.tw/NCNU:NCNU_ILS005206660
# http://webpac.isu.edu.tw/webpac/refid/005203972
# http://lib.yzu.edu.tw/ajaxYZlib/Search/Holding.aspx?bibliosno=256657
# http://140.131.94.8/uhtbin/cgisirsi/x/0/0/57/5/3?searchdata1=94583{CKEY}&searchfield1=GENERAL^SUBJECT^GENERAL^^&user_id=WEBSERVER
# http://opac.lib.ncu.edu.tw/search~S0*cht?/i986729193X/i986729193x/1%2C1%2C2%2CE/frameset&FF=i986729193x&2%2C%2C2
# https://libholding.ntut.edu.tw/bookDetail.do?id=218045
# https://lib.niu.edu.tw/bookDetail.do?id=269109
# https://libelis.tmu.edu.tw/bookDetail.do?id=235813
# https://jinwenlib.just.edu.tw/bookDetail.do?id=270516
# http://163.25.34.60:8080/toread/opac/bibliographic_view/101249
# http://cylis.lib.cycu.edu.tw/search*cht/?searchtype=i&searcharg=986729193X
# https://ntit.ent.sirsidynix.net/client/zh_TW/NUTC/search/detailnonmodal/ent:$002f$002fSD_ILS$002f0$002fSD_ILS:389444/one
# https://library.toread.bocach.gov.tw/toread/opac/bibliographic_view/341724
# http://webpac.lib.pu.edu.tw/webpac/bookDetail.do?id=724445
# http://webpac.lib.ntcu.edu.tw//bookDetail.do?id=72529
# http://140.128.103.234/bookDetail.do?id=188224
# http://webpac.ksml.edu.tw/bookDetail.do?id=74693
# http://134.208.29.214/toread/opac/bibliographic_view/175878
# http://120.107.56.24/Webq2t.aspx?brn=178029
# https://opac.oit.edu.tw/webopac//BookView1.aspx?url=Cxjg.aspx&dc=1&fc=4&n=7&d=Info000072&cata01=BLD0070224&key=1&num=&l=&dd=
# https://toread.kmu.edu.tw/toread/opac/bibliographic_view/55104;jsessionid=6B1FF0F97886F070B772F3A0FDAA3057?limit=50&offset=local%3A-3&q=isbn_issn%3A986729193X&source=local&view=CONTENT
# http://weblis.lib.ksu.edu.tw/webopac/BookView1.aspx?url=Cxjg.aspx&dc=1&fc=4&n=7&d=Info000072&cata01=BLD0030099&key=1&num=&l=&dd=
# http://hy.lib.feu.edu.tw/bookDetail.do?id=39848
# http://163.15.202.116/webopac/BookView1.aspx?url=Cxjg.aspx&dc=1&fc=4&n=7&d=Info000072&cata01=BHC0124894&key=1&num=&l=&dd=
# http://library.lib.fju.edu.tw/search*cht?/i986729193X/i986729193x/1%2C1%2C2%2CB/frameset&FF=i986729193x{213c63}{215765}&2%2C%2C2
# http://aleph.lib.nchu.edu.tw/F?func=direct&l_base=TOP02&format=999&doc_number=005217472
# https://uco-mcu.primo.exlibrisgroup.com/discovery/fulldisplay?context=L&vid=886UCO_MCU:886MCU_INST&lang=zh-tw&docid=alma991000399329705914
# https://uco-scu.primo.exlibrisgroup.com/discovery/fulldisplay?context=L&vid=886UCO_SCU:886SCU_INST&lang=zh-tw&docid=alma991004291389705913
# https://uco-network.primo.exlibrisgroup.com/discovery/fulldisplay?context=L&vid=886UCO_TKU:886TKU_INST&lang=zh-tw&docid=alma991003694619705912
# http://innopac.lib.fcu.edu.tw/search~S9*cht?/i986729193X/i986729193x/1%2C1%2C2%2CB/frameset&FF=i986729193x&2%2C%2C2
# http://webpac.lib.ccu.edu.tw/F?func=direct&l_base=TOP02&format=999&doc_number=005237218
# http://primo.nutn.edu.tw/NUTN:ILS_ALEPH:NUTN_ALEPH005368357
# http://discovery.lib.cjcu.edu.tw/CJCU:ILS:CJCU_ALEPH005199816
# http://webpac.pccu.edu.tw/search*cht/?searchtype=i&searcharg=986729193X
# http://lib1.nptu.edu.tw/search*cht?/i986729193X/i986729193x/1%2C1%2C3%2CB/frameset&FF=i986729193x{213c63}{215765}&2%2C%2C3

# %%
#可以爬出各大學和超連結的完成版

from selenium import webdriver # 先下載 webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
import time
import pandas as pd
from IPython.display import display

driver = webdriver.Chrome("C:\\Users\\88698\\OneDrive\\文件\\chromedriver") 
driver.get("https://metacat.ntu.edu.tw/") # 更改網址以前往不同網頁

ISBN = input()
element = driver.find_element_by_name('simpleSearchText')
element.send_keys(ISBN)
select = Select(driver.find_element_by_id('simpleType'))
select.select_by_value("ISBN")


# 把不要的勾掉
choose_btn = driver.find_element_by_link_text("機構單位篩選").click()
time.sleep(1)

btn_mid = driver.find_element_by_id('library1').click()
btn_south = driver.find_element_by_id('library2').click()
btn_east = driver.find_element_by_id('library3').click()

no_hsc = driver.find_element_by_id('hsc').click() # 新生醫專
no_tust = driver.find_element_by_id('tust').click() # 大華科大
no_must = driver.find_element_by_id('must').click() # 明新科大
no_taitheo = driver.find_element_by_id('taitheo').click() # 台灣神學研究學院
no_dila = driver.find_element_by_id('dila').click() # 法鼓文理學院
no_yzu = driver.find_element_by_id('yzu').click() # 元智大學
no_niu = driver.find_element_by_id('niu').click() # 宜蘭大學
no_lhu = driver.find_element_by_id('lhu').click() # 龍華科大
no_ntuvvAlma = driver.find_element_by_id('ntuvvAlma').click() # 原住民圖資中心

save_opt = driver.find_element_by_id("saveOptions").click() # 儲存已選選項
driver.switch_to_alert().accept() # 點選彈出裡面的確定按鈕
close = driver.find_element_by_class_name("close").click() # 按叉叉

search_gogogo = driver.find_element_by_id('simpleSearchButton').click()
time.sleep(70)

# 有"顯示更多"就按下去
more = driver.find_elements_by_name('collapseLink')
for i in range(len(more)):
    more[i].click()
    time.sleep(1)

# 每頁顯示 100 項搜尋結果
show = Select(driver.find_element_by_name("resultTable_length"))
show.select_by_value("100")
    
name = []
books = driver.find_elements_by_class_name('institution-list')
for i in range(len(books)):
    name.append(books[i].text)

URL = []
www = driver.find_elements_by_class_name('institution-list')
for i in range(len(www)):
    place = www[i].get_attribute('href')
    if place != None:
        URL.append(place)
    else:
        www[i].click()
        www2 = driver.find_elements_by_class_name('institution-list')
        URL.append(www2[-1].get_attribute('href'))
        ActionChains(driver).move_by_offset(150, 200).click().perform()
        ActionChains(driver).move_by_offset(-150, -200).perform()
driver.close()

dic = {}
for n, U in zip(name, URL):
    dic[n] = U
    
print(dic)
# Out:
# 986729193X
# <ipython-input-15-f568495b95c4>:40: DeprecationWarning: use driver.switch_to.alert instead
#   driver.switch_to_alert().accept() # 點選彈出裡面的確定按鈕
# {'國立臺灣大學': 'https://ntu.primo.exlibrisgroup.com/discovery/fulldisplay?context=L&vid=886NTU_INST:886NTU_INST&lang=zh-tw&docid=alma991029463179704786', '國立交通大學(多筆書目)': 'http://ustcate.lib.nctu.edu.tw/NCTU:NCTU_ALEPH001004060', '國立清華大學': 'http://webpac.lib.nthu.edu.tw/F?func=direct&l_base=TOP01&format=999&doc_number=000273599', '國立政治大學': 'https://nccu.primo.exlibrisgroup.com/discovery/fulldisplay?context=L&vid=886NCCU_INST:886NCCU_INST&lang=zh-tw&docid=alma991010195759705721', '國立臺灣圖書館(多筆書目)': 'http://cis.ntl.edu.tw/F?func=direct&l_base=NTL02&format=999&doc_number=000426179', '工業技術研究院': 'http://itrilib.itri.org.tw/F?func=direct&l_base=ITRIBIB&format=999&doc_number=002102702', '中央研究院': 'https://las.sinica.edu.tw/search*cht/?searchtype=i&searcharg=986729193X', '國家衛生研究院': 'http://aleph.nhri.edu.tw/F?func=direct&l_base=NHR01&format=999&doc_number=000028024', '國立臺灣海洋大學': 'http://ocean.ntou.edu.tw/search*cht/?searchtype=i&searcharg=986729193X', '國立臺灣科技大學': 'https://sierra.lib.ntust.edu.tw/search~S1*cht/?searchtype=i&searcharg=986729193X', '國家圖書館': 'http://aleweb.ncl.edu.tw/F?func=direct&l_base=TOP02&format=999&doc_number=001429008', '國立陽明大學': 'http://library.ym.edu.tw/search~S7*cht/?searchtype=i&searcharg=986729193X', '國立臺灣師範大學': 'http://opac.lib.ntnu.edu.tw/search*cht/i?SEARCH=986729193X', '國立臺北護理健康大學': 'http://140.131.94.8/uhtbin/cgisirsi/x/0/0/57/5/3?searchdata1=94583{CKEY}&searchfield1=GENERAL^SUBJECT^GENERAL^^&user_id=WEBSERVER', '國立中央大學(多筆書目)': 'http://opac.lib.ncu.edu.tw/search~S0*cht?/i986729193X/i986729193x/1%2C1%2C2%2CE/frameset&FF=i986729193x&2%2C%2C2', '國立臺北科技大學': 'https://libholding.ntut.edu.tw/bookDetail.do?id=218045', '景文科技大學(多筆書目)': 'https://jinwenlib.just.edu.tw/bookDetail.do?id=270516', '臺北醫學大學(多筆書目)': 'https://libelis.tmu.edu.tw/bookDetail.do?id=235813', '中原大學': 'http://cylis.lib.cycu.edu.tw/search*cht/?searchtype=i&searcharg=986729193X', '亞東技術學院': 'https://opac.oit.edu.tw/webopac//BookView1.aspx?url=Cxjg.aspx&dc=1&fc=4&n=7&d=Info000072&cata01=BLD0070224&key=1&num=&l=&dd=', '輔仁大學(多筆書目)': 'http://library.lib.fju.edu.tw/search*cht?/i986729193X/i986729193x/1%2C1%2C2%2CB/frameset&FF=i986729193x{213c63}{215765}&2%2C%2C2', '淡江大學': 'https://uco-network.primo.exlibrisgroup.com/discovery/fulldisplay?context=L&vid=886UCO_TKU:886TKU_INST&lang=zh-tw&docid=alma991003694619705912', '銘傳大學': 'https://uco-mcu.primo.exlibrisgroup.com/discovery/fulldisplay?context=L&vid=886UCO_MCU:886MCU_INST&lang=zh-tw&docid=alma991000399329705914', '東吳大學': 'https://uco-scu.primo.exlibrisgroup.com/discovery/fulldisplay?context=L&vid=886UCO_SCU:886SCU_INST&lang=zh-tw&docid=alma991004291389705913', '中國文化大學': 'http://webpac.pccu.edu.tw/search*cht/?searchtype=i&searcharg=986729193X'}

# %%
#可以爬出各大學和超連結版 2021.05.27

from selenium import webdriver # 先下載 webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
import time

driver = webdriver.Chrome("C:\\Users\\88698\\OneDrive\\文件\\chromedriver") 
driver.get("https://metacat.ntu.edu.tw/") # 更改網址以前往不同網頁

ISBN = input()
element = driver.find_element_by_name('simpleSearchText')
element.send_keys(ISBN)
select = Select(driver.find_element_by_id('simpleType'))
select.select_by_value("ISBN")

# 把不要的勾掉
choose_btn = driver.find_element_by_link_text("機構單位篩選").click()
time.sleep(1)

btn_mid = driver.find_element_by_id('library1').click()
btn_south = driver.find_element_by_id('library2').click()
btn_east = driver.find_element_by_id('library3').click()

no_hsc = driver.find_element_by_id('hsc').click() # 新生醫專
no_tust = driver.find_element_by_id('tust').click() # 大華科大
no_must = driver.find_element_by_id('must').click() # 明新科大
no_taitheo = driver.find_element_by_id('taitheo').click() # 台灣神學研究學院
no_dila = driver.find_element_by_id('dila').click() # 法鼓文理學院
no_yzu = driver.find_element_by_id('yzu').click() # 元智大學
no_niu = driver.find_element_by_id('niu').click() # 宜蘭大學
no_lhu = driver.find_element_by_id('lhu').click() # 龍華科大
no_ntuvvAlma = driver.find_element_by_id('ntuvvAlma').click() # 原住民圖資中心

save_opt = driver.find_element_by_id("saveOptions").click() # 儲存已選選項
driver.switch_to_alert().accept() # 點選彈出裡面的確定按鈕
close = driver.find_element_by_class_name("close").click() # 按叉叉

search_gogogo = driver.find_element_by_id('simpleSearchButton').click()
time.sleep(70)

# 有"顯示更多"就按下去
more = driver.find_elements_by_name('collapseLink')
for i in range(len(more)):
    more[i].click()
    time.sleep(1)

# 每頁顯示 100 項搜尋結果
show = Select(driver.find_element_by_name("resultTable_length"))
show.select_by_value("100")
    
#
name = []
books = driver.find_elements_by_class_name('institution-list')
for i in range(len(books)):
    name.append(books[i].text)

URL = []
www = driver.find_elements_by_class_name('institution-list')
for i in range(len(www)):
    web = www[i].get_attribute('href')
    if web != None:
        URL.append(web)
        #進各網頁爬狀態囉
        driver.get(str(web))
            
    else:
        www[i].click()
        www2 = driver.find_elements_by_class_name('institution-list')
        URL.append(www2[-1].get_attribute('href'))
        ActionChains(driver).move_by_offset(150, 200).click().perform()
        ActionChains(driver).move_by_offset(-150, -200).perform()
driver.close()
# Out:
# 9789869109321
# <ipython-input-6-0a2acc313d7d>:37: DeprecationWarning: use driver.switch_to.alert instead
#   driver.switch_to_alert().accept() # 點選彈出裡面的確定按鈕
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# <ipython-input-6-0a2acc313d7d> in <module>
#      60 www = driver.find_elements_by_class_name('institution-list')
#      61 for i in range(len(www)):
# ---> 62     web = www[i].get_attribute('href')
#      63     if web != None:
#      64         URL.append(web)
#
# c:\users\88698\appdata\local\programs\python\python39\lib\site-packages\selenium\webdriver\remote\webelement.py in get_attribute(self, name)
#     137         attributeValue = ''
#     138         if self._w3c:
# --> 139             attributeValue = self.parent.execute_script(
#     140                 "return (%s).apply(null, arguments);" % getAttribute_js,
#     141                 self, name)
#
# c:\users\88698\appdata\local\programs\python\python39\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute_script(self, script, *args)
#     632             command = Command.EXECUTE_SCRIPT
#     633
# --> 634         return self.execute(command, {
#     635             'script': script,
#     636             'args': converted_args})['value']
#
# c:\users\88698\appdata\local\programs\python\python39\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# c:\users\88698\appdata\local\programs\python\python39\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=90.0.4430.212)

# %%
def status(web):
    web = str(web)
    driver.get(web)
    output = []
    if 'ntu.primo' in web: #台大系統
        time.sleep(5)
        thelist = driver.find_elements_by_class_name("md-2-line.md-no-proxy._md")
        for row in thelist:
            plist = row.find_elements_by_tag_name("p")
            where = row.find_elements_by_tag_name("h3")
            i = len(where)
            for sth in plist:
                a = sth.find_elements_by_tag_name("span")
                for _ in range(i): 
                    output.append(str('台灣大學 ' + where[_].text + ' ' + a[0].text + ' ' + a[2].text))
                    break
                break
        
    elif 'ntnu' in web: #師大系統
        trlist = driver.find_elements_by_class_name('bibItemsEntry')
        for row in trlist:
            tdlist = row.find_elements_by_tag_name('td')
            output.append(str('臺灣師範大學 ' + ' ' + tdlist[0].text + ' ' + tdlist[3].text))
        
    elif 'nccu' in web: #政大系統
        time.sleep(5)
        thelist = driver.find_elements_by_class_name("md-2-line.md-no-proxy._md")
        for row in thelist:
            plist = row.find_elements_by_tag_name("p")
            where = row.find_elements_by_tag_name("h3")
            i = len(where)
            for sth in plist:
                a = sth.find_elements_by_tag_name("span")
                for _ in range(i): 
                    output.append(str('政治大學 ' + where[_].text + ' ' + a[0].text + ' ' + a[2].text))
                    break
                break
        
    elif 'ntust' in web: #台科大系統
        trlist = driver.find_elements_by_class_name('bibItemsEntry')
        for row in trlist:
            tdlist = row.find_elements_by_tag_name('td')
            output.append(str('臺灣科技大學 ' + tdlist[0].text + ' ' + tdlist[5].text))
        
    elif 'ym' in web: #陽明系統
        trlist = driver.find_elements_by_class_name('bibItemsEntry')
        for row in trlist:
            tdlist = row.find_elements_by_tag_name('td')
            output.append(str('陽明大學 ' + tdlist[0].text + ' ' + tdlist[3].text))
            
    elif 'ntou' in web: #海大系統
        trlist = driver.find_elements_by_class_name('bibItemsEntry')
        for row in trlist:
            tdlist = row.find_elements_by_tag_name('td')
            output.append(str('海洋科技大學 ' + tdlist[0].text + ' ' + tdlist[3].text))
            
    elif 'ntcu' in web: #交大系統
        time.sleep(5)
        thelist = driver.find_elements_by_class_name("tab-content-header.margin-bottom-small.margin-left-medium.layout-align-space-between-end.layout-row")
        for row in thelist:
            plist = row.find_elements_by_tag_name("p")
            where = row.find_elements_by_tag_name("h4")
            i = len(where)
            for sth in plist:
                a = sth.find_elements_by_tag_name("span")
                for _ in range(i): 
                    output.append(str('交通大學 ' + where[_].text + ' ' + a[0].text + ' ' + a[2].text))
                    break
                break
        
    elif 'nthu' in web: #清華系統
        where = driver.find_elements_by_link_text('全部館藏')[1].click()
        table = driver.find_element_by_xpath("/html/body/table[12]")
        trlist = table.find_elements_by_tag_name('tr')
        for row in trlist:
            tdlist = row.find_elements_by_tag_name('td')
            for sth in tdlist:
                output.append(str('清華大學 ' + tdlist[2].text + ' ' + tdlist[8].text))
                break
        
    elif 'ncu' in web: #中央系統
        trlist = driver.find_elements_by_class_name('bibItemsEntry')
        for row in trlist:
            tdlist = row.find_elements_by_tag_name('td')
            output.append(str('中央大學 ' + tdlist[0].text + ' ' + tdlist[3].text))
            
    elif 'ncl' in web: #國圖系統
        where = driver.find_element_by_link_text("書在哪裡(請點選)").click()
        time.sleep(2)
        tdlist = driver.find_elements_by_class_name('td1')
        output.append(str('國家圖書館 ' + tdlist[1].text + ' ' + tdlist[6].text)) 
        
    elif 'las.sinica' in web: #中研院系統
        trlist = driver.find_elements_by_class_name('bibItemsEntry')
        for row in trlist:
            tdlist = row.find_elements_by_tag_name('td')
            output.append(str('中央研究院 ' + tdlist[0].text + ' ' + tdlist[2].text))
            
    elif 'ntpu' in web: #北大系統
        table = driver.find_element_by_class_name("book_location")
        trlist = table.find_elements_by_class_name('odd')
        for row in trlist:
            tdlist = row.find_elements_by_tag_name('td')
            for sth in tdlist:
                output.append(str('台北大學 ' + tdlist[2].text))
                break
                
    elif '203.64.5.158' in web: #台北藝術大學系統
        where = driver.find_element_by_xpath("/html/body/div/div[1]/div[2]/div/div/div[2]/div[3]/div[1]/div[3]/div/ul/li/div/div[2]/h3/a").click()
        time.sleep(2)
        table = driver.find_element_by_class_name('table.table-bordered')
        trlist = table.find_elements_by_tag_name('tr')
        for row in trlist:
            tdlist = row.find_elements_by_tag_name('td')
            for sth in tdlist:
                output.append(str('台北藝術大學 ' + tdlist[0].text + ' ' + tdlist[5].text))
                break
                
    elif '140.131.94.8' in web: #護理健康大學系統
        table = driver.find_element_by_xpath("/html/body/div[4]/div[1]/form[1]/div[2]/div[1]/ul[3]/li[1]/ul[3]/li[2]/table")
        trlist = table.find_elements_by_tag_name('tr')
        for _ in trlist:
            tdlist = driver.find_elements_by_class_name('holdingslist')
            output.append(str('台北護理健康大學 ' + tdlist[3].text))
            break
            
    elif 'ntut' in web: #北科系統
        table = driver.find_element_by_class_name('order')
        trlist = table.find_elements_by_tag_name('tr')
        for row in trlist:
            tdlist = row.find_elements_by_tag_name('td')
            for sth in tdlist:
                output.append(str('台北科技大學 ' + tdlist[2].text + ' ' + tdlist[8].text))
                break    
                
    elif 'ntl' in web: #國台圖系統
        where = driver.find_element_by_xpath("/html/body/table[8]/tbody/tr[1]/td[2]/a").click()
        time.sleep(2)
        tdlist = driver.find_elements_by_class_name('td1')
        output.append(str('國立台灣圖書館 ' + tdlist[8].text + ' ' + tdlist[9].text + ' ' + tdlist[15].text))
        
    elif 'itrilib' in web: #工研院系統
        where = driver.find_element_by_xpath("/html/body/table[8]/tbody/tr[1]/td[2]/a").click()
        time.sleep(2)
        tdlist = driver.find_elements_by_class_name('td1')
        output.append(str('工業研究院 ' + tdlist[9].text + ' ' + tdlist[10].text + ' ' + tdlist[12].text))
        
    elif 'nhri' in web: #國衛院系統
        where = driver.find_element_by_xpath('/html/body/table[8]/tbody/tr[1]/td[2]/a').click()
        time.sleep(2)
        tdlist = driver.find_elements_by_class_name('td1')
        print('國家衛生研究院 ' + tdlist[6].text + ' ' + tdlist[7].text + ' ' + tdlist[13].text))
        
    elif 'pccu' in web: #中國文化大學系統
        trlist = driver.find_elements_by_class_name('bibItemsEntry')
        for row in trlist:
            tdlist = row.find_elements_by_tag_name('td')
            output.append(str('中國文化大學 ' + tdlist[0].text + ' ' + tdlist[3].text))

    elif 'shu' in web: #世新系統       
        where = driver.find_element_by_link_text("世新圖書館").click()
        table = driver.find_element_by_xpath("/html/body/p[2]/table[1]")
        trlist = table.find_elements_by_tag_name('tr')
        for row in trlist:
            tdlist = row.find_elements_by_tag_name('td')
            for sth in tdlist:
                output.append(str('世新大學 ' + tdlist[1].text + ' ' + tdlist[3].text))
                break
                
    elif 'uco-network' in web: #淡江系統
        time.sleep(5)
        thelist = driver.find_elements_by_class_name("md-2-line.has-expand.md-no-proxy.md-with-secondary._md")
        for row in thelist:
            plist = row.find_elements_by_tag_name("p")
            for sth in plist:
                output.append(str('淡江大學 ' + plist[0].text + ' ' + plist[1].text))
                break
                
    elif 'fju' in web: #輔仁大學系統
        trlist = driver.find_elements_by_class_name('bibItemsEntry')
        for row in trlist:
            tdlist = row.find_elements_by_tag_name('td')
            output.append(str('輔仁大學 ' + tdlist[0].text + ' ' + tdlist[3].text))

    elif 'mcu' in web: #銘傳系統
        time.sleep(5)
        thelist = driver.find_elements_by_class_name("md-2-line.md-no-proxy._md")
        for row in thelist[:-2]:
            plist = row.find_elements_by_tag_name("p")
            where = row.find_elements_by_tag_name("h3")
            i = len(where)
            for sth in plist:
                a = sth.find_elements_by_tag_name("span")
                for _ in range(1): 
                    output.append(str('銘傳大學 ' + where[_].text + ' ' + a[0].text))
                    break
                break 
        
    elif 'scu' in web: #東吳系統
        time.sleep(5)
        thelist = driver.find_elements_by_class_name("md-2-line.md-no-proxy._md")
        for row in thelist[:-2]:
            plist = row.find_elements_by_tag_name("p")
            where = row.find_elements_by_tag_name("h3")
            i = len(where)
            for sth in plist:
                a = sth.find_elements_by_tag_name("span")
                for _ in range(1): 
                    output.append(str('東吳大學 ' + where[_].text + ' ' + a[0].text))
                    break
                break 
        
    elif 'cylis' in web: #中原大學系統
        trlist = driver.find_elements_by_class_name('bibItemsEntry')
        for row in trlist:
            tdlist = row.find_elements_by_tag_name('td')
            output.append(str('中原大學 ' + tdlist[0].text + ' ' + tdlist[3].text))
        
    elif 'tmu' in web: #北醫系統
        table = driver.find_element_by_class_name('order')
        trlist = table.find_elements_by_tag_name('tr')
        for row in trlist:
            tdlist = row.find_elements_by_tag_name('td')
            for sth in tdlist:
                output.append(str('台北醫學大學 ' + tdlist[2].text + ' ' + tdlist[5].tex))
                break
    
    elif 'moc' in web: #台博館系統
        where = driver.find_element_by_link_text("書在哪裡 ? (請點我)").click()
        table = driver.find_element_by_xpath("/html/body/table[9]")
        trlist = table.find_elements_by_tag_name('tr')
        for row in trlist:
            tdlist = row.find_elements_by_tag_name('td')
            for sth in tdlist:
                output.append(str('國立台灣博物館 ' + tdlist[2].text + ' ' + tdlist[3].text + ' ' + tdlist[7].text))
                break
        
    elif 'jinwen' in web: #景文科大系統
        table = driver.find_element_by_class_name('order')
        trlist = table.find_elements_by_tag_name('tr')
        for row in trlist:
            tdlist = row.find_elements_by_tag_name('td')
            for sth in tdlist:
                output.append(str('景文科技大學 ' + tdlist[2].text + ' ' + tdlist[5].text))
                break
    
    elif 'mmc' in web: #馬偕醫護系統
        where = driver.find_element_by_xpath("/html/body/table[8]/tbody/tr[1]/td[2]/span/a[1]").click()
        time.sleep(2)
        tdlist = driver.find_elements_by_class_name('td1')
        output.append(str('馬偕醫護管理專科學校 ' + tdlist[7].text + ' ' + tdlist[12].text))
          
    elif 'tfi' in web: #視聽文化中心系統
        table = driver.find_element_by_xpath("/html/body/div/div[1]/div/div/div/div[2]/div/div[2]/div[3]/div/div[4]")
        trlist = table.find_elements_by_tag_name('tr')
        for row in trlist:
            tdlist = row.find_elements_by_tag_name('td')
            for sth in tdlist:
                output.append(str('國家視聽文化中心 ' + tdlist[1].text + ' ' + tdlist[4].text))
                break
    
    return output
# Out:
#   File "<ipython-input-1-53fb4d71280f>", line 152
#     print('國家衛生研究院 ' + tdlist[6].text + ' ' + tdlist[7].text + ' ' + tdlist[13].text))
#                                                                                      ^
# SyntaxError: unmatched ')'

# %%
#台大_純狀態
from selenium import webdriver
import time
driver = webdriver.Chrome("C:\\Users\\88698\\OneDrive\\文件\\chromedriver") 
#台大
driver.get('https://ntu.primo.exlibrisgroup.com/discovery/fulldisplay?context=L&vid=886NTU_INST:886NTU_INST&lang=zh-tw&docid=alma991029463179704786')
time.sleep(5)

unava = driver.find_elements_by_class_name('availability-status.unavailable')
ava = driver.find_elements_by_class_name('availability-status.available')

for i in range(len(unava)):
    print(unava[i].text)
    
for j in range(len(ava)):
    print(ava[j].text)
# Out:
# 有可用館藏
# 有可用館藏

# %%
#台大
from selenium import webdriver
import time
driver = webdriver.Chrome("C:\\Users\\88698\\OneDrive\\文件\\chromedriver") 
#台大
driver.get('https://ntu.primo.exlibrisgroup.com/discovery/fulldisplay?context=L&vid=886NTU_INST:886NTU_INST&lang=zh-tw&docid=alma991012361209704786')
time.sleep(5)

plst = []
slst = []

into = driver.find_elements_by_class_name('md-list-item-text.layout-wrap.layout-row.flex')
for i in range(len(into)):
    into[i].click()
    time.sleep(1)
    place = driver.find_element_by_class_name('md-title.ng-binding.zero-margin').text
    ava = driver.find_element_by_xpath('//*[@id="tab-content-57"]/div/md-content/prm-location-items/div[2]/div[1]/p[1]/span[1]').text
    plst.append(place)
    slst.append(ava)
    back = driver.find_element_by_xpath('/html/body/primo-explore/div/prm-full-view-page/prm-full-view-cont/md-content/div[2]/prm-full-view/div/div/div/div[1]/div/div[4]/div/prm-full-view-service-container/div[2]/div/prm-opac/md-tabs/md-tabs-content-wrapper/md-tab-content[2]/div/div/prm-opac-back-button/button').click()
print(plst)
print(slst)
# Out:
# []
# []

# %%
from selenium import webdriver
import time
driver = webdriver.Chrome("C:\\Users\\88698\\OneDrive\\文件\\chromedriver") 

driver.get('https://uco-scu.primo.exlibrisgroup.com/discovery/fulldisplay?context=L&vid=886UCO_SCU:886SCU_INST&lang=zh-tw&docid=alma991004291389705913')
time.sleep(5)
thelist = driver.find_element_by_class_name("separate-list-items.margin-bottom-medium.padding-bottom-zero.md-primoExplore-theme")
print(thelist.text)
# Out:
# 城區分館書庫
# 目前可獲得 , 城區分館書庫 ; 550 4022-1
# 查找
# 雙溪中正書庫
# 目前可獲得 , 雙溪中正書庫 ; 550 4022-1
# 查找
